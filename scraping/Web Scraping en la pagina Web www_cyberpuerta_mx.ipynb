# %% [markdown]
# <h1 style="color:blue">Proyecto de Scraping con BeautifulSoup en la página www.cyberpuerta.mx</h1>

# %% [markdown]
# <h2 style="color:magenta">1.- Instalar e Importar nuestra libreria y darle un vistazo de la página :</h2>

# %% [markdown]
# <h3 style="color:yellow">Despues de realizar la instalación de nuestras siguiente libreria:</h3>
# <h3 style="color:yellow">-- pip -- numpy -- pandas --  matplotlib --  requests -- seaborn -- BeautifulSoup</h3>

# %% [markdown]
# <h3 style="color:yellow">Vamos a realizar el llamado de nuestras librerias ya instaladas</h3>

# %% [markdown]
# ##### <span style="color:blue">El proceso de Web Scraping es el de realizar un analisis. Ver que tipo de página es por ejemplo ésta es una tienda por que tiene un catálogo y es de libros a la venta. En este caso Podemos identificar ciertos elementos en partícular. Se identifican del lado izquierdo una lista de categorias de libros. Y sobre el lado derecho podemos ver una información o registros; por ejemplo fortos ilustrativas, unas estrellas que representan un raiting, el título de libro, el precio y si existe en la tienda o no. Y por último un botón donde puedes agregar al carrito. Este analisis o proceso de Web Scrap se realiza haciendo analisis, extrayendo la información que queremos extraer, e ir identificando cada unos de estos elementos.</span>

# %%
import numpy as np
import pandas as pd
import requests
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup

# %% [markdown]
# <h2 style="color:magenta">2.- Enviar petición HTTP para extraer Código Fuente de la Página Web</h2>

# %% [markdown]
# ##### <span style="color:blue">Para realizar una petición o (requests). El Código Fuente en terminos generales es el lenguaje etiquetado que despliega todo lo que podemos ver en la página. Los recuadros, las imagenes, los textos son etiquetas dentro de un archivo HTML. Donde HTML es un lenguaje utilizado para escrituras de páginas Web. En terminos generales está basado en una estructura de árbol. Las etiquetas sirven para identificar estos elementos básicos como de una página web como sus etiquetas HTML, sus etiquetas HEAD, sus etiquetas BODY, etc. Que es donde nosotros vamos escribiendo y vamos estructurando nuestra página Web.</span>

# %% [markdown]
# ##### <span style="color:yellow">Despues de identificar todos los elementos. Lo que quisieramos extraer es una LISTA que nos interesara. Por ejemplo los 10 libros mas vendidos de la tienda, O los mejores libros de cada categoría, los últimos libros agregados a cierta categoría, los libros más varatos, cuáles libros ya no están en existencia. Todas éstas incógnitas las podemos obtener de la página web y las respuestas las podemos guardar como un DataFrame para despues visualizarlos con matplotlib.</span>

# %% [markdown]
# ##### <span style="color:yellow">Para poder obtener el Código Fuente de una página vamos hacer una petición HTML utilizando un (url) con un (requests) para obtenerlo..</span>

# %% [markdown]
# ##### <span style="color:yellow">Una vez aceptada nuestra petición podemos crear un objeto (soup) el cual toma como objeto BeautifulSoup y le mandamos la respuesta obtenida del requests y accedemos al atributo text y definimos un analizador en este caso html. Una vez accedido al códgo fuente podemos desplegar el Código Funte de la página.</span>

# %% [markdown]
# ##### <span style="color:yellow">En resumen es ael procceso es de extraer información útil o la información que se le va a sacar provecho de una página web es acceder a la página web. Copiar el link o la dirección de esa página en donde estás interesado. Escogemos el donde queremos investigar por ejemplo en el área de categorias escogemos los libros de ciencia ficción y nos despliega en pantalla los libros según la categoría y nos preguntamos que queremos buscar los mejores 2 libros de esa categoría. Lo que se hace es pasar directamente el link o la liga URL que aparece en la parte superior de tu buscador o browser.</span>

# %% [markdown]
# ##### <span style="color:yellow">Lo colocas en tu variable creada (pagina_web) igualandolo. Después creas tu objeto (BeautifulSoup) igualado en tu variable (soup) donde vas a pasarle el texto de tu respuesta recibida de la variable (pagina_web) y lo despliegas en pantalla.</span>

# %% [markdown]
# ##### <span style="color:yellow">La ventaja de ver la página web en su entorno que distinguir todas esas ramificaciones, todos estos nodos que se van desprendiendo. Desde la etiqueta HTML, la etiqueta HEAD, BODY y dentro de cada una de ellas lo que se va desprendiedo. Obeservamos que en nuetra etiqueta BODY es donde se desprende todos nuestros elementos o la información que son útiles para obtener la información deseada ó buscada. .</span>

# %%
pagina_web = requests.get('https://www.cyberpuerta.mx/Computadoras/PC-s-de-Escritorio/') # Un request con su url

print("Si despliega <Response [200]> (entonces tu petición fue escuchada y aceptada)  : ",pagina_web) # Se despliega el resultado obtenido por la petición
print()

soup = BeautifulSoup(pagina_web.text,'html.parser')

print(soup.prettify())
# Out:
# Si despliega <Response [200]> (entonces tu petición fue escuchada y aceptada)  :  <Response [200]>
#
# <!DOCTYPE HTML>
# <html lang="es">
#  <head>
#   <link href="https://www.cyberpuerta.mx/out/generated/cms-pages.css?1593624763" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/em.selectbox.css?1690486847" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headerlogin.css?1690486847" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headernotice.css?1690486847" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headercompare.css?1690486847" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headerhelp.css?1690486847" rel="stylesheet" type="text/css"/>
# ...

# %% [markdown]
# ##### <span style="color:blue">Una vez aceptada nuestra petición y revisa toda la información de la misma que se desplega en pantalla. Vamos a realizar nuestro ejercicio. Vemos que podemos obtener la siguiente información específica directamente de lo mostrado en pantalla. Por ejemplo todo lo quepodemos obtener. En éste caso vamos a extraer de estos libros el : raiting, nombre del libro, precio, y si lo tienen disponible en tienda o no.</span>

# %% [markdown]
# ##### <span style="color:blue">El proceso para que nosostros podamos extraer ésta o la información que necesitamos es identificar el elemento de HTML o la etiqueta HTML que contenga el elemento que estamos buscando o el que queremos extraer directamente.</span>

# %% [markdown]
# ##### <span style="color:blue">Para la busqueda lo que se hace es asignar a variables nustros elementos a buscar. Entonces vamos hacer uso de las funciones que nos da (BeautifulSoup) para encontrar ciertos elementos. Vamos a crear una variable llamada (marcas_items) seguida de su código fuente (soup) y después la función (find) la cual toma como argumento un entrada de texto o ciertos indicadores </span>

# %%
marcas_items = soup.find('a')

print(marcas_items)
# Out:
# <a data-open="cpsaldo_newsletter_modal_popup" id="cpsaldo_newsletter_modal_popup_link" style="display:none;">cpsaldo_newsletter</a>

# %% [markdown]
# ##### <span style="color:blue">Para buscar todos las etiquetas (a) pondriamos lo siguiente y guardaría todas las etiquetas en un arreglo.</span>

# %%
marcas_items = soup.find_all('a')

print(marcas_items)
# Out:
# [<a data-open="cpsaldo_newsletter_modal_popup" id="cpsaldo_newsletter_modal_popup_link" style="display:none;">cpsaldo_newsletter</a>, <a class="logo" href="https://www.cyberpuerta.mx/" title="">
# <img alt="" src="https://www.cyberpuerta.mx/out/cyberpuertaV5/img/logo2.png"/>
# </a>, <a href="https://www.cyberpuerta.mx/olvide-mi-contrasena/" style="text-align: center;color:#0066bb;font-weight: 700; line-height: 20px;padding: 8px 0 7px 0;" title="Olvidé mi contraseña">
# Olvidé mi contraseña
# </a>, <a class="normalButton largeButton oxwidget_headerlogin_register_button" href="https://www.cyberpuerta.mx/crear-cuenta/" style="margin-right:-3px;">
# Registrarse
# ...

# %% [markdown]
# ##### <span style="color:blue">Vamos agregarle otro tipo de filtro. Utilizando una estructura de control llamada (for) para poder trabajar con los registros. Donde le vamos a decir para cada item en (marcas_items). Se define una otra variable llamada (marca) la cual se va igualar al código fuente y buscamos la etiqueta (title).</span>

# %%
#marcas_items = soup.find_all('div')

#for item in marcas_items:
#    print(item.attrs)



#marcas_items = soup.find_all('a')

#print(marcas_items)



#marcas_items = soup.find_all('a')

#print(marcas_items)


# Vamos acceder directamente a las etiquetas titulo
#marcas_items = soup.find_all('div')

#for items in marcas_items:
#    titulo = items.a
#    print(titulo['title'])


marcas_items = soup.find_all('a',id='productList-1',class_='emproduct_right_title emsmoothtext cpGaProductList-1 productList-1')


print(marcas_items)

for item in marcas_items:
    print(item)
# Out:
# []

# %% [markdown]
# <h1 style="color:green">NumPy</h1>
#
# ##### <span style="color:blue"></span>
