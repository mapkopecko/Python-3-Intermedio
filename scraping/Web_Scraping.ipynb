# %% [markdown]
# # Web Scraping con BeautifulSoup

# %% [markdown]
# ## 1. Instalar e importar librerías

# %%
# pip install requests

# %%
# pip install beautifulsoup4

# %%
import requests

from bs4 import BeautifulSoup

# %% [markdown]
# ## 2. Enviar petición HTTP para extraer código fuente de la página web

# %%
pagina_web = requests.get('http://books.toscrape.com/')

travel_page = requests.get('http://books.toscrape.com/catalogue/category/books/travel_2/index.html')


soup = BeautifulSoup(pagina_web.text, 'html.parser')

soup2 = BeautifulSoup(travel_page.text, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    All products | Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:29" name="created"/>
#   <meta content="" name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %% [markdown]
# ## 3. Analizar código fuente resultante

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %% [markdown]
# ## 4. Extrae la información relevante

# %%
images = []

images_items = soup.find_all('img', class_="thumbnail")

for item in images_items:
    image = item['src']
    images.append("http://books.toscrape.com/" + image)

# %%
print(images)
# Out:
# ['http://books.toscrape.com/media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg', 'http://books.toscrape.com/media/cache/26/0c/260c6ae16bce31c8f8c95daddd9f4a1c.jpg', 'http://books.toscrape.com/media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg', 'http://books.toscrape.com/media/cache/32/51/3251cf3a3412f53f339e42cac2134093.jpg', 'http://books.toscrape.com/media/cache/be/a5/bea5697f2534a2f86a3ef27b5a8c12a6.jpg', 'http://books.toscrape.com/media/cache/68/33/68339b4c9bc034267e1da611ab3b34f8.jpg', 'http://books.toscrape.com/media/cache/92/27/92274a95b7c251fea59a2b8a78275ab4.jpg', 'http://books.toscrape.com/media/cache/3d/54/3d54940e57e662c4dd1f3ff00c78cc64.jpg', 'http://books.toscrape.com/media/cache/66/88/66883b91f6804b2323c8369331cb7dd1.jpg', 'http://books.toscrape.com/media/cache/58/46/5846057e28022268153beff6d352b06c.jpg', 'http://books.toscrape.com/media/cache/be/f4/bef44da28c98f905a3ebec0b87be8530.jpg', 'http://books.toscrape.com/media/cache/10/48/1048f63d3b5061cd2f424d20b3f9
# ...

# %%
images
# Out:
# ['http://books.toscrape.com/media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg',
#  'http://books.toscrape.com/media/cache/26/0c/260c6ae16bce31c8f8c95daddd9f4a1c.jpg',
#  'http://books.toscrape.com/media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg',
#  'http://books.toscrape.com/media/cache/32/51/3251cf3a3412f53f339e42cac2134093.jpg',
#  'http://books.toscrape.com/media/cache/be/a5/bea5697f2534a2f86a3ef27b5a8c12a6.jpg',
#  'http://books.toscrape.com/media/cache/68/33/68339b4c9bc034267e1da611ab3b34f8.jpg',
#  'http://books.toscrape.com/media/cache/92/27/92274a95b7c251fea59a2b8a78275ab4.jpg',
#  'http://books.toscrape.com/media/cache/3d/54/3d54940e57e662c4dd1f3ff00c78cc64.jpg',
#  'http://books.toscrape.com/media/cache/66/88/66883b91f6804b2323c8369331cb7dd1.jpg',
#  'http://books.toscrape.com/media/cache/58/46/5846057e28022268153beff6d352b06c.jpg',
#  'http://books.toscrape.com/media/cache/be/f4/bef44da28c98f905a3ebec0b87be8530.jpg',
# ...

# %%
images_items = soup.find_all('div', class_="cs-image")

print(images_items)

for item in images_items:
    print(item)
# Out:
# []

# %%
titulo_item = soup.find('a')

print(titulo_item)
# Out:
# <a href="index.html">Books to Scrape</a>

# %%
titulo_items = soup.find_all('a')

print(titulo_items)
# Out:
# [<a href="index.html">Books to Scrape</a>, <a href="index.html">Home</a>, <a href="catalogue/category/books_1/index.html">
#
#                                 Books
#
#                         </a>, <a href="catalogue/category/books/travel_2/index.html">
#
#                                 Travel
#
#                         </a>, <a href="catalogue/category/books/mystery_3/index.html">
#
#                                 Mystery
#
#                         </a>, <a href="catalogue/category/books/historical-fiction_4/index.html">
#
#                                 Historical Fiction
#
#                         </a>, <a href="catalogue/category/books/sequential-art_5/index.html">
#
#                                 Sequential Art
#
#                         </a>, <a href="catalogue/category/books/classics_6/index.html">
#
#                                 Classics
#
#                         </a>, <a href="catalogue/category/books/philosophy_7/index.html">
#
# ...

# %%
titulos = []
links = []

titulo_items = soup.find_all('h3')

for items in titulo_items:
    titulo = items.a
    titulos.append(titulo['title'])
    links.append(titulo['href'])

# %%
titulos
# Out:
# ['A Light in the Attic',
#  'Tipping the Velvet',
#  'Soumission',
#  'Sharp Objects',
#  'Sapiens: A Brief History of Humankind',
#  'The Requiem Red',
#  'The Dirty Little Secrets of Getting Your Dream Job',
#  'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#  'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#  'The Black Maria',
#  'Starving Hearts (Triangular Trade Trilogy, #1)',
#  "Shakespeare's Sonnets",
#  'Set Me Free',
#  "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)",
#  'Rip it Up and Start Again',
#  'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991',
#  'Olio',
#  'Mesaerion: The Best Science Fiction Stories 1800-1849',
#  'Libertarianism for Beginners',
#  "It's Only the Himalayas"]

# %%
links
# Out:
# ['catalogue/a-light-in-the-attic_1000/index.html',
#  'catalogue/tipping-the-velvet_999/index.html',
#  'catalogue/soumission_998/index.html',
#  'catalogue/sharp-objects_997/index.html',
#  'catalogue/sapiens-a-brief-history-of-humankind_996/index.html',
#  'catalogue/the-requiem-red_995/index.html',
#  'catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html',
#  'catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html',
#  'catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html',
#  'catalogue/the-black-maria_991/index.html',
#  'catalogue/starving-hearts-triangular-trade-trilogy-1_990/index.html',
#  'catalogue/shakespeares-sonnets_989/index.html',
#  'catalogue/set-me-free_988/index.html',
#  'catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html',
#  'catalogue/rip-it-up-and-start-again_986/index.html',
# ...

# %%
precios = []

precio_items = soup.find_all('p', class_="price_color")

for item in precio_items:
    precio = item.text
    precios.append(precio.lstrip("Â£"))

# %%
precios
# Out:
# ['51.77',
#  '53.74',
#  '50.10',
#  '47.82',
#  '54.23',
#  '22.65',
#  '33.34',
#  '17.93',
#  '22.60',
#  '52.15',
#  '13.99',
#  '20.66',
#  '17.46',
#  '52.29',
#  '35.02',
#  '57.25',
#  '23.88',
#  '37.59',
#  '51.33',
#  '45.17']

# %%
existencias = []

existencia_items = soup.find_all('p', class_='instock availability')

for item in existencia_items:
    existencia = item.text.strip()
    existencias.append(existencia)

# %%
existencias
# Out:
# ['In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock']

# %%
ratings = []

rating_items = soup.find_all('p', class_="star-rating")

for item in rating_items:
    rating = item['class'][1]
    ratings.append(rating)

# %%
ratings
# Out:
# ['Three',
#  'One',
#  'One',
#  'Four',
#  'Five',
#  'One',
#  'Four',
#  'Three',
#  'Four',
#  'One',
#  'Two',
#  'Four',
#  'Five',
#  'Five',
#  'Five',
#  'Three',
#  'One',
#  'One',
#  'Two',
#  'Two']

# %%
import pandas as pd

data = {
    'Titulo': titulos,
    'Precio': precios,
    'Rating': ratings,
    'En existencia': existencias,
    'Links': links
}

df = pd.DataFrame(data)

# %%
df
# Out:
#                                                Titulo Precio Rating  \
# 0                                A Light in the Attic  51.77  Three
# 1                                  Tipping the Velvet  53.74    One
# 2                                          Soumission  50.10    One
# 3                                       Sharp Objects  47.82   Four
# 4               Sapiens: A Brief History of Humankind  54.23   Five
# 5                                     The Requiem Red  22.65    One
# 6   The Dirty Little Secrets of Getting Your Dream...  33.34   Four
# 7   The Coming Woman: A Novel Based on the Life of...  17.93  Three
# 8   The Boys in the Boat: Nine Americans and Their...  22.60   Four
# 9                                     The Black Maria  52.15    One
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  13.99    Two
# 11                              Shakespeare's Sonnets  20.66   Four
# 12                                        Set Me Free  17.46   Five
# ...

# %%
titulos = []
links = []

titulo_items = soup.find_all('h3')

for items in titulo_items:
    titulo = items.a
    titulos.append(titulo['title'])
    links.append("http://books.toscrape.com/" + titulo['href'])

# %%
df['Precio'] = df['Precio'].apply(float)

# %%
df['Precio'].mean()
# Out:
# 38.048500000000004

# %%
df['Precio'].median()
# Out:
# 41.38

# %% [markdown]
# ## Paginación

# %%
import requests

from bs4 import BeautifulSoup

# %%
def obtener_contenido_pagina(url):
    response = requests.get(url)
    return response.content

# %%
def analizar_contenido_html(html):
    return BeautifulSoup(html, 'html.parser')

# %%
data = []

def procesar_pagina(soup):
    titulos = []
    links = []
    ratings = []
    existencias = []

    titulo_items = soup.find_all('h3')

    for items in titulo_items:
        titulo = items.a
        titulos.append(titulo['title'])
        links.append(titulo['href'])

    rating_items = soup.find_all('p', class_="star-rating")

    for item in rating_items:
        rating = item['class'][1]
        ratings.append(rating)

    existencia_items = soup.find_all('p', class_='instock availability')

    for item in existencia_items:
        existencia = item.text.strip()
        existencias.append(existencia)

    for i in range(len(titulos)):
        data.append({
            "Título": titulos[i],
            "Rating": ratings[i],
            "Link": links[i],
            "Existencia": existencias[i]
        })

# %%
def manejar_paginacion(url_base, num_paginas):
    for i in range(1, num_paginas + 1):
        url = url_base + '/page-' + str(i) + ".html"  # Actualiza la URL base con el número de página actual
        contenido_pagina = obtener_contenido_pagina(url)
        soup = analizar_contenido_html(contenido_pagina)
        procesar_pagina(soup)

# %%
url_base = 'http://books.toscrape.com/catalogue/category/books_1'  # Reemplaza con tu URL base
num_paginas = 10 #total_pages  # Reemplaza con el número total de páginas

manejar_paginacion(url_base, num_paginas)

# %%
len(data)
# Out:
# 200

# %% [markdown]
# ## Expresiones regulares

# %%
html = requests.get('http://books.toscrape.com/catalogue/category/books_1/page-2.html')
soup = BeautifulSoup(html.text, 'html.parser')

# %%
import re

patron = r'Page (\d+) of (\d+)'

concuerda = re.search(patron, html.text)

if concuerda:
    page_number = int(concuerda.group(1))
    total_pages = int(concuerda.group(2))
    print(page_number, total_pages)
# Out:
# 2 50

# %%
url_base = 'http://books.toscrape.com/catalogue/category/books_1'  # Reemplaza con tu URL base
num_paginas = total_pages  # Reemplaza con el número total de páginas

manejar_paginacion(url_base, num_paginas)

# %%
data
# Out:
# [{'Título': 'A Light in the Attic',
#   'Rating': 'Three',
#   'Link': '../../a-light-in-the-attic_1000/index.html',
#   'Existencia': 'In stock'},
#  {'Título': 'Tipping the Velvet',
#   'Rating': 'One',
#   'Link': '../../tipping-the-velvet_999/index.html',
#   'Existencia': 'In stock'},
#  {'Título': 'Soumission',
#   'Rating': 'One',
#   'Link': '../../soumission_998/index.html',
#   'Existencia': 'In stock'},
#  {'Título': 'Sharp Objects',
#   'Rating': 'Four',
#   'Link': '../../sharp-objects_997/index.html',
#   'Existencia': 'In stock'},
#  {'Título': 'Sapiens: A Brief History of Humankind',
#   'Rating': 'Five',
#   'Link': '../../sapiens-a-brief-history-of-humankind_996/index.html',
#   'Existencia': 'In stock'},
#  {'Título': 'The Requiem Red',
#   'Rating': 'One',
#   'Link': '../../the-requiem-red_995/index.html',
#   'Existencia': 'In stock'},
#  {'Título': 'The Dirty Little Secrets of Getting Your Dream Job',
#   'Rating': 'Four',
# ...

# %%
import re

patron = r'.*+[aeiou]?{n}{n,m}(ab)+^$\d'

# %%
patron = r'\d+'

# %%
patron = r'^\w+'

# %%
patron = r'^[A-Z][a-z]+$'

# %%
patron = r'\b\d{3}-\d{2}-\d{4}\b'

# %%
patron = r'(?i)python'

# %%
import re

texto = "Hola, mi número de teléfono es 123-456-7890. ¿Necesitas contactarme? Llámame. Contacto: 123-456-7897"

patron = r'\d{3}-\d{3}-\d{4}'

resultado_search = re.search(patron, texto)

if resultado_search:
    print("Número de teléfono encontrado:", resultado_search.group())
else:
    print("Número de teléfono no encontrado.")
# Out:
# Número de teléfono encontrado: 123-456-7890

# %%
patron_saludo = r'Hola'

resultado_match = re.match(patron_saludo, texto)
    
if resultado_match:
    print("Saludo encontrado:", resultado_match.group())
else:
    print("Saludo no encontrado.")
# Out:
# Saludo encontrado: Hola

# %%
patron_telefonos = r'\d{3}-\d{3}-\d{4}'
resultado_findall = re.findall(patron_telefonos, texto)

if resultado_findall:
    print("Números de teléfono encontrados:", resultado_findall)
else:
    print("Ningún número de teléfono encontrado.")
# Out:
# Números de teléfono encontrados: ['123-456-7890', '123-456-7897']

# %%
item = soup.find('li', class_="current")

cadena = item.text

limpio = cadena.strip()

num = limpio.lstrip('Page 1 of')

num_paginas = int(num)

print(num_paginas)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\mapko\OneDrive\Desktop\Python 3 Intermedio\scraping\Web_Scraping.ipynb Cell 54 in 9
#       <a href='vscode-notebook-cell:/c%3A/Users/mapko/OneDrive/Desktop/Python%203%20Intermedio/scraping/Web_Scraping.ipynb#Y104sZmlsZQ%3D%3D?line=4'>5</a> limpio = cadena.strip()
#       <a href='vscode-notebook-cell:/c%3A/Users/mapko/OneDrive/Desktop/Python%203%20Intermedio/scraping/Web_Scraping.ipynb#Y104sZmlsZQ%3D%3D?line=6'>7</a> num = limpio.lstrip('Page 1 of')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mapko/OneDrive/Desktop/Python%203%20Intermedio/scraping/Web_Scraping.ipynb#Y104sZmlsZQ%3D%3D?line=8'>9</a> num_paginas = int(num)
#      <a href='vscode-notebook-cell:/c%3A/Users/mapko/OneDrive/Desktop/Python%203%20Intermedio/scraping/Web_Scraping.ipynb#Y104sZmlsZQ%3D%3D?line=10'>11</a> print(num_paginas)
#
# ...

# %%
import pandas as pd

df = pd.DataFrame(data)

# %%
print(df.to_string())
# Out:
#                                                                                                                                                                                                            Título Rating                                                                                                                                                                                                                     Link Existencia
# 0                                                                                                                                                                                            A Light in the Attic  Three                                                                                                                                                                               ../../a-light-in-the-attic_1000/index.html   In stock
# ...

# %% [markdown]
# ## Multimedia

# %%
soup

# %%
imagenes = []

img_items = soup.find_all('img')

print(img_items)

for item in img_items:
    imagenes.append("books.toscrape.com/" + item['src'])

# %%
imagenes

# %% [markdown]
# # Ejercicio Cyberpuerta
#
# 1. Entrar a la página https://www.cyberpuerta.mx/ y buscar una categoría.
#
# 2. Realizar las peticiones HTTP pertinentes para obtener el código fuente de la página.
#
# 3. Analizar la páginas web para identificar los elementos relevantes.
#
# 4. Extraer los datos relevante de las páginas web.
#
# 5. Generar un DataFrame con los datos obtenidos.
#
# 6. Generar una gráfica para visualizar los datos.

# %% [markdown]
# ### Pruebas

# %%
page = requests.get('https://www.cyberpuerta.mx/Promociones/')

soup = BeautifulSoup(page.text, 'html.parser')

print(soup.prettify())

# %%
skus = []

sku_items = soup.find_all('div', class_="emproduct_right_artnum")

for item in sku_items:
    sku = item.text
    skus.append(sku)

print(skus)

# %%
lista_items = soup.find('div', class_="emproduct_right")

print(lista_items.a.attrs)

# %%
lista_items = soup.find('div', class_="emproduct_right")

print(lista_items.a['title'])

# %%
lista_items = soup.find_all('div', class_="emproduct_right")

print(lista_items)

# %%
urls = []

for i in range(1, 10):
    response = requests.get(f'http://books.toscrape.com/catalogue/category/books/young-adult_21/page-{i}.html')

    if response.status_code == 200:
        urls.append(response.url)

# %%
urls

# %%
titulos = []

def extraer_titulos(soup):
    page_items = soup.find_all('h3')

    for item in page_items:
        etiqueta = item.find('a')
        titulo = etiqueta['title']
        titulos.append(titulo)

# %%
precios = []

def extraer_precios(soup):
    page_items = soup.find_all('p', class_="price_color")

    for item in page_items:
        precio = item.text
        precios.append(precio)

# %%
ratings = []

def extraer_ratings(soup):
    page_items = soup.find_all('p', class_="star-rating")

    for item in page_items:
        ratings.append(item['class'][1])

# %%
existencias = []

def extraer_existencias(soup):
    page_items = soup.find_all('p', class_="instock availability")

    for item in page_items:
        existencia = item.text
        existencias.append(existencia)

# %%
def obtener_contenido_titulos(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')
    extraer_titulos(soup)
    extraer_precios(soup)
    extraer_ratings(soup)
    extraer_existencias(soup)

# %%
for url in urls:
    obtener_contenido_titulos(url)

# %%
import pandas as pd

data = {'Titulo': titulos, 'Precio': precios, 'Rating': ratings, 'En existencia': existencias}

df = pd.DataFrame(data)

# %%
df
