# %% [markdown]
# <h1 style="color:red">Proyecto de Web Scraping con BeautifulSoup</h1>

# %% [markdown]
# #### <span style="color:yellow">1.- Instalar e Importar librerías para realizar el proceso de Web Scraping</span>

# %% [markdown]
# #### <span style="color:#800080">Instamos la librería pip</span>

# %%
# pip install pip

# %% [markdown]
# #### <span style="color:#800080">Instalamos la libreria requests la cual nos ayuda a comunicarnos con un servidor para realizar la petición http</span>

# %%
# pip install requests

# %% [markdown]
# #### <span style="color:#800080">Instalamos la libreria beautifulsoup4 para poder analizar el código fuente de la pagina http</span>

# %%
# pip install beautifulsoup4

# %% [markdown]
# #### <span style="color:#800080">Una vez instalada esta libreria. Procedemos a Importar directamente estas librerias a nustro archivo</span>
#
# #### <span style="color:#800080">Importamos requests</span>
#
# #### <span style="color:#800080">Importamos beautifullsoup4</span>
#
# #### <span style="color:#800080">Esta tipo de librerias se llama con "from" por que tienen módulos o paquetes con tareas definidas. En este caso tiene una clase con el mismo nombre y las que nos va ayudar a realizar ésta extración de datos.</span>

# %% [markdown]
# ## <span style="color:yellow">BeautifulSoup</span>
# #### <span style="color:yellow">Biblioteca de **Python** utilizada para **analizar y extraer datos** de un archivo **HTML y XML**.</span>
#
# #### <span style="color:yellow">Proporciona una forma fácil y legible de manejar por el **código fuente HTML** y extraer información relevante.</span>
#
# #### <span style="color:yellow">Algunas características importantes BeautifulSoup son: .</span>
#
# 1.- Analisis y navegación.
#
# 2.- Seleccion de elementos.
#
# 3.- Extración de Datos.
#
# 4.- Limpieza y Formateo.
#
# 5.- Integración.

# %% [markdown]
# ## <span style="color:yellow">Análisis y navegación del código HTML</span>
# #### <span style="color:yellow">BS4 analiza el código fuente HTML y lo convierte en una estructura de árbol de objetos Python.</span>
#
# #### <span style="color:yellow">Esto permite navegar y exprorar la estructura del HTML de manera intuitiva.</span>
#
#
# 1.- find().
#
# 2.- find_all().

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# #### <span style="color:yellow">2.- Enviar la petición HTTP para extraer el código fuente de la página WEB (página de prueba)</span>

# %% [markdown]
# #### <span style="color:yellow">La petición a la HTTP se envia por medio del método (requests) y se manda a desplegar en pantalla. y nos responde 200 nuestra petición fue aceptada de lo contrario mandará 404 que no fue aceptada.</span>

# %%
pagina_web = requests.get('https://books.toscrape.com/aassdff')

print(pagina_web) #<Response [404]>

pagina_web = requests.get('https://www.cyberpuerta.mx/')

print(pagina_web) #<Response [200]>
# Out:
# <Response [404]>
# <Response [200]>

# %% [markdown]
# #### <span style="color:yellow">Una vez aceptada nuestra petición. Vamos a crear un objeto (soup) el cual toma como objeto (BeautifulSoup) y le mandamos nuestro response con lo que alla llegado de nuestra respuesta pagina web y accedemos a nuestro attributo texto. Y definimos un analizador o un parse en este caso.</span>

# %% [markdown]
# #### <span style="color:yellow">Una vez obtenido nuestra página web y nuestro objeto (soup) ya accedimos al código fuente de la página. Y la desplegamos con print().</span>

# %%
pagina_web = requests.get('https://www.cyberpuerta.mx/')

soup = BeautifulSoup(pagina_web.text, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html lang="es">
#  <head>
#   <link href="https://www.cyberpuerta.mx/out/generated/cms-pages.css?1593624763" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/emslider2.css?1690486847" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headerlogin.css?1690486847" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headernotice.css?1690486847" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headercompare.css?1690486847" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headerhelp.css?1690486847" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headerminibasket.css?1690486847" rel="stylesheet" type="text/css"/>
#   <link data-cp-orig="cdn.Swiper.css" href="https://cdnjs.cloudflare.com/ajax/libs/Swiper/4.3.5/css/swiper.min.css" rel="stylesheet" type="text/css"/>
#   <link data-cp-orig="cp.app.legacy.css" href="https://www.cyberpuerta.mx/out/dist/cp.app.legacy.c6cd68cd7a9e818b946e.g.css" rel="stylesheet" type="text/css"/>
#   <link data-cp-orig="cp.app.foundation.css" href="https://www.cyberpuerta.mx/out/dist/cp.app.foundation.e29b346a69794f0187d9.g.css" rel="stylesheet" type="text/css"/>
#   <link data-cp-orig="cp.app.css" href="https://www.cyberpuerta.mx/out/dist/cp.app.2597a5763d93a7d4fff0.g.css" rel="stylesheet" type="text/css"/>
#   <link data-cp-orig="vendors~cp.app.css" href="https://www.cyberpuerta.mx/out/dist/vendors~cp.app.f79cffac28db61b5a671.g.css" rel="stylesheet" type="text/css"/>
#   <link data-cp-orig="cdn.material-icons.css" href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet" type="text/css"/>
#   <link data-cp-orig="cdn.open-sans.css" href="https://fonts.googleapis.com/css?family=Open+Sans:400,700&amp;display=swap" rel="stylesheet" type="text/css"/>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#         let loginCookieMatch = document.cookie.match(/\bcpcautologin=([^;]+)/);
#         let loginCookie = loginCookieMatch ? loginCookieMatch[1] : null;
#
#         // gtm Cookie to be sent to get prediction from Google Recommendations AI
#         let gtmCookie = null;
#         function getCookie(cName) {
#           const name = cName + "=";
#           const cDecoded = decodeURIComponent(document.cookie); //to be careful
#           const cArr = cDecoded.split('; ');
#           let res;
#           cArr.forEach(val => {
#             if (val.indexOf(name) === 0) res = val.substring(name.length);
#           })
#           return res
#         }
#
#         window.onload = function() {
#             gtmCookie = getCookie("_ga");
#         };
#
#         // If in the query string is utm_campaign, set it in a cookie
#
#         // section to define variable to send information to another project "CP Cyberpuerta production"
#         var _gre = _gre || [];
#         // Credentials for project.
#         _gre.push(['apiKey', 'AIzaSyAOwVGpimHdB81KmBDgnKta0wxX9RqszKE']);
#         _gre.push(['projectId', 'cyberpuerta-144818']);
#         _gre.push(['locationId', 'global']);
#         _gre.push(['catalogId', 'default_catalog']);
#
#         let justOne = true;
#
#         window.onload = function() {
#             if ( justOne ) {
#                 var gre = document.createElement('script'); gre.type = 'text/javascript'; gre.async = true;
#                 gre.src = 'https://www.gstatic.com/retail/v2_event.js';
#                 var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(gre, s);
#                 justOne = false;
#             }
#         };
#
#                     dataLayer.push(
#                 {"shop_cl":"start"}
#             );
#                     dataLayer.push(
#                 {"ab1047_pixel":0}
#             );
#                     dataLayer.push(
#                 {"sess_tk":"1C0281AB"}
#             );
#                     dataLayer.push(
#                 {"internal_user":0}
#             );
#                     dataLayer.push(
#                 {"rai_active":true}
#             );
#                     dataLayer.push(
#                 {"new_customer":false}
#             );
#
#         dataLayer.push({
#             api_version: 'v0.1'
#         })
#
#
#                                                     dataLayer.push({'Referer':'(direct)'});
#                 dataLayer.push({'firstaccess':'y'});
#
#                             // If is a search page or is a category/manufacturer page but comes from a search
#                             // ALL-811 send url path on 404 pages
#                 let url_path = window.location.pathname;
#                 // remove slash at the end
#                 url_path = url_path.replace(/\/$/g, '')
#
#                                                         url_path = '/start';
#
#                 dataLayer.push({'pageview': url_path});
#
#
#
#
#
#                             dataLayer.push({
#                 'ecomm_prodid': '',
#                 'ecomm_totalvalue': 0,
#                 'nl': 'n'
#             });
#             //Google Recommendations AI home-page-view
#             const homePageView = {
#                 'cloud_retail': {
#                     'eventType': 'home-page-view',
#                 }
#             };
#
#             homePageView.cloud_retail.visitorId = gtmCookie ? gtmCookie : loginCookie;
#             dataLayer.push(homePageView);
#
#             homePageView.cloud_retail.visitorId = getCookie("_ga");
#
#             if(!homePageView.cloud_retail.visitorId) {
#                 homePageView.cloud_retail.visitorId = "GA1.2.1758256664.1659050323";
#             }
#
#             dataLayer.push({
#                 'event': 'track_content_group',
#                 'content_group': 'Home'
#             });
#             _gre.push(['logEvent', homePageView.cloud_retail]);
#
#             /** GA4Event */
#
#             /**
#             * GA4Event
#             * DailyOffers Items List
#             */
#             dataLayer.push({
#                 'event': 'view_item_list',
#                 'ecommerce': {
#                     'items': [
#                                                     {
#                                 'item_name': 'Tarjeta de Video MSI NVIDIA GeForce RTX 3060 VENTUS 2X 12G OC, 12GB 192-bit GDDR6, PCI Express 4.0',
#                                 'item_id': 'GEFORCE RTX 3060 VENTUS 2X 12G OC',
#                                 'price': 5949,
#                                                                 'item_brand': 'MSI',
#                                                                                                                                                                                                                     'item_category': 'Cómputo (Hardware)',
#                                                                                                                     'item_category2': 'Componentes',
#                                                                                                                     'item_category3': 'Tarjetas de Video',
#                                                                                                                                             'item_list_name': '¡Destacados del día!',
#                                 'item_variant': 'NA',
#                                 'index': 1,
#                             },
#                                                     {
#                                 'item_name': 'Corsair Audífonos Gamer HS65 SURROUND 7.1, Alámbrico, 1.8 Metros, 3.5mm/USB, Negro',
#                                 'item_id': 'CA-9011270-NA',
#                                 'price': 869,
#                                                                 'item_brand': 'CORSAIR',
#                                                                                                                                                                                                                     'item_category': 'Audio y Video',
#                                                                                                                     'item_category2': 'Audio y MP3',
#                                                                                                                     'item_category3': 'Audífonos',
#                                                                                                                                             'item_list_name': '¡Destacados del día!',
#                                 'item_variant': 'NA',
#                                 'index': 2,
#                             },
#                                                     {
#                                 'item_name': 'Tarjeta de Video Gigabyte AMD Radeon RX 6600 Eagle 8G, 8GB 128-bit GDDR6, PCI Express x8 4.0 ',
#                                 'item_id': 'GV-R66EAGLE-8GD',
#                                 'price': 4209,
#                                                                 'item_brand': 'GIGABYTE',
#                                                                                                                                                                                                                     'item_category': 'Cómputo (Hardware)',
#                                                                                                                     'item_category2': 'Componentes',
#                                                                                                                     'item_category3': 'Tarjetas de Video',
#                                                                                                                                             'item_list_name': '¡Destacados del día!',
#                                 'item_variant': 'NA',
#                                 'index': 3,
#                             },
#                                                     {
#                                 'item_name': 'Jabra Audífonos con Micrófono Evolve 20 UC Stereo, Alámbrico, USB, Negro',
#                                 'item_id': '4999-829-209',
#                                 'price': 629,
#                                                                 'item_brand': 'JABRA',
#                                                                                                                                                                                                                     'item_category': 'Telecomunicación',
#                                                                                                                     'item_category2': 'Audio para Telefonía',
#                                                                                                                     'item_category3': 'Auriculares y Monoaurales',
#                                                                                                                                             'item_list_name': '¡Destacados del día!',
#                                 'item_variant': 'NA',
#                                 'index': 4,
#                             },
#                                                     {
#                                 'item_name': 'Gabinete XPG INVADER con Ventana, Midi-Tower, ATX/Micro-ATX/Mini-ITX, USB 3.2, sin Fuente, Blanco',
#                                 'item_id': 'INVADER-WHCWW',
#                                 'price': 919,
#                                                                 'item_brand': 'XPG',
#                                                                                                                                                                                                                     'item_category': 'Cómputo (Hardware)',
#                                                                                                                     'item_category2': 'Componentes',
#                                                                                                                     'item_category3': 'Gabinetes',
#                                                                                                                                             'item_list_name': '¡Destacados del día!',
#                                 'item_variant': 'NA',
#                                 'index': 5,
#                             },
#                                                     {
#                                 'item_name': 'Kit Gamer 4 en 1 Corsair Teclado K55 RGB Pro + Mouse Harpoon RGB Pro + Audífonos HS50 Pro + Mousepad MM100, Alámbrico, USB, Negro (Español)',
#                                 'item_id': 'CH-9226A65-SP',
#                                 'price': 1239,
#                                                                 'item_brand': 'CORSAIR',
#                                                                                                                                                                                                                     'item_category': 'Cómputo (Hardware)',
#                                                                                                                     'item_category2': 'Dispositivos de Entrada',
#                                                                                                                     'item_category3': 'Kits de Teclado y Mouse',
#                                                                                                                                             'item_list_name': '¡Destacados del día!',
#                                 'item_variant': 'NA',
#                                 'index': 6,
#                             },
#                                                     {
#                                 'item_name': 'Monitor ASUS VA279HAE LED VA 27\", Full HD, HDMI, Negro',
#                                 'item_id': 'VA279HAE',
#                                 'price': 2549,
#                                                                 'item_brand': 'ASUS',
#                                                                                                                                                                                                                     'item_category': 'Cómputo (Hardware)',
#                                                                                                                     'item_category2': 'Monitores',
#                                                                                                                     'item_category3': 'Monitores',
#                                                                                                                                             'item_list_name': '¡Destacados del día!',
#                                 'item_variant': 'NA',
#                                 'index': 7,
#                             },
#                                                     {
#                                 'item_name': 'Monitor Stylos STPMOT3B LED 19\", HD, HDMI, Negro',
#                                 'item_id': 'STPMOT3B',
#                                 'price': 1069,
#                                                                 'item_brand': 'STYLOS',
#                                                                                                                                                                                                                     'item_category': 'Cómputo (Hardware)',
#                                                                                                                     'item_category2': 'Monitores',
#                                                                                                                     'item_category3': 'Monitores',
#                                                                                                                                             'item_list_name': '¡Destacados del día!',
#                                 'item_variant': 'NA',
#                                 'index': 8,
#                             },
#                                                     {
#                                 'item_name': 'Monitor AOC 22B2HN LED 21.5\", Full HD, 75Hz, HDMI, Negro',
#                                 'item_id': '22B2HN',
#                                 'price': 1469,
#                                                                 'item_brand': 'AOC',
#                                                                                                                                                                                                                     'item_category': 'Cómputo (Hardware)',
#                                                                                                                     'item_category2': 'Monitores',
#                                                                                                                     'item_category3': 'Monitores',
#                                                                                                                                             'item_list_name': '¡Destacados del día!',
#                                 'item_variant': 'NA',
#                                 'index': 9,
#                             },
#                                                     {
#                                 'item_name': 'Fuente de Poder XPG CORE REACTOR 80 PLUS Gold, 24-pin ATX, 120mm, 750W',
#                                 'item_id': 'COREREACTOR750G-BKCUS',
#                                 'price': 1789,
#                                                                 'item_brand': 'XPG',
#                                                                                                                                                                                                                     'item_category': 'Cómputo (Hardware)',
#                                                                                                                     'item_category2': 'Componentes',
#                                                                                                                     'item_category3': 'Fuentes de Poder para PC\'s',
#                                                                                                                                             'item_list_name': '¡Destacados del día!',
#                                 'item_variant': 'NA',
#                                 'index': 10,
#                             },
#                                                     {
#                                 'item_name': 'Monitor Gamer Curvo Gigabyte G27FC LED 27\", Full HD, FreeSync, 165Hz, HDMI, Bocinas Integradas (2 x 4W), Negro',
#                                 'item_id': 'G27FC',
#                                 'price': 3809,
#                                                                 'item_brand': 'GIGABYTE',
#                                                                                                                                                                                                                     'item_category': 'Cómputo (Hardware)',
#                                                                                                                     'item_category2': 'Monitores',
#                                                                                                                     'item_category3': 'Monitores',
#                                                                                                                                             'item_list_name': '¡Destacados del día!',
#                                 'item_variant': 'NA',
#                                 'index': 11,
#                             },
#                                                     {
#                                 'item_name': 'Disco Duro para Videovigilancia Western Digital WD Purple Surveillance 3.5\", 2TB, SATA, 6 Gbit/s, 256MB Caché',
#                                 'item_id': 'WD22PURZ',
#                                 'price': 969,
#                                                                 'item_brand': 'WESTERN DIGITAL',
#                                                                                                                                                                                                                     'item_category': 'Cómputo (Hardware)',
#                                                                                                                     'item_category2': 'Discos Duros - SSD - NAS',
#                                                                                                                     'item_category3': 'Discos Duros para Videovigilancia',
#                                                                                                                                             'item_list_name': '¡Destacados del día!',
#                                 'item_variant': 'NA',
#                                 'index': 12,
#                             },
#                                             ]
#                 }
#             });
#
#
#                 if (window.cpGa && window.cpGa.ecProdImp && window.cpGa.ecProdImp.length > 0) {
#             dataLayer.push({
#                 'ecommerce': {
#                     'impressions': window.cpGa.ecProdImp
#                 }
#             });
#         }
#   </script>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){
#             w[l]=w[l]||[];w[l].push({
#                 'gtm.start': new Date().getTime(),'event':'gtm.js'
#             });
#             var f=d.getElementsByTagName(s)[0],
#                 j=d.createElement(s),
#                 dl=l!='dataLayer'?'&l='+l:'';
#             j.async=true;
#             j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window, document, 'script', 'dataLayer', 'GTM-TZF4FD');
#
#
#
#
#                                 let addToCart=null;
#
#
#
#
#
#         //criteo pixel $oxcmp_utils->emcriteo_active()
#                     dataLayer.push({
#                 'criteo_data': [{"event":"setAccount","account":6218},{"event":"setSiteType","type":"d"},{"event":"setHashedEmail","email":""},{"event":"viewHome"}]
#             })
#   </script>
#   <!-- End Google Tag Manager -->
#   <meta content="https://www.cyberpuerta.mx/out/cyberpuertaV5/img/logo2.png" property="og:image"/>
#   <!--sse-->
#   <!-- Customizing Knowledge Graph: page-specific structured data -->
#   <script type="application/ld+json">
#    {"@context":"http:\/\/schema.org","@type":"Organization","name":"Cyberpuerta, S.A. de C.V.","url":"https:\/\/www.cyberpuerta.mx\/","logo":"https:\/\/www.cyberpuerta.mx\/out\/cyberpuertaV5\/img\/logo2.png","contactPoint":[{"@type":"ContactPoint","telephone":"+52-33 4737 1360","contactType":"customer service"},{"@type":"ContactPoint","telephone":"+52-55 4737 1360","contactType":"customer service"},{"@type":"ContactPoint","telephone":"+52-81 4737 1360","contactType":"customer service"}],"sameAs":["http:\/\/www.facebook.com\/Cyberpuerta","http:\/\/twitter.com\/CyberPuerta"]}
#   </script>
#   <script type="application/ld+json">
#    {"@context":"http:\/\/schema.org","@type":"WebSite","url":"https:\/\/www.cyberpuerta.mx\/","potentialAction":{"@type":"SearchAction","target":"https:\/\/www.cyberpuerta.mx\/index.php?cl=search&searchparam={search_term_string}","query-input":"required name=search_term_string"}}
#   </script>
#   <!--/sse-->
#   <meta content="width=device-width,initial-scale=1.0" name="viewport"/>
#   <title>
#    Cyberpuerta.mx: Hardware, Computadoras, Laptops &amp; Más
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"4879248977",applicationID:"66344412"};;/*! For license information please see nr-loader-rum-1.236.0.min.js.LICENSE.txt */
# (()=>{"use strict";var e,t,n={5763:(e,t,n)=>{n.d(t,{P_:()=>f,Mt:()=>p,C5:()=>s,DL:()=>m,OP:()=>_,lF:()=>E,Yu:()=>y,Dg:()=>g,CX:()=>c,GE:()=>b,sU:()=>j});var r=n(8632),i=n(9567);const o={beacon:r.ce.beacon,errorBeacon:r.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},a={};function s(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!a[e])throw new Error("Info for ".concat(e," was never set"));return a[e]}function c(e,t){if(!e)throw new Error("All info objects require an agent identifier!");a[e]=(0,i.D)(t,o),(0,r.Qy)(e,a[e],"info")}var d=n(7056);const u=()=>{const e={blockSelector:"[data-nr-block]",maskInputOptions:{password:!0}};return{allow_bfcache:!0,privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,enabled:!0,harvestTimeSeconds:10},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},session:{domain:void 0,expiresMs:d.oD,inactiveMs:d.Hb},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10},metrics:{enabled:!0},page_action:{enabled:!0,harvestTimeSeconds:30},page_view_event:{enabled:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30,long_task:!1},session_trace:{enabled:!0,harvestTimeSeconds:10},harvest:{tooManyRequestsDelay:60},session_replay:{enabled:!1,harvestTimeSeconds:60,sampleRate:.1,errorSampleRate:.1,maskTextSelector:"*",maskAllInputs:!0,get blockClass(){return"nr-block"},get ignoreClass(){return"nr-ignore"},get maskTextClass(){return"nr-mask"},get blockSelector(){return e.blockSelector},set blockSelector(t){e.blockSelector+=",".concat(t)},get maskInputOptions(){return e.maskInputOptions},set maskInputOptions(t){e.maskInputOptions={...t,password:!0}}},spa:{enabled:!0,harvestTimeSeconds:10}}},l={};function f(e){if(!e)throw new Error("All configuration objects require an agent identifier!");if(!l[e])throw new Error("Configuration for ".concat(e," was never set"));return l[e]}function g(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");l[e]=(0,i.D)(t,u()),(0,r.Qy)(e,l[e],"config")}function p(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");var n=f(e);if(n){for(var r=t.split("."),i=0;i<r.length-1;i++)if("object"!=typeof(n=n[r[i]]))return;n=n[r[r.length-1]]}return n}const h={accountID:void 0,trustKey:void 0,agentID:void 0,licenseKey:void 0,applicationID:void 0,xpid:void 0},v={};function m(e){if(!e)throw new Error("All loader-config objects require an agent identifier!");if(!v[e])throw new Error("LoaderConfig for ".concat(e," was never set"));return v[e]}function b(e,t){if(!e)throw new Error("All loader-config objects require an agent identifier!");v[e]=(0,i.D)(t,h),(0,r.Qy)(e,v[e],"loader_config")}const y=(0,r.mF)().o;var w=n(385),A=n(6818);const x={buildEnv:A.Re,bytesSent:{},queryBytesSent:{},customTransaction:void 0,disabled:!1,distMethod:A.gF,isolatedBacklog:!1,loaderType:void 0,maxBytes:3e4,offset:Math.floor(w._A?.performance?.timeOrigin||w._A?.performance?.timing?.navigationStart||Date.now()),onerror:void 0,origin:""+w._A.location,ptid:void 0,releaseIds:{},session:void 0,xhrWrappable:"function"==typeof w._A.XMLHttpRequest?.prototype?.addEventListener,version:A.q4},D={};function _(e){if(!e)throw new Error("All runtime objects require an agent identifier!");if(!D[e])throw new Error("Runtime for ".concat(e," was never set"));return D[e]}function j(e,t){if(!e)throw new Error("All runtime objects require an agent identifier!");D[e]=(0,i.D)(t,x),(0,r.Qy)(e,D[e],"runtime")}function E(e){return function(e){try{const t=s(e);return!!t.licenseKey&&!!t.errorBeacon&&!!t.applicationID}catch(e){return!1}}(e)}},9567:(e,t,n)=>{n.d(t,{D:()=>i});var r=n(50);function i(e,t){try{if(!e||"object"!=typeo ...
#   </script>
#   <meta content="Venta en línea de Hardware, Computadoras, Laptops, Impresoras, Monitores y más.
# ✓Precios accesibles ✓Excelente servicio
# ✓40,000 productos ✓15 años en el mercado ✓500,000+ clientes" name="description"/>
#   <link href="https://www.cyberpuerta.mx/" rel="canonical"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/img/favicon.ico" rel="shortcut icon"/>
#   <script id="cp-env-data" type="application/json">
#    {"cl":"start","isMobile":false,"isCpx":false,"enableCpNotify":false,"shopUrl":"https:\/\/www.cyberpuerta.mx","enableBanners":1690524000,"bannersFindUrl":"https:\/\/us-central1-cyberpuerta-144818.cloudfunctions.net\/cp-banner-find","bannersExpires":1690524054,"bannerPlaces":["side-left","side-right","cpx-home-main","cpx-home-middle-1","cpx-home-middle-2","cpx-home-middle-3","page-top","home-main","home-top-left","home-top-middle","home-top-right","home-bottom","side-left","side-right","page-top"],"bannerContext":[],"baseApiData":"*,*,4f1f198301cd6","shopPrefix":"cp","env":"prod","restrictionGroup":"1","restrictionGroupName":"Cyberpuerta","sessionToken":"","sessionId":null,"apiVersion":"v0.1","etaCalculatorUri":"https:\/\/cp-eta-calculator-e346qjngfq-uc.a.run.app","etaCalculatorExpires":1690285903,"additional":null,"noSpa":false,"showVat":true,"rai":true,"fid":{"enabled":true,"gsi_clientId":"1044917490556-kg2simrb5fm8ml0s0uubmgeri9rrfhf1.apps.googleusercontent.com","gsi_clientId_android":"1044917490556-9kvrnb85iao90rr8ejf6l4ksd5idut33.apps.googleusercontent.com","gsi_clientId_ios":"1044917490556-nqt66sdvhcel94loopng83jvjle8g4va.apps.googleusercontent.com","apple_clientId":"mx.cyberpuerta","autoLink":false,"autoRegister":true,"canAddPasswordAgain":true,"requirePasswordToLink":false},"cpAdditionalTaxInfo":true,"catalogExpires":"20230725131258"}
#   </script>
#   <script id="cp-layout-view-data" type="application/json">
#    {"initialCategories":[{"id":"99748977a0a9f40e2.09126772","title":"C\u00f3mputo (Hardware)","link":"https://www.cyberpuerta.mx/Computo-Hardware/","image":"cp-menu-icon1","parentId":"","subCategories":[],"path":[],"hasSubCategories":true},{"id":"07a49b1b2f27967a1.24876408","title":"Impresi\u00f3n y Copiado","link":"https://www.cyberpuerta.mx/Impresion-y-Copiado/","image":"cp-menu-icon2","parentId":"","subCategories":[],"path":[],"hasSubCategories":true},{"id":"4fe38c01729fc","title":"Computadoras","link":"https://www.cyberpuerta.mx/Computadoras/","image":"cp-menu-icon6","parentId":"","subCategories":[],"path":[],"hasSubCategories":true},{"id":"4fe353e55a8d4","title":"Audio y Video","link":"https://www.cyberpuerta.mx/Audio-y-Video/","image":"cp-menu-icon4","parentId":"","subCategories":[],"path":[],"hasSubCategories":true},{"id":"5e8f92ef7a3a3","title":"Home Office","link":"https://www.cyberpuerta.mx/Home-Office/","image":"cp-menu-icon9","parentId":"","subCategories":[],"path":[],"hasSubCategories":true}],"moreCategoriesUrl":"https://www.cyberpuerta.mx/out/generated/main-menu/6-oxrootid-1689996556.json","menuUrl":"https://www.cyberpuerta.mx/out/generated/main-menu/main-1689996524.json","basket":{"empty":true,"articles":[],"linkNextStep":null,"numberOfItems":null,"savedItems":[],"numberOfSavedArticles":null,"linkToOffers":null,"saldoData":null,"messagesValidation":null,"errors":null,"forceOpen":null,"msiData":null,"summary":null,"paymentMethods":[],"CheckedPaymentId":""},"beforeCategories":[{"title":"Inicio","icon":"cp-menu-home-image","href":"https://www.cyberpuerta.mx/","template":""},{"title":"Mi cuenta","icon":"cp-menu-icon5","href":"","template":"cp-ko-user-menu"}],"afterCategories":[{"title":"Otras\u003Cbr\u003Ecategor\u00edas","icon":"cp-menu-icon7","href":"","template":"cp-ko-category-menu2"},{"title":"M\u00e1s\u003Cbr\u003Einformaci\u00f3n","icon":"cp-menu-icon3","href":"","template":"cp-ko-moreinfo-menu"}],"simpleHeader":false,"noHeader":false,"accountUrls":[{"url":"https://www.cyberpuerta.mx/mi-cuenta/","lang":"Mi cuenta"},{"url":"https://www.cyberpuerta.mx/historial-de-pedidos/","lang":"Historial de pedidos"},{"url":"https://www.cyberpuerta.mx/mis-direcciones/","lang":"Datos de env\u00edo, pago y facturaci\u00f3n"},{"url":"https://www.cyberpuerta.mx/mis-favoritos/","lang":"Mis favoritos"},{"url":"https://www.cyberpuerta.mx/mis-opiniones/","lang":"Mis opiniones"},{"url":"https://www.cyberpuerta.mx/mis-preguntas/","lang":"Mis preguntas"},{"url":"https://www.cyberpuerta.mx/mis-respuestas/","lang":"Mis respuestas"},{"url":"https://www.cyberpuerta.mx/mi-contrasena/","lang":"Configuraci\u00f3n de cuenta"},{"url":"https://www.cyberpuerta.mx/preferencias-de-correo/","lang":"Suscripciones"},{"url":"js-dynamic","lang":""},{"url":"#user-form=logout","lang":"Salir de cuenta","class":"button primary hollow expanded"}],"loginOptions":{"activeClass":"start","navParams":"\u003Cinput type=\"hidden\" name=\"actcontrol\" value=\"start\" /\u003E\n","action":"https://www.cyberpuerta.mx/index.php?","errors":[],"sizeOptions":[],"loginLink":"https://www.cyberpuerta.mx/web/account/login","logoutLink":"https://www.cyberpuerta.mx/web/account/logout","createAccountLink":"https://www.cyberpuerta.mx/crear-cuenta/","forgotPasswordLink":"https://www.cyberpuerta.mx/olvide-mi-contrasena/"},"cmsUrls":[],"basketUrl":"https://www.cyberpuerta.mx/carrito-de-compras/","homeLink":"https://www.cyberpuerta.mx/","actionLink":"https://www.cyberpuerta.mx/","searchParam":"","fidLink":null}
#   </script>
#   <script id="cp-view-data" type="application/json">
#    {"dailyOffers":[],"brands":[{"id":"2ae6fda0ccd034cab3bee65bbfd1904d","title":"ACER","link":"https://www.cyberpuerta.mx/Por-Marca/ACER/","image":"https://cdn.cyberpuerta.mx/storage/brands/acernewlogo.jpg","parentId":null,"subCategories":null,"path":null,"hasSubCategories":false},{"id":"20e1b3688e94df3f62d35b44df5f7954","title":"SAMSUNG","link":"https://www.cyberpuerta.mx/Por-Marca/SAMSUNG/","image":"https://cdn.cyberpuerta.mx/storage/brands/samsung.png","parentId":null,"subCategories":null,"path":null,"hasSubCategories":false},{"id":"146ae729839fab95f5876d8aeb381608","title":"EPSON","link":"https://www.cyberpuerta.mx/Por-Marca/EPSON/","image":"https://cdn.cyberpuerta.mx/storage/brands/epson.png","parentId":null,"subCategories":null,"path":null,"hasSubCategories":false},{"id":"e6fc8ce107f2bdf0955f021a391514ce","title":"HP","link":"https://www.cyberpuerta.mx/Por-Marca/HP/","image":"https://cdn.cyberpuerta.mx/storage/brands/e6fc8ce107f2bdf0955f021a391514ce_hp.png","parentId":null,"subCategories":null,"path":null,"hasSubCategories":false},{"id":"8726e36e9d6d53646390d495b4ce9dc1","title":"MSI","link":"https://www.cyberpuerta.mx/Por-Marca/MSI/","image":"https://cdn.cyberpuerta.mx/storage/brands/8726e36e9d6d53646390d495b4ce9dc1_msi.png","parentId":null,"subCategories":null,"path":null,"hasSubCategories":false},{"id":"40183069c6b7a5144ac7e7fdffb4f13b","title":"KINGSTON","link":"https://www.cyberpuerta.mx/Por-Marca/KINGSTON/","image":"https://cdn.cyberpuerta.mx/storage/brands/kingstonlogofcc32d090fseeklogo.com.png","parentId":null,"subCategories":null,"path":null,"hasSubCategories":false},{"id":"1ec9de0c06c0d089bff3d3f70f237ae1","title":"XTREME PC GAMING","link":"https://www.cyberpuerta.mx/Por-Marca/XTREME-PC-GAMING/","image":"https://cdn.cyberpuerta.mx/storage/brands/5da100a24aafc_logoxtreme.png","parentId":null,"subCategories":null,"path":null,"hasSubCategories":false},{"id":"67243b4384dbf4c379f1b7ea112742bd","title":"WESTERN DIGITAL","link":"https://www.cyberpuerta.mx/Por-Marca/WESTERN-DIGITAL/","image":"https://cdn.cyberpuerta.mx/storage/brands/westernDigital2022.png","parentId":null,"subCategories":null,"path":null,"hasSubCategories":false},{"id":"f9232ef48e81c8fa4eb9a0cafbe1f13d","title":"INTEL","link":"https://www.cyberpuerta.mx/Por-Marca/INTEL/","image":"https://cdn.cyberpuerta.mx/storage/brands/intellogo.png","parentId":null,"subCategories":null,"path":null,"hasSubCategories":false},{"id":"c230b14bfa6e4bfdbf75b5432eb55d8c","title":"CORSAIR","link":"https://www.cyberpuerta.mx/Por-Marca/CORSAIR/","image":"https://cdn.cyberpuerta.mx/storage/brands/CORSAIRLogo2020_horiz_K.png","parentId":null,"subCategories":null,"path":null,"hasSubCategories":false},{"id":"f976fb2ecf4847ecb507697a8d02ed3d","title":"ADATA","link":"https://www.cyberpuerta.mx/Por-Marca/ADATA/","image":"https://cdn.cyberpuerta.mx/storage/brands/f976fb2ecf4847ecb507697a8d02ed3d_ADATA.png","parentId":null,"subCategories":null,"path":null,"hasSubCategories":false},{"id":"48af4341f745163f945fa838eeabb062","title":"AMD","link":"https://www.cyberpuerta.mx/Por-Marca/AMD/","image":"https://cdn.cyberpuerta.mx/storage/brands/48af4341f745163f945fa838eeabb062_amdlogo.png","parentId":null,"subCategories":null,"path":null,"hasSubCategories":false},{"id":"685903ef83f7a7c8a165f77eed160d9e","title":"LENOVO","link":"https://www.cyberpuerta.mx/Por-Marca/LENOVO/","image":"https://cdn.cyberpuerta.mx/storage/brands/685903ef83f7a7c8a165f77eed160d9e_lenovo.png","parentId":null,"subCategories":null,"path":null,"hasSubCategories":false},{"id":"1ec2744b3a948fae2382b1ec7bdb962b","title":"GIGABYTE","link":"https://www.cyberpuerta.mx/Por-Marca/GIGABYTE/","image":"https://cdn.cyberpuerta.mx/storage/brands/1ec2744b3a948fae2382b1ec7bdb962b_gigabyte.png","parentId":null,"subCategories":null,"path":null,"hasSubCategories":false},{"id":"4c462d6dd59d782386bb1cdad0060c70","title":"APPLE","link":"https://www.cyberpuerta.mx/Por-Marca/APPLE/","image":"https://cdn.cyberpuerta.mx/storage/brands/shops/apple- ...
#   </script>
#   <script data-cp-lang="" type="application/json">
#    {"cpx-compare":"Comparar","cpx-offer":"Oferta","cpx-new":"Nuevo","cpx-just-today":"\u00a1S\u00f3lo hoy!","cpx-from":"Desde","cpx-pcs":"Pza.|Pzs.","cpx-pcs-stock1":"Pieza en|Piezas en","cpx-pcs-stock2":"bodega|bodegas","cpx-shipping":"Env\u00edo","cpx-free-signs":"\u00a1Gratis!","cpx-out-of-stock":"Agotado","cpx-create-alert":"Crear alerta","cpx-see-more":"Ver m\u00e1s","cpx-add-to-cart":"Agregar a carrito","cpx-high-eta":"+%d d\u00edas","cpx-sku":"SKU","cpx-in-existence":"En existencia","cpx-weekly-offers-title":"Ofertas de la semana: \u00a1Descuento de volumen a partir de una sola pieza!","cpx-clock-title":"Ofertas validas por tiempo limitado","cpx-clock-are-left":"Quedan:","cpx-clock-day":"Dia|Dias","cpx-clock-hr":"Hr|Hrs","cpx-clock-min":"Min|Mins","cpx-clock-seg":"Seg|Segs","cpx-clock-button":"Ver todas las ofertas","cpx-categories-buy-by-brands":"Comprar por marca","cpx-categories-title":"Algunas de nuestras principales categorias","cpx-tools-title":"Utilice nuestras herramientas de compra","cpx-certificates-title":"Certificados","cpx-reviews-title":"Algunos de nuestros clientes","cpx-certificates-button":"Ver todos los certificados","cpx-links-about-abasteo":"Acerca de abasteo","cpx-links-about-us":"Quienes Somos","cpx-links-why-abasteo":"Por que abasteo","cpx-links-payment-methods":"Formas de pago","cpx-links-shipping-methods":"Formas de envio","cpx-links-information-center":"Centro de informacion","cpx-links-shortcuts":"Accesos rapidos","cpx-links-my-account":"Mi cuenta","cpx-links-my-orders":"Mis Pedidos","cpx-links-my-quotes":"Mis Cotizaciones","cpx-links-address-book":"Libreta de direcciones","cpx-links-purchasing-advice":"Asesoria de compras","cpx-links-how-to-buy":"Como comprar","cpx-links-shopping-guides":"Guias de compra","cpx-links-shopping-tools":"Herramientas de compra","cpx-links-assurances":"Garantias","cpx-links-contact":"Contacto","cpx-links-tel-mex":"MEX (55) 47 800 901","cpx-links-tel-gdl":"GDL (33) 47 800 901","cpx-links-tel-mty":"MTY (81) 47 800 901","cpx-links-schedule":"L-V 9AM A 6PM","cpx-links-email":"INFO@ABASTEO.MX","cpx-payment-prices-with-vat":"Precios incluyendo IVA","cpx-footer-general-conditions":"Condiciones generales","cpx-footer-notice-of-privacy":"Aviso de privacidad","cpx-footer-copyright":"\u00a9 2012 - 2019 ABASTEO.MX","cpx-about-abasteo":"Sobre Abasteo"}
#   </script>
#   <script>
#    window.cp = {}
#   </script>
#   <script data-cp-orig="cdn.jquery.js" src="https://cdnjs.cloudflare.com/ajax/libs/jquery/3.5.1/jquery.min.js">
#   </script>
#   <script data-cp-orig="cdn.foundation.js" src="https://cdnjs.cloudflare.com/ajax/libs/foundation/6.5.3/js/foundation.min.js">
#   </script>
#   <script data-cp-orig="cdn.knockout.js" src="https://cdnjs.cloudflare.com/ajax/libs/knockout/3.5.0/knockout-min.js">
#   </script>
#   <script data-cp-orig="cdn.moment.js" src="https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.27.0/moment.min.js">
#   </script>
#   <script data-cp-orig="cdn.moment-es.js" src="https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.27.0/locale/es.min.js">
#   </script>
#   <script data-cp-orig="cdn.moment-timezone.js" src="https://cdnjs.cloudflare.com/ajax/libs/moment-timezone/0.5.26/moment-timezone-with-data-10-year-range.min.js">
#   </script>
#   <script data-cp-orig="cdn.Swiper.js" src="https://cdnjs.cloudflare.com/ajax/libs/Swiper/4.3.5/js/swiper.min.js">
#   </script>
#   <script data-cp-orig="cdn.vue.js" src="https://cdnjs.cloudflare.com/ajax/libs/vue/2.7.10/vue.runtime.min.js">
#   </script>
#   <script data-cp-orig="cdn.nouislider.js" src="https://cdnjs.cloudflare.com/ajax/libs/noUiSlider/14.6.3/nouislider.min.js">
#   </script>
#   <script data-cp-orig="google.account" src="https://accounts.google.com/gsi/client">
#   </script>
#   <script data-cp-orig="apple.account" src="https://appleid.cdn-apple.com/appleauth/static/jsapi/appleid/1/es_MX/appleid.auth.js">
#   </script>
#   <script data-cp-orig="manifest.js" src="https://www.cyberpuerta.mx/out/dist/manifest.919e56bc383450206d0f.js">
#   </script>
#   <script data-cp-orig="cp.app.js" src="https://www.cyberpuerta.mx/out/dist/cp.app.4b0bf906f37e476ed466.js">
#   </script>
#   <script data-cp-orig="cp.app.foundation.js" src="https://www.cyberpuerta.mx/out/dist/cp.app.foundation.0a5a8952f9e3dc1de013.js">
#   </script>
#   <script data-cp-orig="cp.app.legacy.js" src="https://www.cyberpuerta.mx/out/dist/cp.app.legacy.0915f10e27b62a63394f.js">
#   </script>
#   <script data-cp-orig="vendors~cp.app.js" src="https://www.cyberpuerta.mx/out/dist/vendors~cp.app.458736c1a92521caac2e.js">
#   </script>
#  </head>
#  <!-- OXID eShop Community Edition, Version 4, Shopping Cart System (c) OXID eSales AG 2003 - 2023 - http://www.oxid-esales.com -->
#  <body class="start">
#   <!-- Google Tag Manager -->
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-TZF4FD" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div class="general-overlay cp-overlay1 hide">
#    <div class="cp-overlay-cnt" style="background-image:url('https://www.cyberpuerta.mx/out/cyberpuertaV5/img/loading_md.gif')">
#     <div class="inner-cnt">
#      <div class="cp-overlay-loader">
#      </div>
#      <div class="cp-overlay-title">
#      </div>
#      <div class="cp-overlay-subtitle">
#      </div>
#     </div>
#    </div>
#   </div>
#   <div data-cp-banner-place="side-left">
#   </div>
#   <div data-cp-banner-place="side-right">
#   </div>
#   <div class="cp-page-bg">
#    <div data-cp-banner-place="page-top">
#    </div>
#    <a data-open="cpsaldo_newsletter_modal_popup" id="cpsaldo_newsletter_modal_popup_link" style="display:none;">
#     cpsaldo_newsletter
#    </a>
#    <div class="reveal" data-reveal="" id="cpsaldo_newsletter_modal_popup" style="width: 720px">
#     <div class="cpsaldo_newsletter">
#      <div>
#       <!-- <img alt="" src="//www.cyberpuerta.mx/out/pictures/wysiwigpro/layovers/newsletter-pop-up-image-100-2020.png" /> -->
#       <img alt="" src="//www.cyberpuerta.mx/out/banners/welcome/bannerwelcome-saldo-new@2x.jpg"/>
#      </div>
#      <div>
#       <div class="cpsaldo_newsletter_register">
#        <form action="https://www.cyberpuerta.mx/index.php?" class="js-oxValidate inline-error" id="cpsaldo_newsletter_registration" method="post">
#         <input name="lang" type="hidden" value="0"/>
#         <input name="actcontrol" type="hidden" value="start"/>
#         <input name="fnc" type="hidden" value="cpsaldo_newsletter_register"/>
#         <input name="cl" type="hidden" value="start"/>
#         <input name="tpl" type="hidden" value=""/>
#         <input name="oxloadid" type="hidden" value=""/>
#         <input name="CustomError" type="hidden" value="cpsaldo_newsletter_registration"/>
#         <input name="option" type="hidden" value="4"/>
#         <input data-cp-password-length="" type="hidden" value="6"/>
#         <input name="pgNr" type="hidden" value="0"/>
#         <div class="login_account clear">
#          <input name="blnewssubscribed" type="hidden" value="1"/>
#          <ul class="emvalidateform form" data-cp-password-strength-tool="" data-cp-register-form="">
#           <li>
#            <div class="form_field_box oxuser__oxfname_box">
#             <label class="req">
#              Nombre:
#             </label>
#             <input class="js-oxValidate js-oxValidate_notEmpty" maxlength="255" name="lgn_name" type="text" value=""/>
#            </div>
#            <div data-cp-error-msg="">
#             <span class="form-invalid-input">
#              <span class="js-oxError_notEmpty">
#               Favor de llenar el campo
#              </span>
#             </span>
#            </div>
#           </li>
#           <li>
#            <div class="form_field_box oxuser__oxusername_box">
#             <label class="req">
#              Ingresa tu email:
#             </label>
#             <input class="js-oxValidate js-oxValidate_notEmpty js-oxValidate_email" maxlength="73" name="lgn_usr" type="text" value=""/>
#            </div>
#            <div data-cp-error-msg="">
#             <span class="form-invalid-input">
#              <span class="js-oxError_notEmpty">
#               Favor de llenar el campo
#              </span>
#              <span class="js-oxError_email">
#               Por favor ingresa un e-mail válido
#              </span>
#             </span>
#            </div>
#           </li>
#           <li>
#            <div class="form_field_box oxuser__oxpassword_box">
#             <label class="req">
#              Crea una contraseña:
#             </label>
#             <input class="js-oxValidate js-oxValidate_notEmpty js-oxValidate_length js-oxValidate_match js-oxValidate_pwdStrength" name="lgn_pwd" type="password"/>
#            </div>
#            <div data-cp-error-msg="">
#             <span class="form-invalid-input">
#              <span class="js-oxError_notEmpty">
#               Favor de llenar el campo
#              </span>
#              <span class="js-oxError_length">
#               Tu contraseña debe tener mínimo 6 dígitos
#              </span>
#              <span class="js-oxError_pwdStrength">
#               Seguridad insuficiente
#              </span>
#              <span class="js-oxError_match">
#               Las contraseñas no coinciden
#              </span>
#             </span>
#            </div>
#           </li>
#           <li>
#            <div class="form_field_box oxuser__oxpassword2_box">
#             <label class="req">
#              Confirma la contraseña:
#             </label>
#             <input class="js-oxValidate js-oxValidate_notEmpty js-oxValidate_match" name="lgn_pwd2" type="password"/>
#            </div>
#            <div data-cp-error-msg="">
#             <span class="form-invalid-input">
#              <span class="js-oxError_notEmpty">
#               Favor de llenar el campo
#              </span>
#              <span class="js-oxError_match">
#               Las contraseñas no coinciden
#              </span>
#             </span>
#            </div>
#           </li>
#           <li class="password-strength-container password-strength-container--two-column">
#            <input data-cp-lang="empty" type="hidden" value="vacía"/>
#            <input data-cp-lang="weak" type="hidden" value="debil"/>
# ...
#                     exitintentdisplayed = true;
#                 }
#             }
#         }
#
#         if (!display) {
#             $(window).on("mouseleave", cpexitintent_leave);
#         }
#     });
# /**
#      * set the cookie to be sure the popup never display
#      */
#     function cpsaldo_set_newsletter_cookie()
#     {
#         let param=$('form#cpsaldo_newsletter_cookie').serialize();
#         $.ajax({
#             type: 'POST',
#             url: 'https://www.cyberpuerta.mx/index.php?',
#             data: param,
#             cache: false,
#             dataType: "html",
#         }).done(function(data) {
#             console.log(data);
#         });
#     }
#
#
#     var cpsaldo_newslettersticker_timer;
#     $('#cpsaldo_newslettersticker').mouseenter(function () {
#         clearTimeout(cpsaldo_newslettersticker_timer);
#         if ($('#cpsaldo_newslettersticker').attr('data-open') == "0") {
#             $('#cpsaldo_newslettersticker').attr('data-open', '2');
#             $('#cpsaldo_newslettersticker .bg1').animate({top: "-=120"}, 400, function () {
#             });
#             $('#cpsaldo_newslettersticker .bg2').delay(200).animate({top: "-=120"}, 400, function () {
#                 $('#cpsaldo_newslettersticker').attr('data-open', '1');
#             });
#             $('#cpsaldo_newslettersticker .bg3').animate({top: "-=120"}, 400, function () {
#             });
#         }
#         $('#cpsaldo_newslettersticker .close').stop(true).animate({opacity: 1}, 200, function () {
#         });
#     });
#     $('#cpsaldo_newslettersticker').mouseleave(function () {
#         if ($('#cpsaldo_newslettersticker').attr('data-open') != "0") {
#             cpsaldo_newslettersticker_timer = setTimeout(function () {
#                 $('#cpsaldo_newslettersticker .bg1').animate({top: "+=120"}, 1000, function () {
#                 });
#                 $('#cpsaldo_newslettersticker .bg2').animate({top: "+=120"}, 1000, function () {
#                     $('#cpsaldo_newslettersticker').attr('data-open', '0');
#                 });
#                 $('#cpsaldo_newslettersticker .bg3').animate({top: "+=120"}, 1000, function () {
#                 });
#             }, 1500);
#         }
#         $('#cpsaldo_newslettersticker .close').stop(true).animate({opacity: 0}, 200, function () {
#         });
#     });
#     $('#cpsaldo_newslettersticker .close').click(function () {
#         $('#cpsaldo_newslettersticker').animate({
#             opacity: 0
#         });
#
#         /* set cookie */
#         cpsaldo_set_newsletter_cookie();
#     });
#     $('#cpsaldo_newslettersticker div.bg10, #cpsaldo_newslettersticker div.bg1, #cpsaldo_newslettersticker div.bg2, #cpsaldo_newslettersticker div.bg3').click(function () {
#         $('#cpsaldo_newsletter_modal_popup_link').click();
#     });
# var oxwidget_headerlogin_timeoutopen = null;
#     var oxwidget_headerlogin_timeout     = null;
#     var oxwidget_headerlogin_canclose    = true;
#     var oxwidget_headerlogin_mousehover  = false;
#     $('#oxwidget_headerlogin input').focus(function () {
#         oxwidget_headerlogin_canclose = false;
#     }).blur(function () {
#         oxwidget_headerlogin_canclose = true;
#         if (!oxwidget_headerlogin_mousehover) {
#             clearTimeout(oxwidget_headerlogin_timeoutopen);
#             oxwidget_headerlogin_timeout = setTimeout(function () {
#                 $('#oxwidget_headerlogin').removeClass('hover');
#             }, 200);
#         }
#     });
#     $('#oxwidget_headerlogin').mouseenter(function () {
#         if (oxwidget_headerlogin_timeout) {
#             clearTimeout(oxwidget_headerlogin_timeout);
#         }
#         oxwidget_headerlogin_timeoutopen = setTimeout(function () {
#             $('#oxwidget_headerlogin').addClass('hover');
#         }, 200);
#
#         oxwidget_headerlogin_mousehover = true;
#     }).mouseleave(function () {
#         oxwidget_headerlogin_mousehover = false;
#         if (oxwidget_headerlogin_canclose) {
#             clearTimeout(oxwidget_headerlogin_timeoutopen);
#             oxwidget_headerlogin_timeout = setTimeout(function () {
#                 $('#oxwidget_headerlogin').removeClass('hover');
#             }, 200);
#         }
#     });
#
#     $('#logoutBtn').click(function () {
#         if (!window.dataLayer) return;
#
#         /** GA4Event */
#         window.dataLayer.push({
#             event: 'logout'
#         });
#     });
#     $('.oxwidget_headerlogin_loginform form').on('submit', function () {
#         try{
#             let localSearches = localStorage.getItem('recentSearches');
#             let localSearchesArr = [];
#             let searchesArr = [];
#             if(localSearches) {
#
#                 localSearchesArr = JSON.parse(localSearches);
#                 localSearchesArr.forEach((e) => {
#                     if(typeof e === 'string') {
#                         searchesArr.push({
#                             'date': Math.floor((new Date().getTime() - 60000) / 1000),
#                             'keyword': e
#                         });
#                     }else {
#                         searchesArr.push(e);
#                     }
#                 });
#             }
#             if(searchesArr.length > 8) {
#                 searchesArr = searchesArr.slice(searchesArr.length - 8, searchesArr.length);
#             }
#             // Add cookie to track that search is suggested
#             const d = new Date();
#             d.setTime(d.getTime() + 8000);
#             let expires = d.toUTCString();
#             document.cookie = 'recentSearchesCookie='+JSON.stringify(searchesArr)+'; expires='+expires+'; path=/;'
#         }catch (e){console.error(e);}
#     });
# $(function () {
#         var notice = $('#oxwidget_headernotice');
#         var popup = notice.find('.oxwidget_headernotice_popup');
#         popup.find('li').on("click mouseenter", function (e) {
#             popup.find('li').removeClass('selected');
#             $(e.currentTarget).addClass('selected');
#             popup.find('.oxwidget_headernotice_products > div').css('display', 'none');
#             popup.find('.oxwidget_headernotice_products #products' + $(e.currentTarget).attr('data-id')).css('display', 'block');
#         });
#
#         notice.hoverIntent(function () {
#             notice.addClass('hover');
#             var listbox = notice.find('.oxwidget_headernotice_listsbox');
#             if (listbox.length > 0 && !notice.attr('data-checked')) {
#                 notice.attr('data-checked', '1');
#                 var h = listbox.outerHeight(true);
#                 notice.find('.oxwidget_headernotice_products > div').each(function (i, el) {
#                     h = Math.max($(el).outerHeight(true), h);
#                 });
#                 popup.css('height', (h + 2) + 'px');
#                 popup.find('li').first().trigger("click");
#             }
#         }, function () {
#             notice.removeClass('hover');
#         });
#
#     });
#     function notice_global_remove(wid, aid) {
#         $('#oxwidget_headernotice_globalremove_wid').val(wid);
#         $('#oxwidget_headernotice_globalremove_aid').val(aid);
#         $('#oxwidget_headernotice_globalremove').trigger("submit");
#     }
# $(function () {
#         var help = $('#oxwidget_headerhelp');
#         help.hoverIntent(
#             function() { help.addClass('hover'); },
#             function() {help.removeClass('hover'); }
#         );
#     });
# var oxwidget_headerminibasket_timeout = null;
# $('#oxwidget_headerminibasket').mouseenter(function() {
#     $('#oxwidget_headerminibasket').addClass('hover');
#     $('#oxwidget_headerminibasket').parent('#emheaderminibasket').addClass('hover');
#     if (oxwidget_headerminibasket_timeout) {
#
#         clearTimeout(oxwidget_headerminibasket_timeout);
#     }
# }).mouseleave(function() {
#     oxwidget_headerminibasket_timeout = setTimeout(function () {
#         $('#oxwidget_headerminibasket').removeClass('hover');
#         $('#oxwidget_headerminibasket').parent('#emheaderminibasket').removeClass('hover');
#     }, 300)
# });
# $('.cp-header-overlay').click(function(){
#     $('#oxwidget_headerminibasket').removeClass('hover');
#     $('#oxwidget_headerminibasket').parent('#emheaderminibasket').removeClass('hover');
# });
# (function(){
#                 window.cpGa = window.cpGa || {};
#                 cpGa.ecPromoImp = cpGa.ecPromoImp || []; // first stored here, then pushed to datalayer
#                 window.ecPromoImpNivoShown = window.ecPromoImpNivoShown || []; // for nivoSlider
#
#                 $('a[data-ecPromoImp]').each(function(){
#                     var self = $(this);
#                     var promoFieldObject = JSON.parse(self.attr("data-ecPromoImp"));
#                     // promotion views, preparing
#                     if (promoFieldObject.creative.substr(promoFieldObject.creative.length - 2) == "-1") {
#                         // this if is because the nivoSlider will push too. If we disable the nivoSlider to do this then we remove this if
#                         window.ecPromoImpNivoShown.push(promoFieldObject.creative); // "burn" the banner so it is not counted again
#                         cpGa.ecPromoImp.push(promoFieldObject);
#                     }
#
#                     // promotion clicks
#                     self.click(function(){
#                         dataLayer.push({
#                             'event': 'promotionClick',
#                             'ecommerce': {
#                                 'promoClick': {
#                                     'promotions':[ promoFieldObject]
#                                 }
#                             }
#                         });
#                     });
#                 });
#             })();
# function cpnosto_request(place, rai = false, slot_name = "", show = false) {
#             $('#cpnosto_place').val(place);
#             let param = $('#cpnosto_form').serialize();
#             param += rai ? "&rai=true" : "";
#             param += slot_name ? `&slot_name=${ slot_name }` : "";
#             param += show ? "&show=true" : "";
#
#             // this sections
#             let specialSections = ["detail0", "home0"];
#
#             // here will be the local storage instead to use session
#             let placeId =  getCookie("_ga") + place + '';
#             let returnDataFromLocalStorage = sessionStorage.getItem(placeId);
#
#             if( !returnDataFromLocalStorage ) {
#                 $.ajax({
#                     type: 'GET',
#                     url: 'https://www.cyberpuerta.mx/index.php?',
#                     data: param,
#                     cache: false,
#                     dataType: "html",
#                 }).done(function (returndata) {
#
#                     if (returndata) {
#                         let element = `#cpnosto_${place}_result`;
#                         element += (rai) ? ".rai" : "";
#                         $(element).html(returndata);
#
#                         if ( specialSections.includes(place) ) {
#                             sessionStorage.setItem(placeId, returndata);
#                         }
#                     }
#                 });
#             } else {
#                 let element = `#cpnosto_${place}_result`;
#                 element += (rai) ? ".rai" : "";
#                 $(element).html(returnDataFromLocalStorage);
#             }
#         }
#   </script>
#   <script>
#    var oxwidget_headercompare_timeout=null;
# var oxwidget_headercompare_timeoutdelay=null;
# var oxwidget_headercompare_timeoutopen=null;
# $('#oxwidget_headercompare').mouseenter(function() {
#     /*$('#oxwidget_headercompare').addClass('hover');*/
#     if(oxwidget_headercompare_timeoutdelay)
#     {
#         clearTimeout(oxwidget_headercompare_timeoutdelay);
#     }
#     if(oxwidget_headercompare_timeout)
#     {
#         clearTimeout(oxwidget_headercompare_timeout);
#     }
#     oxwidget_headercompare_timeoutopen=setTimeout(function() {
#         $('#oxwidget_headercompare').addClass('hover');
#     },200);
# }).mouseleave(function() {
#     if(oxwidget_headercompare_timeoutdelay)
#     {
#         clearTimeout(oxwidget_headercompare_timeoutdelay);
#     }
#     if(oxwidget_headercompare_timeoutopen)
#     {
#         clearTimeout(oxwidget_headercompare_timeoutopen);
#     }
#     oxwidget_headercompare_timeout=setTimeout(function() {
#         $('#oxwidget_headercompare').removeClass('hover');
#     },200);
# });
#
#
# function compare_global_remove(id)
# {
#     $('#oxwidget_headercompare_globalremove_aid').val(id);
#     $('#oxwidget_headercompare_globalremove').submit();
# }
#
# function compare_emstr_replace(search, replace, subject)
# {
#     return subject.split(search).join(replace);
# }
# function compare_add(id)
# {
#     $('#oxwidget_headercompare .oxwidget_headercompare_header_wait').css('display','block');
#
#     $('#compare_add'+id).css('display','none');
#     $('#compare_remove'+id).css('display','block');
#
#     var href=$('#emcomparelinkbox' + id + ' .emcomparelinkbox_link_add').attr('href');
#     href=compare_emstr_replace('&amp;','&',href);
#     href=href+'&emcomparemodule=1';
#
#     $.get(href, function(data) {
#                         var tmp='https://www.cyberpuerta.mx/index.php?cl=oxwidget_headercompare_getwidget&amp;searchparam=';
#         tmp=compare_emstr_replace('&amp;','&',tmp);
#         $.get(tmp,function(data) {
#             $('#oxwidget_headercompare').html(data);
#             $("#oxwidget_headercompare img").unveil();
#
#             if(oxwidget_headercompare_timeout)
#             {
#                 clearTimeout(oxwidget_headercompare_timeout);
#             }
#             $('#oxwidget_headercompare').addClass('hover');
#             oxwidget_headercompare_timeoutdelay=setTimeout(function() {
#                 $('#oxwidget_headercompare').removeClass('hover');
#             },5000);
#         });
#     });
# }
# function compare_remove(id)
# {
#     $('#oxwidget_headercompare .oxwidget_headercompare_header_wait').css('display','block');
#
#     $('#compare_add'+id).css('display','block');
#     $('#compare_remove'+id).css('display','none');
#
#     var href=$('#emcomparelinkbox' + id + ' .emcomparelinkbox_link_remove').attr('href');
#     href = href + "&emcomparemodule=1";
#     href=compare_emstr_replace('&amp;','&',href);
#     href=href+'&emcomparemodule=1';
#
#     $.get(href, function(data) {
#                         var tmp='https://www.cyberpuerta.mx/index.php?cl=oxwidget_headercompare_getwidget&amp;searchparam=';
#         tmp=compare_emstr_replace('&amp;','&',tmp);
#         $.get(tmp,function(data) {
#             $('#oxwidget_headercompare').html(data);
#         });
#     });
# }
#
# $('.emcomparelinkbox_link_add').on("click", function(e) {
#     var id = $(e.currentTarget).attr('data-id');
#     compare_add(id);
#     return false;
# });
# $('.emcomparelinkbox_link_remove').on("click", function(e) {
#     var id = $(e.currentTarget).attr('data-id');
#     compare_remove(id);
#     return false;
# });
#   </script>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"4879248977","applicationID":"66344412","transactionName":"MQEAbUNRXkVQAEBbVghLN0tYH1lYVQZMHEkOFA==","queueTime":0,"applicationTime":501,"atts":"HUYDGwtLTUs=","errorBeacon":"bam.nr-data.net","agent":""}
#   </script>
#   <script>
#    (function(){var js = "window['__CF$cv$params']={r:'7eddfc370e855216'};_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/scripts/invisible.js',document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();
#   </script>
#  </body>
# </html>

# %% [markdown]
# #### <span style="color:yellow">Una vez obtenido el código fuente podemos de la página WEB (página de prueba) para analizar los datos que queremos almacenar ó extraer.</span>

# %% [markdown]
# #### <span style="color:yellow">Si queremos extraer y almacenar datos desde el código fuente nos tomaría mucho tiempo leyendo linea por linea o entenderlo e ir buscando ciertos elemetos e información desde la página Web.</span>
#
#  #### <span style="color:yellow">Para agilizar el proceso de analisis de los datos podemos hacer uso de las herramientas de desarrollador que directamente tienen los navegadores.</span>

# %% [markdown]
# #### <span style="color:blue">Vamos a asignar a variables nuestros elementos buscados utilizando las funciones que nos proporciona la libreria de BeautifulSoup</span>
#
# #### <span style="color:blue">Creamos una variable llamada (titulo_item) despues hacemos uso de nuestro código fuente (soup).</span>
# #### <span style="color:blue">y despues usamos la función (find) la cual utiliza una entrada de texto o ciertos identificadores.</span>
# #### <span style="color:blue">le colocamos en el parentesis la etiqueta "a" localizando la 1er en la página.</span>

# %%
titulo_item = soup.find('a')

print(titulo_item)
# Out:
# <a data-open="cpsaldo_newsletter_modal_popup" id="cpsaldo_newsletter_modal_popup_link" style="display:none;">cpsaldo_newsletter</a>

# %% [markdown]
# #### <span style="color:green">Acabamos de identificar la primera etiqueta encontrada de nuestro código de fuente.</span>

# %% [markdown]
# #### <span style="color:blue">Ahora vamos buscar todas las etiquetas "a" de este código fuente.</span>
# #### <span style="color:blue">Para eso vamos a utilizar la variable (titulo_items) y en la función le agregamos all find_all().</span>
# #### <span style="color:blue">Lo que hace es encontrar todas las etiquetas "a" en nuestro código fuente.</span>
# #### <span style="color:blue">Cuando lo despleguemos tendremos un arreglo de todas nustras etiquetas "a" que están en nuestra página.</span>

# %%
titulo_items = soup.find_all('a')

print(titulo_items)
# Out:
# [<a data-open="cpsaldo_newsletter_modal_popup" id="cpsaldo_newsletter_modal_popup_link" style="display:none;">cpsaldo_newsletter</a>, <a class="logo" href="https://www.cyberpuerta.mx/" title="">
# <img alt="" src="https://www.cyberpuerta.mx/out/cyberpuertaV5/img/logo2.png"/>
# </a>, <a href="https://www.cyberpuerta.mx/olvide-mi-contrasena/" style="text-align: center;color:#0066bb;font-weight: 700; line-height: 20px;padding: 8px 0 7px 0;" title="Olvidé mi contraseña">
# Olvidé mi contraseña
# </a>, <a class="normalButton largeButton oxwidget_headerlogin_register_button" href="https://www.cyberpuerta.mx/crear-cuenta/" style="margin-right:-3px;">
# Registrarse
# </a>, <a href="https://www.cyberpuerta.mx/Quienes-somos/">Quiénes somos</a>, <a href="https://www.cyberpuerta.mx/Contacto/">Contacto</a>, <a href="https://www.cyberpuerta.mx/Preguntas-frequentes/">Preguntas frecuentes</a>, <a href="https://www.cyberpuerta.mx/Modos-de-Pago/">Formas de pago</a>, <a href="https://www.cyberpuerta.mx/Modos-de-envio/">Formas de envío</a>, <a href="https://www.cyberpuerta.mx/Guias-de-Compra/">Guías de compra</a>, <a href="https://www.cyberpuerta.mx/Herramientas-de-compra/">Herramientas de compra</a>, <a class="normalButton" href="https://www.cyberpuerta.mx/Centro-de-Informacion/">Ver más</a>, <a class="oxwidget_headerminibasket_header" href="https://www.cyberpuerta.mx/carrito-de-compras/">
# <span class="count">0</span>
# <span class="icon"></span>
# <span class="total">$0.00</span>
# </a>, <a class="submitButton largeButton" href="https://www.cyberpuerta.mx/Quienes-somos/">
# Conocer más
# </a>, <a class="submitButton" href="https://www.cyberpuerta.mx/Bienvenido/" style="margin-bottom: 6px;">Crear cuenta</a>, <a href="https://www.cyberpuerta.mx/index.php?cl=alist&amp;cnid=emsalearticle_startdetail">
# Ver todos los productos destacados de hoy
# </a>, <a class="cp-picture-container cpGaProdemstartpagenew-1" href="https://www.cyberpuerta.mx/Computo-Hardware/Componentes/Tarjetas-de-Video/Tarjeta-de-Video-MSI-NVIDIA-GeForce-RTX-3060-VENTUS-2X-12G-OC-12GB-192-bit-GDDR6-PCI-Express-4-0.html">
# <div class="picture-wrapper">
# <div class="catSlider" data-cp-prod-slider='["https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-MSI-GEFORCERTX3060VENTUS2X12GOC-1.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-MSI-GEFORCERTX3060VENTUS2X12GOC-2.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-MSI-GEFORCERTX3060VENTUS2X12GOC-3.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-MSI-GEFORCERTX3060VENTUS2X12GOC-4.jpg"]'>
# <div class="cs-image" data-cp-img-container=""></div>
# <div class="csnav"></div>
# </div>
# </div>
# <div class="picture-overlay">
# <div class="badges-left">
# <img alt="MSI" class="product-logo" data-cp-brand-logo="https://www.cyberpuerta.mx/Por-Marca/MSI/" src="https://cdn.cyberpuerta.mx/storage/brands/8726e36e9d6d53646390d495b4ce9dc1_msi.png"/>
# </div>
# <div class="badges-middle">
# </div>
# <div class="badges-right">
# <div class="badges-right-top">
# </div>
# </div>
# </div>
# </a>, <a href="https://www.cyberpuerta.mx/Opiniones-sobre-Tarjeta-de-Video-MSI-NVIDIA-GeForce-RTX-3060-VENTUS-2X-12G-OC-12GB-192-bit-GDDR6-PCI-Express-4-0/">Ver todas las (59) opiniones</a>, <a href="https://www.cyberpuerta.mx/Opiniones-sobre-Tarjeta-de-Video-MSI-NVIDIA-GeForce-RTX-3060-VENTUS-2X-12G-OC-12GB-192-bit-GDDR6-PCI-Express-4-0/">
# 59
# opiniones
# </a>, <a class="emproduct_title cpGaProdemstartpagenew-1" data-text="" data-truncate="Tarjeta de Video MSI NVIDIA GeForce RTX 3060 VENTUS 2X 12G OC, 12GB 192-bit GDDR6, PCI ..." href="https://www.cyberpuerta.mx/Computo-Hardware/Componentes/Tarjetas-de-Video/Tarjeta-de-Video-MSI-NVIDIA-GeForce-RTX-3060-VENTUS-2X-12G-OC-12GB-192-bit-GDDR6-PCI-Express-4-0.html" id="emstartpagenew-1" title="Tarjeta de Video MSI NVIDIA GeForce RTX 3060 VENTUS 2X 12G OC, 12GB 192-bit GDDR6, PCI Express 4.0">
# <span>Tarjeta de Video MSI NVIDIA GeForce RTX 3060 VENTUS 2X 12G OC, 12GB 192-bit GDDR6, PCI ...</span>
# </a>, <a class="emcomparelinkbox_link_remove" data-aid="529c45b81c21ae107c88a12290fac95b" data-id="listproduct_emstartpagenew-1" href="#" id="removeCmplistproduct_emstartpagenew-1" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=529c45b81c21ae107c88a12290fac95b&amp;anid=529c45b81c21ae107c88a12290fac95b&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# </a>, <a class="emcomparelinkbox_link_txt" href="https://www.cyberpuerta.mx/lista-de-comparacion/">
# Ver Comparación (0)            </a>, <a class="emcomparelinkbox_link_add" data-aid="529c45b81c21ae107c88a12290fac95b" data-id="listproduct_emstartpagenew-1" href="#" id="toCmplistproduct_emstartpagenew-1" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=529c45b81c21ae107c88a12290fac95b&amp;anid=529c45b81c21ae107c88a12290fac95b&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# Comparar
# </a>, <a class="cp-picture-container cpGaProdemstartpagenew-2" href="https://www.cyberpuerta.mx/Audio-y-Video/Audio-y-MP3/Audifonos/Corsair-Audifonos-Gamer-HS65-SURROUND-7-1-Alambrico-1-8-Metros-3-5mm-USB-Negro.html">
# <div class="picture-wrapper">
# <div class="catSlider" data-cp-prod-slider='["https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-CORSAIR-CA-9011270-NA-1.png","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-CORSAIR-CA-9011270-NA-2.png","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-CORSAIR-CA-9011270-NA-3.png","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-CORSAIR-CA-9011270-NA-4.png"]'>
# <div class="cs-image" data-cp-img-container=""></div>
# <div class="csnav"></div>
# </div>
# </div>
# <div class="picture-overlay">
# <div class="badges-left">
# <img alt="CORSAIR" class="product-logo" data-cp-brand-logo="https://www.cyberpuerta.mx/Por-Marca/CORSAIR/" src="https://cdn.cyberpuerta.mx/storage/brands/CORSAIRLogo2020_horiz_K.png"/>
# </div>
# <div class="badges-middle">
# </div>
# <div class="badges-right">
# <div class="badges-right-top">
# </div>
# </div>
# </div>
# </a>, <a class="emproduct_title cpGaProdemstartpagenew-2" data-text="" data-truncate="Corsair Audífonos Gamer HS65 SURROUND 7.1, Alámbrico, 1.8 Metros, 3.5mm/USB, Negro" href="https://www.cyberpuerta.mx/Audio-y-Video/Audio-y-MP3/Audifonos/Corsair-Audifonos-Gamer-HS65-SURROUND-7-1-Alambrico-1-8-Metros-3-5mm-USB-Negro.html" id="emstartpagenew-2" title="Corsair Audífonos Gamer HS65 SURROUND 7.1, Alámbrico, 1.8 Metros, 3.5mm/USB, Negro">
# <span>Corsair Audífonos Gamer HS65 SURROUND 7.1, Alámbrico, 1.8 Metros, 3.5mm/USB, Negro</span>
# </a>, <a class="emcomparelinkbox_link_remove" data-aid="6c99446d5e5f8b961d730daa6f6a3055" data-id="listproduct_emstartpagenew-2" href="#" id="removeCmplistproduct_emstartpagenew-2" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=6c99446d5e5f8b961d730daa6f6a3055&amp;anid=6c99446d5e5f8b961d730daa6f6a3055&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# </a>, <a class="emcomparelinkbox_link_txt" href="https://www.cyberpuerta.mx/lista-de-comparacion/">
# Ver Comparación (0)            </a>, <a class="emcomparelinkbox_link_add" data-aid="6c99446d5e5f8b961d730daa6f6a3055" data-id="listproduct_emstartpagenew-2" href="#" id="toCmplistproduct_emstartpagenew-2" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=6c99446d5e5f8b961d730daa6f6a3055&amp;anid=6c99446d5e5f8b961d730daa6f6a3055&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# Comparar
# </a>, <a class="cp-picture-container cpGaProdemstartpagenew-3" href="https://www.cyberpuerta.mx/Computo-Hardware/Componentes/Tarjetas-de-Video/Tarjeta-de-Video-Gigabyte-AMD-Radeon-RX-6600-Eagle-8G-8GB-128-bit-GDDR6-PCI-Express-x8-4-0.html">
# <div class="picture-wrapper">
# <div class="catSlider" data-cp-prod-slider='["https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-GIGABYTE-GV-R66EAGLE-8GD-689c41.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-GIGABYTE-GV-R66EAGLE-8GD-44700d.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-GIGABYTE-GV-R66EAGLE-8GD-f750ed.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-GIGABYTE-GV-R66EAGLE-8GD-778b88.jpg"]'>
# <div class="cs-image" data-cp-img-container=""></div>
# <div class="csnav"></div>
# </div>
# </div>
# <div class="picture-overlay">
# <div class="badges-left">
# <img alt="GIGABYTE" class="product-logo" data-cp-brand-logo="https://www.cyberpuerta.mx/Por-Marca/GIGABYTE/" src="https://cdn.cyberpuerta.mx/storage/brands/1ec2744b3a948fae2382b1ec7bdb962b_gigabyte.png"/>
# </div>
# <div class="badges-middle">
# </div>
# <div class="badges-right">
# <div class="badges-right-top">
# <div class="cp-processor-badge" style="background-image: url('https://www.cyberpuerta.mx/out/pictures/badge-manager/rx-radeon.png?1598661319');background-repeat: no-repeat;background-size: contain;"></div>
# </div>
# </div>
# </div>
# </a>, <a href="https://www.cyberpuerta.mx/Opiniones-sobre-Tarjeta-de-Video-Gigabyte-AMD-Radeon-RX-6600-Eagle-8G-8GB-128-bit-GDDR6-PCI-Express-x8-4-0/">Ver todas las (38) opiniones</a>, <a href="https://www.cyberpuerta.mx/Opiniones-sobre-Tarjeta-de-Video-Gigabyte-AMD-Radeon-RX-6600-Eagle-8G-8GB-128-bit-GDDR6-PCI-Express-x8-4-0/">
# 38
# opiniones
# </a>, <a class="emproduct_title cpGaProdemstartpagenew-3" data-text="" data-truncate="Tarjeta de Video Gigabyte AMD Radeon RX 6600 Eagle 8G, 8GB 128-bit GDDR6, PCI Express x..." href="https://www.cyberpuerta.mx/Computo-Hardware/Componentes/Tarjetas-de-Video/Tarjeta-de-Video-Gigabyte-AMD-Radeon-RX-6600-Eagle-8G-8GB-128-bit-GDDR6-PCI-Express-x8-4-0.html" id="emstartpagenew-3" title="Tarjeta de Video Gigabyte AMD Radeon RX 6600 Eagle 8G, 8GB 128-bit GDDR6, PCI Express x8 4.0 ― ¡Compra y llévate de regalo Starfield!">
# <span>Tarjeta de Video Gigabyte AMD Radeon RX 6600 Eagle 8G, 8GB 128-bit GDDR6, PCI Express x...</span>
# </a>, <a class="emcomparelinkbox_link_remove" data-aid="b4f578d1e0e56a1139582627cc234c96" data-id="listproduct_emstartpagenew-3" href="#" id="removeCmplistproduct_emstartpagenew-3" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=b4f578d1e0e56a1139582627cc234c96&amp;anid=b4f578d1e0e56a1139582627cc234c96&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# </a>, <a class="emcomparelinkbox_link_txt" href="https://www.cyberpuerta.mx/lista-de-comparacion/">
# Ver Comparación (0)            </a>, <a class="emcomparelinkbox_link_add" data-aid="b4f578d1e0e56a1139582627cc234c96" data-id="listproduct_emstartpagenew-3" href="#" id="toCmplistproduct_emstartpagenew-3" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=b4f578d1e0e56a1139582627cc234c96&amp;anid=b4f578d1e0e56a1139582627cc234c96&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# Comparar
# </a>, <a class="cp-picture-container cpGaProdemstartpagenew-4" href="https://www.cyberpuerta.mx/Telecomunicacion/Audio-para-Telefonia/Auriculares-y-Monoaurales/Jabra-Audifonos-con-Microfono-Evolve-20-UC-Stereo-Alambrico-USB-Negro.html">
# <div class="picture-wrapper">
# <div class="catSlider" data-cp-prod-slider='["https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-JABRA-4999-829-209-1.png","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-JABRA-4999-829-209-2.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-JABRA-4999-829-209-3.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-JABRA-4999-829-209-4.jpg"]'>
# <div class="cs-image" data-cp-img-container=""></div>
# <div class="csnav"></div>
# </div>
# </div>
# <div class="picture-overlay">
# <div class="badges-left">
# <img alt="JABRA" class="product-logo" data-cp-brand-logo="https://www.cyberpuerta.mx/Por-Marca/JABRA/" src="https://cdn.cyberpuerta.mx/storage/brands/682d8575e3ff48b014315531046250a7_jabragn.png"/>
# </div>
# <div class="badges-middle">
# </div>
# <div class="badges-right">
# <div class="badges-right-top">
# </div>
# </div>
# </div>
# </a>, <a href="https://www.cyberpuerta.mx/Opiniones-sobre-Jabra-Audifonos-con-Microfono-Evolve-20-UC-Stereo-Alambrico-USB-Negro/">Ver todas las (1) opiniones</a>, <a href="https://www.cyberpuerta.mx/Opiniones-sobre-Jabra-Audifonos-con-Microfono-Evolve-20-UC-Stereo-Alambrico-USB-Negro/">
# 1
# opinión
# </a>, <a class="emproduct_title cpGaProdemstartpagenew-4" data-text="" data-truncate="Jabra Audífonos con Micrófono Evolve 20 UC Stereo, Alámbrico, USB, Negro" href="https://www.cyberpuerta.mx/Telecomunicacion/Audio-para-Telefonia/Auriculares-y-Monoaurales/Jabra-Audifonos-con-Microfono-Evolve-20-UC-Stereo-Alambrico-USB-Negro.html" id="emstartpagenew-4" title="Jabra Audífonos con Micrófono Evolve 20 UC Stereo, Alámbrico, USB, Negro">
# <span>Jabra Audífonos con Micrófono Evolve 20 UC Stereo, Alámbrico, USB, Negro</span>
# </a>, <a class="emcomparelinkbox_link_remove" data-aid="bd79fac60743aafb9772c956ee6b74d8" data-id="listproduct_emstartpagenew-4" href="#" id="removeCmplistproduct_emstartpagenew-4" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=bd79fac60743aafb9772c956ee6b74d8&amp;anid=bd79fac60743aafb9772c956ee6b74d8&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# </a>, <a class="emcomparelinkbox_link_txt" href="https://www.cyberpuerta.mx/lista-de-comparacion/">
# Ver Comparación (0)            </a>, <a class="emcomparelinkbox_link_add" data-aid="bd79fac60743aafb9772c956ee6b74d8" data-id="listproduct_emstartpagenew-4" href="#" id="toCmplistproduct_emstartpagenew-4" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=bd79fac60743aafb9772c956ee6b74d8&amp;anid=bd79fac60743aafb9772c956ee6b74d8&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# Comparar
# </a>, <a class="cp-picture-container cpGaProdemstartpagenew-5" href="https://www.cyberpuerta.mx/Computo-Hardware/Componentes/Gabinetes/Gabinete-XPG-INVADER-con-Ventana-Midi-Tower-ATX-Micro-ATX-Mini-ITX-USB-3-2-sin-Fuente-Blanco.html">
# <div class="picture-wrapper">
# <div class="catSlider" data-cp-prod-slider='["https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-XPG-INVADER-WHCWW-1.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-XPG-INVADER-WHCWW-2.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-XPG-INVADER-WHCWW-3.jpg"]'>
# <div class="cs-image" data-cp-img-container=""></div>
# <div class="csnav"></div>
# </div>
# </div>
# <div class="picture-overlay">
# <div class="badges-left">
# <img alt="XPG" class="product-logo" data-cp-brand-logo="https://www.cyberpuerta.mx/Por-Marca/XPG/" src="https://cdn.cyberpuerta.mx/storage/brands/Red_XPG_LOGO.png"/>
# </div>
# <div class="badges-middle">
# </div>
# <div class="badges-right">
# <div class="badges-right-top">
# </div>
# </div>
# </div>
# </a>, <a href="https://www.cyberpuerta.mx/Opiniones-sobre-Gabinete-XPG-INVADER-con-Ventana-Midi-Tower-ATX/Micro-ATX/Mini-ITX-USB-3-2-sin-Fuente-Blanco/">Ver todas las (238) opiniones</a>, <a href="https://www.cyberpuerta.mx/Opiniones-sobre-Gabinete-XPG-INVADER-con-Ventana-Midi-Tower-ATX/Micro-ATX/Mini-ITX-USB-3-2-sin-Fuente-Blanco/">
# 238
# opiniones
# </a>, <a class="emproduct_title cpGaProdemstartpagenew-5" data-text="" data-truncate="Gabinete XPG INVADER con Ventana, Midi-Tower, ATX/Micro-ATX/Mini-ITX, USB 3.2, sin Fuen..." href="https://www.cyberpuerta.mx/Computo-Hardware/Componentes/Gabinetes/Gabinete-XPG-INVADER-con-Ventana-Midi-Tower-ATX-Micro-ATX-Mini-ITX-USB-3-2-sin-Fuente-Blanco.html" id="emstartpagenew-5" title="Gabinete XPG INVADER con Ventana, Midi-Tower, ATX/Micro-ATX/Mini-ITX, USB 3.2, sin Fuente, Blanco">
# <span>Gabinete XPG INVADER con Ventana, Midi-Tower, ATX/Micro-ATX/Mini-ITX, USB 3.2, sin Fuen...</span>
# </a>, <a class="emcomparelinkbox_link_remove" data-aid="2884d2df16a61f8214fb92e6b2237dc2" data-id="listproduct_emstartpagenew-5" href="#" id="removeCmplistproduct_emstartpagenew-5" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=2884d2df16a61f8214fb92e6b2237dc2&amp;anid=2884d2df16a61f8214fb92e6b2237dc2&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# </a>, <a class="emcomparelinkbox_link_txt" href="https://www.cyberpuerta.mx/lista-de-comparacion/">
# Ver Comparación (0)            </a>, <a class="emcomparelinkbox_link_add" data-aid="2884d2df16a61f8214fb92e6b2237dc2" data-id="listproduct_emstartpagenew-5" href="#" id="toCmplistproduct_emstartpagenew-5" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=2884d2df16a61f8214fb92e6b2237dc2&amp;anid=2884d2df16a61f8214fb92e6b2237dc2&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# Comparar
# </a>, <a class="cp-picture-container cpGaProdemstartpagenew-6" href="https://www.cyberpuerta.mx/Computo-Hardware/Dispositivos-de-Entrada/Kits-de-Teclado-y-Mouse/Kit-Gamer-4-en-1-Corsair-Teclado-K55-RGB-Pro-Mouse-Harpoon-RGB-Pro-Audifonos-HS50-Pro-Mousepad-MM100-Alambrico-USB-Negro-Espanol.html">
# <div class="picture-wrapper">
# <div class="catSlider" data-cp-prod-slider='["https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-CORSAIR-CH-9226A65-SP-ffcaf2.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-CORSAIR-CH-9226A65-SP-10ac5b.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-CORSAIR-CH-9226A65-SP-ba3671.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-CORSAIR-CH-9226A65-SP-7bc341.jpg"]'>
# <div class="cs-image" data-cp-img-container=""></div>
# <div class="csnav"></div>
# </div>
# </div>
# <div class="picture-overlay">
# <div class="badges-left">
# <img alt="CORSAIR" class="product-logo" data-cp-brand-logo="https://www.cyberpuerta.mx/Por-Marca/CORSAIR/" src="https://cdn.cyberpuerta.mx/storage/brands/CORSAIRLogo2020_horiz_K.png"/>
# </div>
# <div class="badges-middle">
# </div>
# <div class="badges-right">
# <div class="badges-right-top">
# </div>
# </div>
# </div>
# </a>, <a href="https://www.cyberpuerta.mx/Opiniones-sobre-Kit-Gamer-4-en-1-Corsair-Teclado-K55-RGB-Pro-Mouse-Harpoon-RGB-Pro-Audifonos-HS50-Pro-Mousepad-MM100-Alambrico-USB-Negro-Espanol/">Ver todas las (5) opiniones</a>, <a href="https://www.cyberpuerta.mx/Opiniones-sobre-Kit-Gamer-4-en-1-Corsair-Teclado-K55-RGB-Pro-Mouse-Harpoon-RGB-Pro-Audifonos-HS50-Pro-Mousepad-MM100-Alambrico-USB-Negro-Espanol/">
# 5
# opiniones
# </a>, <a class="emproduct_title cpGaProdemstartpagenew-6" data-text="" data-truncate="Kit Gamer 4 en 1 Corsair Teclado K55 RGB Pro + Mouse Harpoon RGB Pro + Audífonos HS50 P..." href="https://www.cyberpuerta.mx/Computo-Hardware/Dispositivos-de-Entrada/Kits-de-Teclado-y-Mouse/Kit-Gamer-4-en-1-Corsair-Teclado-K55-RGB-Pro-Mouse-Harpoon-RGB-Pro-Audifonos-HS50-Pro-Mousepad-MM100-Alambrico-USB-Negro-Espanol.html" id="emstartpagenew-6" title="Kit Gamer 4 en 1 Corsair Teclado K55 RGB Pro + Mouse Harpoon RGB Pro + Audífonos HS50 Pro + Mousepad MM100, Alámbrico, USB, Negro (Español)">
# <span>Kit Gamer 4 en 1 Corsair Teclado K55 RGB Pro + Mouse Harpoon RGB Pro + Audífonos HS50 P...</span>
# </a>, <a class="emcomparelinkbox_link_remove" data-aid="34161bba007346527e34662f95247321" data-id="listproduct_emstartpagenew-6" href="#" id="removeCmplistproduct_emstartpagenew-6" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=34161bba007346527e34662f95247321&amp;anid=34161bba007346527e34662f95247321&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# </a>, <a class="emcomparelinkbox_link_txt" href="https://www.cyberpuerta.mx/lista-de-comparacion/">
# Ver Comparación (0)            </a>, <a class="emcomparelinkbox_link_add" data-aid="34161bba007346527e34662f95247321" data-id="listproduct_emstartpagenew-6" href="#" id="toCmplistproduct_emstartpagenew-6" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=34161bba007346527e34662f95247321&amp;anid=34161bba007346527e34662f95247321&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# Comparar
# </a>, <a class="cp-picture-container cpGaProdemstartpagenew-7" href="https://www.cyberpuerta.mx/Computo-Hardware/Monitores/Monitores/Monitor-ASUS-VA279HAE-LED-VA-27-Full-HD-HDMI-Negro.html">
# <div class="picture-wrapper">
# <div class="catSlider" data-cp-prod-slider='["https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-ASUS-VA279HAE-562221.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-ASUS-VA279HAE-251bff.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-ASUS-VA279HAE-371ac0.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-ASUS-VA279HAE-98fc7d.jpg"]'>
# <div class="cs-image" data-cp-img-container=""></div>
# <div class="csnav"></div>
# </div>
# </div>
# <div class="picture-overlay">
# <div class="badges-left">
# <img alt="ASUS" class="product-logo" data-cp-brand-logo="https://www.cyberpuerta.mx/Por-Marca/ASUS/" src="https://cdn.cyberpuerta.mx/storage/brands/asuslogoa5705fdb70seeklogo.com.png"/>
# </div>
# <div class="badges-middle">
# </div>
# <div class="badges-right">
# <div class="badges-right-top">
# </div>
# </div>
# </div>
# </a>, <a ,="" class="emproduct_title cpGaProdemstartpagenew-7" data-text="" data-truncate="Monitor ASUS VA279HAE LED VA 27" full="" hd,="" hdmi,="" href="https://www.cyberpuerta.mx/Computo-Hardware/Monitores/Monitores/Monitor-ASUS-VA279HAE-LED-VA-27-Full-HD-HDMI-Negro.html" id="emstartpagenew-7" negro"="" title='Monitor ASUS VA279HAE LED VA 27", Full HD, HDMI, Negro'>
# <span>Monitor ASUS VA279HAE LED VA 27", Full HD, HDMI, Negro</span>
# </a>, <a class="emcomparelinkbox_link_remove" data-aid="5564b9b75e8af13cc937c824d5ef8e03" data-id="listproduct_emstartpagenew-7" href="#" id="removeCmplistproduct_emstartpagenew-7" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=5564b9b75e8af13cc937c824d5ef8e03&amp;anid=5564b9b75e8af13cc937c824d5ef8e03&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# </a>, <a class="emcomparelinkbox_link_txt" href="https://www.cyberpuerta.mx/lista-de-comparacion/">
# Ver Comparación (0)            </a>, <a class="emcomparelinkbox_link_add" data-aid="5564b9b75e8af13cc937c824d5ef8e03" data-id="listproduct_emstartpagenew-7" href="#" id="toCmplistproduct_emstartpagenew-7" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=5564b9b75e8af13cc937c824d5ef8e03&amp;anid=5564b9b75e8af13cc937c824d5ef8e03&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# Comparar
# </a>, <a class="cp-picture-container cpGaProdemstartpagenew-8" href="https://www.cyberpuerta.mx/Computo-Hardware/Monitores/Monitores/Monitor-Stylos-STPMOT3B-LED-19-HD-HDMI-Negro.html">
# <div class="picture-wrapper">
# <div class="catSlider" data-cp-prod-slider='["https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-STYLOS-STPMOT3B-51e9b7.jpg"]'>
# <div class="cs-image" data-cp-img-container=""></div>
# <div class="csnav"></div>
# </div>
# </div>
# <div class="picture-overlay">
# <div class="badges-left">
# <img alt="STYLOS" class="product-logo" data-cp-brand-logo="https://www.cyberpuerta.mx/Por-Marca/STYLOS/" src="https://cdn.cyberpuerta.mx/storage/brands/logomini.png"/>
# </div>
# <div class="badges-middle">
# </div>
# <div class="badges-right">
# <div class="badges-right-top">
# </div>
# </div>
# </div>
# </a>, <a href="https://www.cyberpuerta.mx/Opiniones-sobre-Monitor-Stylos-STPMOT3B-LED-19-HD-HDMI-Negro/">Ver todas las (14) opiniones</a>, <a href="https://www.cyberpuerta.mx/Opiniones-sobre-Monitor-Stylos-STPMOT3B-LED-19-HD-HDMI-Negro/">
# 14
# opiniones
# </a>, <a ,="" class="emproduct_title cpGaProdemstartpagenew-8" data-text="" data-truncate="Monitor Stylos STPMOT3B LED 19" hd,="" hdmi,="" href="https://www.cyberpuerta.mx/Computo-Hardware/Monitores/Monitores/Monitor-Stylos-STPMOT3B-LED-19-HD-HDMI-Negro.html" id="emstartpagenew-8" negro"="" title='Monitor Stylos STPMOT3B LED 19", HD, HDMI, Negro'>
# <span>Monitor Stylos STPMOT3B LED 19", HD, HDMI, Negro</span>
# </a>, <a class="emcomparelinkbox_link_remove" data-aid="d38e21c632add1ae026bfe99db6bd87f" data-id="listproduct_emstartpagenew-8" href="#" id="removeCmplistproduct_emstartpagenew-8" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=d38e21c632add1ae026bfe99db6bd87f&amp;anid=d38e21c632add1ae026bfe99db6bd87f&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# </a>, <a class="emcomparelinkbox_link_txt" href="https://www.cyberpuerta.mx/lista-de-comparacion/">
# Ver Comparación (0)            </a>, <a class="emcomparelinkbox_link_add" data-aid="d38e21c632add1ae026bfe99db6bd87f" data-id="listproduct_emstartpagenew-8" href="#" id="toCmplistproduct_emstartpagenew-8" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=d38e21c632add1ae026bfe99db6bd87f&amp;anid=d38e21c632add1ae026bfe99db6bd87f&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# Comparar
# </a>, <a class="cp-picture-container cpGaProdemstartpagenew-9" href="https://www.cyberpuerta.mx/Computo-Hardware/Monitores/Monitores/Monitor-AOC-22B2HN-LED-21-5-Full-HD-75Hz-HDMI-Negro.html">
# <div class="picture-wrapper">
# <div class="catSlider" data-cp-prod-slider='["https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-AOC-22B2HN-11ef9e.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-AOC-22B2HN-f0cceb.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-AOC-22B2HN-566114.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-AOC-22B2HN-12bc6c.jpg"]'>
# <div class="cs-image" data-cp-img-container=""></div>
# <div class="csnav"></div>
# </div>
# </div>
# <div class="picture-overlay">
# <div class="badges-left">
# <img alt="AOC" class="product-logo" data-cp-brand-logo="https://www.cyberpuerta.mx/Por-Marca/AOC/" src="https://cdn.cyberpuerta.mx/storage/brands/aoclogo.jpg"/>
# </div>
# <div class="badges-middle">
# </div>
# <div class="badges-right">
# <div class="badges-right-top">
# </div>
# </div>
# </div>
# </a>, <a href="https://www.cyberpuerta.mx/Opiniones-sobre-Monitor-AOC-22B2HN-LED-21-5-Full-HD-75Hz-HDMI-Negro/">Ver todas las (2) opiniones</a>, <a href="https://www.cyberpuerta.mx/Opiniones-sobre-Monitor-AOC-22B2HN-LED-21-5-Full-HD-75Hz-HDMI-Negro/">
# 2
# opiniones
# </a>, <a ,="" 75hz,="" class="emproduct_title cpGaProdemstartpagenew-9" data-text="" data-truncate="Monitor AOC 22B2HN LED 21.5" full="" hd,="" hdmi,="" href="https://www.cyberpuerta.mx/Computo-Hardware/Monitores/Monitores/Monitor-AOC-22B2HN-LED-21-5-Full-HD-75Hz-HDMI-Negro.html" id="emstartpagenew-9" negro"="" title='Monitor AOC 22B2HN LED 21.5", Full HD, 75Hz, HDMI, Negro'>
# <span>Monitor AOC 22B2HN LED 21.5", Full HD, 75Hz, HDMI, Negro</span>
# </a>, <a class="emcomparelinkbox_link_remove" data-aid="e984a15b49edadc8a9b39631d17af2ec" data-id="listproduct_emstartpagenew-9" href="#" id="removeCmplistproduct_emstartpagenew-9" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=e984a15b49edadc8a9b39631d17af2ec&amp;anid=e984a15b49edadc8a9b39631d17af2ec&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# </a>, <a class="emcomparelinkbox_link_txt" href="https://www.cyberpuerta.mx/lista-de-comparacion/">
# Ver Comparación (0)            </a>, <a class="emcomparelinkbox_link_add" data-aid="e984a15b49edadc8a9b39631d17af2ec" data-id="listproduct_emstartpagenew-9" href="#" id="toCmplistproduct_emstartpagenew-9" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=e984a15b49edadc8a9b39631d17af2ec&amp;anid=e984a15b49edadc8a9b39631d17af2ec&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# Comparar
# </a>, <a class="cp-picture-container cpGaProdemstartpagenew-10" href="https://www.cyberpuerta.mx/Computo-Hardware/Componentes/Fuentes-de-Poder-para-PC-s/Fuente-de-Poder-XPG-CORE-REACTOR-80-PLUS-Gold-24-pin-ATX-120mm-750W.html">
# <div class="picture-wrapper">
# <div class="catSlider" data-cp-prod-slider='["https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-XPG-COREREACTOR750G-BKCUS-1.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-XPG-COREREACTOR750G-BKCUS-2.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-XPG-COREREACTOR750G-BKCUS-3.jpg","https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-XPG-COREREACTOR750G-BKCUS-4.jpg"]'>
# <div class="cs-image" data-cp-img-container=""></div>
# <div class="csnav"></div>
# </div>
# </div>
# <div class="picture-overlay">
# <div class="badges-left">
# <img alt="XPG" class="product-logo" data-cp-brand-logo="https://www.cyberpuerta.mx/Por-Marca/XPG/" src="https://cdn.cyberpuerta.mx/storage/brands/Red_XPG_LOGO.png"/>
# </div>
# <div class="badges-middle">
# </div>
# <div class="badges-right">
# <div class="badges-right-top">
# </div>
# </div>
# </div>
# </a>, <a href="https://www.cyberpuerta.mx/Opiniones-sobre-Fuente-de-Poder-XPG-CORE-REACTOR-80-PLUS-Gold-24-pin-ATX-120mm-750W/">Ver todas las (161) opiniones</a>, <a href="https://www.cyberpuerta.mx/Opiniones-sobre-Fuente-de-Poder-XPG-CORE-REACTOR-80-PLUS-Gold-24-pin-ATX-120mm-750W/">
# 161
# opiniones
# </a>, <a class="emproduct_title cpGaProdemstartpagenew-10" data-text="" data-truncate="Fuente de Poder XPG CORE REACTOR 80 PLUS Gold, 24-pin ATX, 120mm, 750W" href="https://www.cyberpuerta.mx/Computo-Hardware/Componentes/Fuentes-de-Poder-para-PC-s/Fuente-de-Poder-XPG-CORE-REACTOR-80-PLUS-Gold-24-pin-ATX-120mm-750W.html" id="emstartpagenew-10" title="Fuente de Poder XPG CORE REACTOR 80 PLUS Gold, 24-pin ATX, 120mm, 750W">
# <span>Fuente de Poder XPG CORE REACTOR 80 PLUS Gold, 24-pin ATX, 120mm, 750W</span>
# </a>, <a class="emcomparelinkbox_link_remove" data-aid="f234734bbdf77a2aa12cf6881e730c43" data-id="listproduct_emstartpagenew-10" href="#" id="removeCmplistproduct_emstartpagenew-10" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=f234734bbdf77a2aa12cf6881e730c43&amp;anid=f234734bbdf77a2aa12cf6881e730c43&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# </a>, <a class="emcomparelinkbox_link_txt" href="https://www.cyberpuerta.mx/lista-de-comparacion/">
# Ver Comparación (0)            </a>, <a class="emcomparelinkbox_link_add" data-aid="f234734bbdf77a2aa12cf6881e730c43" data-id="listproduct_emstartpagenew-10" href="#" id="toCmplistproduct_emstartpagenew-10" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=f234734bbdf77a2aa12cf6881e730c43&amp;anid=f234734bbdf77a2aa12cf6881e730c43&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# Comparar
# </a>, <a class="cp-picture-container cpGaProdemstartpagenew-11" href="https://www.cyberpuerta.mx/Computo-Hardware/Monitores/Monitores/Monitor-Gamer-Curvo-Gigabyte-G27FC-LED-27-Full-HD-FreeSync-165Hz-HDMI-Bocinas-Integradas-2-x-4W-Negro.html">
# <div class="picture-wrapper">
# <div class="catSlider" data-cp-prod-slider='["https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-GIGABYTE-G27FC-1.jpg"]'>
# <div class="cs-image" data-cp-img-container=""></div>
# <div class="csnav"></div>
# </div>
# </div>
# <div class="picture-overlay">
# <div class="badges-left">
# <img alt="GIGABYTE" class="product-logo" data-cp-brand-logo="https://www.cyberpuerta.mx/Por-Marca/GIGABYTE/" src="https://cdn.cyberpuerta.mx/storage/brands/1ec2744b3a948fae2382b1ec7bdb962b_gigabyte.png"/>
# </div>
# <div class="badges-middle">
# </div>
# <div class="badges-right">
# <div class="badges-right-top">
# </div>
# </div>
# </div>
# </a>, <a href="https://www.cyberpuerta.mx/Opiniones-sobre-Monitor-Gamer-Curvo-Gigabyte-G27FC-LED-27-Full-HD-FreeSync-165Hz-HDMI-Bocinas-Integradas-2-x-4W-Negro/">Ver todas las (8) opiniones</a>, <a href="https://www.cyberpuerta.mx/Opiniones-sobre-Monitor-Gamer-Curvo-Gigabyte-G27FC-LED-27-Full-HD-FreeSync-165Hz-HDMI-Bocinas-Integradas-2-x-4W-Negro/">
# 8
# opiniones
# </a>, <a class="emproduct_title cpGaProdemstartpagenew-11" data-text="" data-truncate='Monitor Gamer Curvo Gigabyte G27FC LED 27", Full HD, FreeSync, 165Hz, HDMI, Bocinas Int...' href="https://www.cyberpuerta.mx/Computo-Hardware/Monitores/Monitores/Monitor-Gamer-Curvo-Gigabyte-G27FC-LED-27-Full-HD-FreeSync-165Hz-HDMI-Bocinas-Integradas-2-x-4W-Negro.html" id="emstartpagenew-11" title='Monitor Gamer Curvo Gigabyte G27FC LED 27", Full HD, FreeSync, 165Hz, HDMI, Bocinas Integradas (2 x 4W), Negro'>
# <span>Monitor Gamer Curvo Gigabyte G27FC LED 27", Full HD, FreeSync, 165Hz, HDMI, Bocinas Int...</span>
# </a>, <a class="emcomparelinkbox_link_remove" data-aid="ae7ba06f9095ee5230ded0980af1be57" data-id="listproduct_emstartpagenew-11" href="#" id="removeCmplistproduct_emstartpagenew-11" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=ae7ba06f9095ee5230ded0980af1be57&amp;anid=ae7ba06f9095ee5230ded0980af1be57&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# </a>, <a class="emcomparelinkbox_link_txt" href="https://www.cyberpuerta.mx/lista-de-comparacion/">
# Ver Comparación (0)            </a>, <a class="emcomparelinkbox_link_add" data-aid="ae7ba06f9095ee5230ded0980af1be57" data-id="listproduct_emstartpagenew-11" href="#" id="toCmplistproduct_emstartpagenew-11" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=ae7ba06f9095ee5230ded0980af1be57&amp;anid=ae7ba06f9095ee5230ded0980af1be57&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# Comparar
# </a>, <a class="cp-picture-container cpGaProdemstartpagenew-12" href="https://www.cyberpuerta.mx/Computo-Hardware/Discos-Duros-SSD-NAS/Discos-Duros-para-Videovigilancia/Disco-Duro-para-Videovigilancia-Western-Digital-WD-Purple-Surveillance-3-5-2TB-SATA-6-Gbit-s-256MB-Cache.html">
# <div class="picture-wrapper">
# <div class="catSlider" data-cp-prod-slider='["https:\/\/www.cyberpuerta.mx\/img\/product\/S\/CP-WESTERNDIGITAL-WD22PURZ-4cc7a7.jpg"]'>
# <div class="cs-image" data-cp-img-container=""></div>
# <div class="csnav"></div>
# </div>
# </div>
# <div class="picture-overlay">
# <div class="badges-left">
# <img alt="WESTERN DIGITAL" class="product-logo" data-cp-brand-logo="https://www.cyberpuerta.mx/Por-Marca/WESTERN-DIGITAL/" src="https://cdn.cyberpuerta.mx/storage/brands/westernDigital2022.png"/>
# </div>
# <div class="badges-middle">
# </div>
# <div class="badges-right">
# <div class="badges-right-top">
# </div>
# </div>
# </div>
# </a>, <a href="https://www.cyberpuerta.mx/Opiniones-sobre-Disco-Duro-para-Videovigilancia-Western-Digital-WD-Purple-Surveillance-3-5-2TB-SATA-6-Gbit/s-256MB-Cache/">Ver todas las (5) opiniones</a>, <a href="https://www.cyberpuerta.mx/Opiniones-sobre-Disco-Duro-para-Videovigilancia-Western-Digital-WD-Purple-Surveillance-3-5-2TB-SATA-6-Gbit/s-256MB-Cache/">
# 5
# opiniones
# </a>, <a class="emproduct_title cpGaProdemstartpagenew-12" data-text="" data-truncate='Disco Duro para Videovigilancia Western Digital WD Purple Surveillance 3.5", 2TB, SATA,...' href="https://www.cyberpuerta.mx/Computo-Hardware/Discos-Duros-SSD-NAS/Discos-Duros-para-Videovigilancia/Disco-Duro-para-Videovigilancia-Western-Digital-WD-Purple-Surveillance-3-5-2TB-SATA-6-Gbit-s-256MB-Cache.html" id="emstartpagenew-12" title='Disco Duro para Videovigilancia Western Digital WD Purple Surveillance 3.5", 2TB, SATA, 6 Gbit/s, 256MB Caché'>
# <span>Disco Duro para Videovigilancia Western Digital WD Purple Surveillance 3.5", 2TB, SATA,...</span>
# </a>, <a class="emcomparelinkbox_link_remove" data-aid="20ed1f81d1f8628c018ccdfd03254c2c" data-id="listproduct_emstartpagenew-12" href="#" id="removeCmplistproduct_emstartpagenew-12" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=20ed1f81d1f8628c018ccdfd03254c2c&amp;anid=20ed1f81d1f8628c018ccdfd03254c2c&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# </a>, <a class="emcomparelinkbox_link_txt" href="https://www.cyberpuerta.mx/lista-de-comparacion/">
# Ver Comparación (0)            </a>, <a class="emcomparelinkbox_link_add" data-aid="20ed1f81d1f8628c018ccdfd03254c2c" data-id="listproduct_emstartpagenew-12" href="#" id="toCmplistproduct_emstartpagenew-12" onclick="go_to('https://www.cyberpuerta.mx/index.php?cl=start&amp;am=1&amp;addcompare=1&amp;fnc=tocomparelist&amp;aid=20ed1f81d1f8628c018ccdfd03254c2c&amp;anid=20ed1f81d1f8628c018ccdfd03254c2c&amp;pgNr=0&amp;searchparam=')">
# <span class="square"></span>
# Comparar
# </a>, <a class="manufacturerbox emsmoothhover" href="https://www.cyberpuerta.mx/Por-Marca/ACER/" title="ACER">
# <img alt="ACER" src="https://cdn.cyberpuerta.mx/storage/brands/acernewlogo.jpg" style="max-height: 90px; max-width: 180px"/>
# </a>, <a class="manufacturerbox emsmoothhover" href="https://www.cyberpuerta.mx/Por-Marca/SAMSUNG/" title="SAMSUNG">
# <img alt="SAMSUNG" src="https://cdn.cyberpuerta.mx/storage/brands/samsung.png" style="max-height: 90px; max-width: 180px"/>
# </a>, <a class="manufacturerbox emsmoothhover" href="https://www.cyberpuerta.mx/Por-Marca/EPSON/" title="EPSON">
# <img alt="EPSON" src="https://cdn.cyberpuerta.mx/storage/brands/epson.png" style="max-height: 90px; max-width: 180px"/>
# </a>, <a class="manufacturerbox emsmoothhover" href="https://www.cyberpuerta.mx/Por-Marca/HP/" title="HP">
# <img alt="HP" src="https://cdn.cyberpuerta.mx/storage/brands/e6fc8ce107f2bdf0955f021a391514ce_hp.png" style="max-height: 90px; max-width: 180px"/>
# </a>, <a class="manufacturerbox emsmoothhover" href="https://www.cyberpuerta.mx/Por-Marca/MSI/" title="MSI">
# <img alt="MSI" src="https://cdn.cyberpuerta.mx/storage/brands/8726e36e9d6d53646390d495b4ce9dc1_msi.png" style="max-height: 90px; max-width: 180px"/>
# </a>, <a class="manufacturerbox emsmoothhover" href="https://www.cyberpuerta.mx/Por-Marca/KINGSTON/" title="KINGSTON">
# <img alt="KINGSTON" src="https://cdn.cyberpuerta.mx/storage/brands/kingstonlogofcc32d090fseeklogo.com.png" style="max-height: 90px; max-width: 180px"/>
# </a>, <a class="manufacturerbox emsmoothhover" href="https://www.cyberpuerta.mx/Por-Marca/XTREME-PC-GAMING/" title="XTREME PC GAMING">
# <img alt="XTREME PC GAMING" src="https://cdn.cyberpuerta.mx/storage/brands/5da100a24aafc_logoxtreme.png" style="max-height: 90px; max-width: 180px"/>
# </a>, <a class="manufacturerbox emsmoothhover" href="https://www.cyberpuerta.mx/Por-Marca/WESTERN-DIGITAL/" title="WESTERN DIGITAL">
# <img alt="WESTERN DIGITAL" src="https://cdn.cyberpuerta.mx/storage/brands/westernDigital2022.png" style="max-height: 90px; max-width: 180px"/>
# </a>, <a class="manufacturerbox emsmoothhover" href="https://www.cyberpuerta.mx/Por-Marca/INTEL/" title="INTEL">
# <img alt="INTEL" src="https://cdn.cyberpuerta.mx/storage/brands/intellogo.png" style="max-height: 90px; max-width: 180px"/>
# </a>, <a class="manufacturerbox emsmoothhover" href="https://www.cyberpuerta.mx/Por-Marca/CORSAIR/" title="CORSAIR">
# <img alt="CORSAIR" src="https://cdn.cyberpuerta.mx/storage/brands/CORSAIRLogo2020_horiz_K.png" style="max-height: 90px; max-width: 180px"/>
# </a>, <a class="manufacturerbox emsmoothhover" href="https://www.cyberpuerta.mx/Por-Marca/ADATA/" title="ADATA">
# <img alt="ADATA" src="https://cdn.cyberpuerta.mx/storage/brands/f976fb2ecf4847ecb507697a8d02ed3d_ADATA.png" style="max-height: 90px; max-width: 180px"/>
# </a>, <a class="manufacturerbox emsmoothhover" href="https://www.cyberpuerta.mx/Por-Marca/AMD/" title="AMD">
# <img alt="AMD" src="https://cdn.cyberpuerta.mx/storage/brands/48af4341f745163f945fa838eeabb062_amdlogo.png" style="max-height: 90px; max-width: 180px"/>
# </a>, <a class="manufacturerbox emsmoothhover" href="https://www.cyberpuerta.mx/Por-Marca/LENOVO/" title="LENOVO">
# <img alt="LENOVO" src="https://cdn.cyberpuerta.mx/storage/brands/685903ef83f7a7c8a165f77eed160d9e_lenovo.png" style="max-height: 90px; max-width: 180px"/>
# </a>, <a class="manufacturerbox emsmoothhover" href="https://www.cyberpuerta.mx/Por-Marca/GIGABYTE/" title="GIGABYTE">
# <img alt="GIGABYTE" src="https://cdn.cyberpuerta.mx/storage/brands/1ec2744b3a948fae2382b1ec7bdb962b_gigabyte.png" style="max-height: 90px; max-width: 180px"/>
# </a>, <a class="manufacturerbox emsmoothhover" href="https://www.cyberpuerta.mx/Por-Marca/APPLE/" title="APPLE">
# <img alt="APPLE" src="https://cdn.cyberpuerta.mx/storage/brands/shops/apple-autorized.png" style="max-height: 90px; max-width: 180px"/>
# </a>, <a class="manufacturerbox emsmoothhover" href="https://www.cyberpuerta.mx/Por-Marca/ZOTAC/" title="ZOTAC">
# <img alt="ZOTAC" src="https://cdn.cyberpuerta.mx/storage/brands/zotac.jpg" style="max-height: 90px; max-width: 180px"/>
# </a>, <a class="manufacturerbox emsmoothhover" href="https://www.cyberpuerta.mx/Por-Marca/DELL/" title="DELL">
# <img alt="DELL" src="https://cdn.cyberpuerta.mx/storage/brands/04c74ad625352f7093356e441ef69610_logodell.png" style="max-height: 90px; max-width: 180px"/>
# </a>, <a class="manufacturerbox emsmoothhover" href="https://www.cyberpuerta.mx/Por-Marca/XPG/" title="XPG">
# <img alt="XPG" src="https://cdn.cyberpuerta.mx/storage/brands/Red_XPG_LOGO.png" style="max-height: 90px; max-width: 180px"/>
# </a>, <a class="manufacturerbox emsmoothhover" href="https://www.cyberpuerta.mx/Por-Marca/LOGITECH/" title="LOGITECH">
# <img alt="LOGITECH" src="https://cdn.cyberpuerta.mx/storage/brands/43ee0a7ff98dae4ebf41c6bec8a4ae0e_logitech.png" style="max-height: 90px; max-width: 180px"/>
# </a>, <a class="manufacturerbox emsmoothhover" href="https://www.cyberpuerta.mx/Por-Marca/BROTHER/" title="BROTHER">
# <img alt="BROTHER" src="https://cdn.cyberpuerta.mx/storage/brands/brother.jpg" style="max-height: 90px; max-width: 180px"/>
# </a>, <a class="categorybox emsmoothhover" href="https://www.cyberpuerta.mx/Computo-Hardware/Componentes/Tarjetas-de-Video/">
# <div class="empicture">
# <img alt="Tarjetas de Video" src="https://www.cyberpuerta.mx/out/pictures/master/category/icon/tdv(1).png" style="max-height: 180px; max-width: 190px;"/>
# </div>
# <div class="emsmoothsep"></div>
# <div class="emtitle emsmoothtext">
# Tarjetas de Video
# </div>
# </a>, <a class="categorybox emsmoothhover" href="https://www.cyberpuerta.mx/Computadoras/Laptops/">
# <div class="empicture">
# <img alt="Laptops" src="https://www.cyberpuerta.mx/out/pictures/master/category/icon/laptops-home2(1).png" style="max-height: 180px; max-width: 190px;"/>
# </div>
# <div class="emsmoothsep"></div>
# <div class="emtitle emsmoothtext">
# Laptops
# </div>
# </a>, <a class="categorybox emsmoothhover" href="https://www.cyberpuerta.mx/Computo-Hardware/Monitores/Monitores/">
# <div class="empicture">
# <img alt="Monitores" src="https://www.cyberpuerta.mx/out/pictures/master/category/icon/monitores(1).png" style="max-height: 180px; max-width: 190px;"/>
# </div>
# <div class="emsmoothsep"></div>
# <div class="emtitle emsmoothtext">
# Monitores
# </div>
# </a>, <a class="categorybox emsmoothhover" href="https://www.cyberpuerta.mx/Impresion-y-Copiado/Consumibles-para-Impresoras/Toner/">
# <div class="empicture">
# <img alt="Tóner" src="https://www.cyberpuerta.mx/out/pictures/master/category/icon/toner2.png" style="max-height: 180px; max-width: 190px;"/>
# </div>
# <div class="emsmoothsep"></div>
# <div class="emtitle emsmoothtext">
# Tóner
# </div>
# </a>, <a class="categorybox emsmoothhover" href="https://www.cyberpuerta.mx/Computo-Hardware/Componentes/Procesadores/Procesadores-para-PC/">
# <div class="empicture">
# <img alt="Procesadores para PC" src="https://www.cyberpuerta.mx/out/pictures/master/category/icon/procesador-ryzen.png" style="max-height: 180px; max-width: 190px;"/>
# </div>
# <div class="emsmoothsep"></div>
# <div class="emtitle emsmoothtext">
# Procesadores para PC
# </div>
# </a>, <a class="categorybox emsmoothhover" href="https://www.cyberpuerta.mx/Computo-Hardware/Discos-Duros-SSD-NAS/SSD/">
# <div class="empicture">
# <img alt="SSD" src="https://www.cyberpuerta.mx/out/pictures/master/category/icon/ssds.png" style="max-height: 180px; max-width: 190px;"/>
# </div>
# <div class="emsmoothsep"></div>
# <div class="emtitle emsmoothtext">
# SSD
# </div>
# </a>, <a class="categorybox emsmoothhover" href="https://www.cyberpuerta.mx/Computo-Hardware/Memorias-RAM-y-Flash/Memorias-RAM-para-PC/">
# <div class="empicture">
# <img alt="Memorias RAM para PC" src="https://www.cyberpuerta.mx/out/pictures/master/category/icon/memorias-ram-para-pc.png" style="max-height: 180px; max-width: 190px;"/>
# </div>
# <div class="emsmoothsep"></div>
# <div class="emtitle emsmoothtext">
# Memorias RAM para PC
# </div>
# </a>, <a class="categorybox emsmoothhover" href="https://www.cyberpuerta.mx/Impresion-y-Copiado/Impresoras-y-Multifuncionales/Multifuncionales/">
# <div class="empicture">
# <img alt="Multifuncionales" src="https://www.cyberpuerta.mx/out/pictures/master/category/icon/multi-laser.png" style="max-height: 180px; max-width: 190px;"/>
# </div>
# <div class="emsmoothsep"></div>
# <div class="emtitle emsmoothtext">
# Multifuncionales
# </div>
# </a>, <a class="categorybox emsmoothhover" href="https://www.cyberpuerta.mx/Computo-Hardware/Componentes/Tarjetas-Madre/">
# <div class="empicture">
# <img alt="Tarjetas Madre" src="https://www.cyberpuerta.mx/out/pictures/master/category/icon/motherboard2.png" style="max-height: 180px; max-width: 190px;"/>
# </div>
# <div class="emsmoothsep"></div>
# <div class="emtitle emsmoothtext">
# Tarjetas Madre
# </div>
# </a>, <a class="categorybox emsmoothhover" href="https://www.cyberpuerta.mx/Computadoras/PC-s-de-Escritorio/">
# <div class="empicture">
# <img alt="PC's de Escritorio" src="https://www.cyberpuerta.mx/out/pictures/master/category/icon/pc-escritorio.png" style="max-height: 180px; max-width: 190px;"/>
# </div>
# <div class="emsmoothsep"></div>
# <div class="emtitle emsmoothtext">
# PC's de Escritorio
# </div>
# </a>, <a class="contentbox emsmoothhover" href="https://www.cyberpuerta.mx/configurador-de-pc/">
# <div class="empicture">
# <img alt="Configurador de PC" src="https://www.cyberpuerta.mx/out/pictures/emstartcontentslider/20230112_63c0181ee6f2e.png" style="max-width: 180px; max-height: 70px;"/>
# </div>
# <div class="emsmoothsep"></div>
# <div class="emtitle emsmoothtext">
# Configurador de PC
# </div>
# </a>, <a class="contentbox emsmoothhover" href="https://www.cyberpuerta.mx/hp-buscador-de-consumibles/">
# <div class="empicture">
# <img alt="Buscador de consumibles HP" src="https://www.cyberpuerta.mx/out/pictures/emstartcontentslider/hp-buscador-hometool.png" style="max-width: 180px; max-height: 70px;"/>
# </div>
# <div class="emsmoothsep"></div>
# <div class="emtitle emsmoothtext">
# Buscador de consumibles HP
# </div>
# </a>, <a class="contentbox emsmoothhover" href="https://www.cyberpuerta.mx/Configurador-de-Memoria-Kingston/">
# <div class="empicture">
# <img alt="Configurador de memoria" src="https://www.cyberpuerta.mx/out/pictures/emstartcontentslider/20200618_5eebd62637392.png" style="max-width: 180px; max-height: 70px;"/>
# </div>
# <div class="emsmoothsep"></div>
# <div class="emtitle emsmoothtext">
# Configurador de memoria
# </div>
# </a>, <a class="contentbox emsmoothhover" href="https://www.cyberpuerta.mx/StarTech-com-ConXit-Configurador/">
# <div class="empicture">
# <img alt="Configurador de conectividad" src="https://www.cyberpuerta.mx/out/pictures/emstartcontentslider/530cbd545e662-5453badb4a360.png" style="max-width: 180px; max-height: 70px;"/>
# </div>
# <div class="emsmoothsep"></div>
# <div class="emtitle emsmoothtext">
# Configurador de conectividad
# </div>
# </a>, <a class="contentbox emsmoothhover" href="https://www.cyberpuerta.mx/Configurador-de-Cables-Manhattan/">
# <div class="empicture">
# <img alt="Connect-Pro" src="https://www.cyberpuerta.mx/out/pictures/emstartcontentslider/20200622_5ef12cb7b2ecd.png" style="max-width: 180px; max-height: 70px;"/>
# </div>
# <div class="emsmoothsep"></div>
# <div class="emtitle emsmoothtext">
# Connect-Pro
# </div>
# </a>, <a class="contentbox emsmoothhover" href="https://www.cyberpuerta.mx/Guias-de-Compra/">
# <div class="empicture">
# <img alt="Guías de Compra" src="https://www.cyberpuerta.mx/out/pictures/emstartcontentslider/20200618_5eebe83d786de.png" style="max-width: 180px; max-height: 70px;"/>
# </div>
# <div class="emsmoothsep"></div>
# <div class="emtitle emsmoothtext">
# Guías de Compra
# </div>
# </a>, <a class="contentbox emsmoothhover" href="https://www.cyberpuerta.mx/Tripp-Lite-Cable-Finder/">
# <div class="empicture">
# <img alt="Tripp Lite Cable Finder" src="https://www.cyberpuerta.mx/out/pictures/emstartcontentslider/tripplite-cable-finder.png" style="max-width: 180px; max-height: 70px;"/>
# </div>
# <div class="emsmoothsep"></div>
# <div class="emtitle emsmoothtext">
# Tripp Lite Cable Finder
# </div>
# </a>, <a class="contentbox emsmoothhover" href="https://www.cyberpuerta.mx/pc-chooser-journey/">
# <div class="empicture">
# <img alt="Encuentra la laptop perfecta" src="https://www.cyberpuerta.mx/out/pictures/emstartcontentslider/boton-chooser.png" style="max-width: 180px; max-height: 70px;"/>
# </div>
# <div class="emsmoothsep"></div>
# <div class="emtitle emsmoothtext">
# Encuentra la laptop perfecta
# </div>
# </a>, <a href="https://www.cyberpuerta.mx/Computo-Hardware/">hardware</a>, <a href="https://www.cyberpuerta.mx/Computadoras/PC-s-de-Escritorio/">computadoras</a>, <a href="https://www.cyberpuerta.mx/Computadoras/Laptops/">laptops</a>, <a href="https://www.cyberpuerta.mx/Impresion-y-Copiado/Impresoras-y-Multifuncionales/Impresoras/">impresoras</a>, <a href="https://www.cyberpuerta.mx/Computo-Hardware/Monitores/Monitores/">monitores</a>, <a href="https://www.cyberpuerta.mx/Computo-Hardware/Componentes/">componentes</a>, <a class="__cf_email__" data-cfemail="d2bbbcb4bd92b1abb0b7a0a2a7b7a0a6b3fcbfaa" href="/cdn-cgi/l/email-protection">[email protected]</a>, <a href="https://sellosdeconfianza.org.mx/MuestraCertificado.php?NUMERO_SERIE=MD_x042" onclick="newWindow = window.open('https://sellosdeconfianza.org.mx/MuestraCertificado.php?NUMERO_SERIE=MD_x042', 'Certificado', 'width=500,height=616,left=150,top=70,toolbar=0,menuBar=0,scrollBars=0 resizable=0' ); newWindow.focus(); return false;" target="_blank">
# <img alt="" src="//www.cyberpuerta.mx/out/pictures/wysiwigpro/amipci-datospersonales1.png" style="width: 102px;margin-top:0px">
# </img></a>, <a href="https://www.cyberpuerta.mx/Computo-Hardware/" style="text-decoration: none; color: #666666;">Hardware</a>, <a href="https://www.cyberpuerta.mx/Computadoras/" style="text-decoration: none; color: #666666;">Computadoras</a>, <a href="https://www.cyberpuerta.mx/Impresion-Copiado/" style="text-decoration: none; color: #666666;">Impresión</a>, <a href="https://www.cyberpuerta.mx/Audio-Video/" style="text-decoration: none; color: #666666;">Audio / Video</a>, <a href="https://www.cyberpuerta.mx/Energia/" style="text-decoration: none; color: #666666;">Energía</a>, <a href="https://www.cyberpuerta.mx/Por-Marca/APPLE/" style="text-decoration: none; color: #666666;">Apple</a>, <a href="https://www.cyberpuerta.mx/Seguridad-Vigilancia/" style="text-decoration: none; color: #666666;">Seguridad y vigilancia</a>, <a href="https://www.cyberpuerta.mx/Software/" style="text-decoration: none; color: #666666;">Software</a>, <a href="https://www.cyberpuerta.mx/Telecomunicacion/" style="text-decoration: none; color: #666666;">Telecomunicación</a>, <a href="/cdn-cgi/l/email-protection#264f48404966455f444354565343545247084b5e" style="
# font-size: 14px;
# color: #0066BB;
# text-decoration: none;
# ">
# <span class="__cf_email__" data-cfemail="90f9fef6ffd0f3e9f2f5e2e0e5f5e2e4f1befde8">[email protected]</span>
# </a>, <a href="https://www.facebook.com/Cyberpuerta" style="text-decoration: none;" target="_blank">
# <img src="https://www.cyberpuerta.mx/out/email/assets/fb@2x.png" width="24">
# </img></a>, <a href="https://twitter.com/cyberpuerta" style="text-decoration: none;" target="_blank">
# <img src="https://www.cyberpuerta.mx/out/email/assets/tw@2x.png" width="24">
# </img></a>, <a href="https://wa.me/5213347371360" style="text-decoration: none;" target="_blank">
# <img src="https://www.cyberpuerta.mx/out/pictures/footer/whats.png" width="24">
# </img></a>, <a href="https://discord.com/invite/wsbm5pZb7e" style="text-decoration: none;" target="_blank">
# <img src="https://www.cyberpuerta.mx/out/email/assets/discord.png" width="24">
# </img></a>, <a href="https://apps.apple.com/mx/app/cyberpuerta/id1636030641" style="text-decoration: none;" target="_blank">
# <img src="https://cyberpuerta.mx/out/pictures/footer/ButtonAppStore.png" width="107">
# </img></a>, <a href="https://play.google.com/store/apps/details?id=com.cyberpuerta&amp;hl=es_MX" style="text-decoration: none;" target="_blank">
# <img src="https://www.cyberpuerta.mx/out/pictures/footer/ButtonGooglePlay.png" width="107">
# </img></a>, <a href="https://appgallery.huawei.com/app/C106425283" style="text-decoration: none;" target="_blank">
# <img src="https://cyberpuerta.mx/out/pictures/footer/ButtonAppGallery.png" width="107">
# </img></a>, <a href="https://www.ekomi.es/testimonios-cyberpuerta.html" target="_blank" title="Cyberpuerta en Ekomi">
# <img alt="Ekomi" src="https://connect.ekomi.de/widget/AALYTJ5H68C8V1V-5.gif" style="display: block; margin: auto; height: 128px;">
# </img></a>, <a href="https://greatplacetowork.com.mx/" target="_blank" title="Great Place to Work">
# <img src="https://www.cyberpuerta.mx/out/pictures/wysiwigpro/GPTW2022.png">
# </img></a>, <a href="https://www.cyberpuerta.mx/Modos-de-Pago/" style="display: inline-block; ">
# <img src="https://www.cyberpuerta.mx/out/pictures/footer/pago.png" style="width: 32px; padding-right: 8px;">
# </img></a>, <a href="https://www.cyberpuerta.mx/Por-Marca/">Tiendas de marcas</a>, <a href="https://www.cyberpuerta.mx/Como-comprar/">¿Cómo comprar?</a>, <a href="https://www.cyberpuerta.mx/historial-de-pedidos/">Historial de pedidos</a>, <a href="https://www.cyberpuerta.mx/configurador-de-pc/">Configurador de PC</a>, <a href="https://www.cyberpuerta.mx/Preguntas-frequentes/">Preguntas frecuentes</a>, <a href="https://www.cyberpuerta.mx/Quienes-somos/">Quiénes somos</a>, <a href="https://www.cyberpuerta.mx/Condiciones-generales/">Condiciones generales</a>, <a href="https://www.cyberpuerta.mx/Condiciones-generales/#Aviso-privacidad">Aviso de privacidad</a>, <a href="https://www.cyberpuerta.mx/Proveedores/">¿Quieres ser proveedor?</a>, <a href="https://cyberpuerta.breezy.hr/" target="_blank">Únete a nuestro equipo</a>, <a class="cp-product-line" data-bind="attr:{href: link}">
# <div class="grid-x">
# <div class="cell shrink">
# </div>
# <div class="cell auto cp-product-line__title" data-bind="text: title"></div>
# <div class="cell shrink cp-product-line__icon">
# <span class="material-icons">chevron_right</span>
# </div>
# </div>
# </a>, <a class="submitButton--primary submitButton--full-width" data-bind="attr:{href: linkCompatibles}" rel="nofollow">
# Ver Care Packs
# </a>, <a data-bind="attr: {href: link}">
# <div class="product-pic-container">
# <img data-bind="attr: {src: picture, alt:title}"/>
# </div>
# </a>, <a data-bind="attr: {href: link, title: title, 'data-truncate': truncateTitle}, html: truncateTitle" data-text="">
# </a>, <a href="/cdn-cgi/l/email-protection#432a2d252c03203a2126313336263137226d2e3b"><span class="__cf_email__" data-cfemail="1a73747c755a7963787f686a6f7f686e7b347762">[email protected]</span></a>, <a data-bind="attr: {href: link}">
# <div class="product-pic-container">
# <img data-bind="attr: {src: picture, alt:title}"/>
# </div>
# </a>, <a data-bind="attr: {href: link, title: title, 'data-truncate': truncateTitle}, html: truncateTitle" data-text="">
# </a>, <a data-bind="attr: {href: link}">
# <div class="product-pic-container">
# <img data-bind="attr: {src: picture, alt:title}"/>
# </div>
# </a>, <a data-bind="attr: {href: link, title: title, 'data-truncate': truncateTitle}, html: truncateTitle" data-text="">
# </a>, <a data-bind="attr: {href: link}">
# <div class="product-pic-container">
# <img data-bind="attr: {src: picture, alt:title}"/>
# </div>
# </a>, <a data-bind="attr: {href: link, title: title, 'data-truncate': truncateTitle}, html: truncateTitle" data-text="">
# </a>]

# %% [markdown]
# #### <span style="color:blue">Como vemos no es una forma de filtrar la información.</span>
#
# #### <span style="color:blue">Para esto se nos permite agregarle filtros a nuestra busqueda.</span>
# #### <span style="color:green">Vamos a filtrar sus elementos por propiedades, clases, identificadores etc..</span>
# #### <span style="color:green">Como vemos que están desplegados en un arreglo podemos hacer la busqueda.</span>
# #### <span style="color:blue">Utilizando las Estructuras de Control como un (for) para poder iterar o filtrar los datos.</span>
# #### <span style="color:red">Nota:Como la etiqueta a está dentro de un "h3" la busqueda se realiza desde ahi para desplgar las etiquetas "a" .</span>

# %%
titulo_items = soup.find_all('a')

for items in titulo_items:
    titulo = items.a
    print(titulo)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %% [markdown]
# #### <span style="color:blue">Como podemos obtener directamente los titulos que se encuentran dentro de "h3" y dentro de "a" se filtrar:</span>
#
# #### <span style="color:blue">Podemos acceder directamente a los atributos de cada registo.</span>
# #### <span style="color:red">Pidiendo que acceda directaemente al atributo titulo.</span>

# %%
titulo_items = soup.find_all('h3')

for items in titulo_items:
    titulo = items.a
    print(titulo['title'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\mapko\OneDrive\Desktop\Python 3 Intermedio\scraping\Web Scraping.ipynb Cell 29 in 5
#       <a href='vscode-notebook-cell:/c%3A/Users/mapko/OneDrive/Desktop/Python%203%20Intermedio/scraping/Web%20Scraping.ipynb#X40sZmlsZQ%3D%3D?line=2'>3</a> for items in titulo_items:
#       <a href='vscode-notebook-cell:/c%3A/Users/mapko/OneDrive/Desktop/Python%203%20Intermedio/scraping/Web%20Scraping.ipynb#X40sZmlsZQ%3D%3D?line=3'>4</a>     titulo = items.a
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mapko/OneDrive/Desktop/Python%203%20Intermedio/scraping/Web%20Scraping.ipynb#X40sZmlsZQ%3D%3D?line=4'>5</a>     print(titulo['title'])
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# #### <span style="color:yellow">Podemos guardar la informción en un arreglo vacio llamado "titulos"</span>

# %%
titulos = []

titulo_items = soup.find_all('h3')

for items in titulo_items:
    titulo = items.a
    print(titulo['title'])
    titulos.append(titulo['title'])
# Out:
# A Light in the Attic
# Tipping the Velvet
# Soumission
# Sharp Objects
# Sapiens: A Brief History of Humankind
# The Requiem Red
# The Dirty Little Secrets of Getting Your Dream Job
# The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull
# The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics
# The Black Maria
# Starving Hearts (Triangular Trade Trilogy, #1)
# Shakespeare's Sonnets
# Set Me Free
# Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)
# Rip it Up and Start Again
# Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991
# Olio
# Mesaerion: The Best Science Fiction Stories 1800-1849
# Libertarianism for Beginners
# It's Only the Himalayas

# %% [markdown]
# #### <span style="color:yellow">Tenemos una lista de titulos guardados en un arreglo llamado "titulos" </span>

# %%
titulos
# Out:
# ['A Light in the Attic',
#  'Tipping the Velvet',
#  'Soumission',
#  'Sharp Objects',
#  'Sapiens: A Brief History of Humankind',
#  'The Requiem Red',
#  'The Dirty Little Secrets of Getting Your Dream Job',
#  'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#  'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#  'The Black Maria',
#  'Starving Hearts (Triangular Trade Trilogy, #1)',
#  "Shakespeare's Sonnets",
#  'Set Me Free',
#  "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)",
#  'Rip it Up and Start Again',
#  'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991',
#  'Olio',
#  'Mesaerion: The Best Science Fiction Stories 1800-1849',
#  'Libertarianism for Beginners',
#  "It's Only the Himalayas"]

# %% [markdown]
# #### <span style="color:yellow">Depues de obtener y guardar los titulos. La tarea es guardar los demás elementos.</span>

# %% [markdown]
# #### <span style="color:yellow">Vamos a acceder al (precio) y guardarlo en un arreglo vacio llamado "precio[]". Tambien creamos una variable</span>
# #### <span style="color:yellow">llamada precio_items donde utilizaremos las mismas propiedades. Utilizando mi codigo fuente (soup),</span>
# #### <span style="color:yellow">buscamos todas las etiquetas (p) cuya clase es (price_color). Y cuando despleguemos "precio_items" </span>
# #### <span style="color:yellow">vamos a obtener todas las etiquetas (p) con la clase (price_color) con sus precios.</span>

# %%
precio = []

precio_items = soup.find_all( 'p', class_= 'price_color')

print(precio_items)
# Out:
# [<p class="price_color">Â£51.77</p>, <p class="price_color">Â£53.74</p>, <p class="price_color">Â£50.10</p>, <p class="price_color">Â£47.82</p>, <p class="price_color">Â£54.23</p>, <p class="price_color">Â£22.65</p>, <p class="price_color">Â£33.34</p>, <p class="price_color">Â£17.93</p>, <p class="price_color">Â£22.60</p>, <p class="price_color">Â£52.15</p>, <p class="price_color">Â£13.99</p>, <p class="price_color">Â£20.66</p>, <p class="price_color">Â£17.46</p>, <p class="price_color">Â£52.29</p>, <p class="price_color">Â£35.02</p>, <p class="price_color">Â£57.25</p>, <p class="price_color">Â£23.88</p>, <p class="price_color">Â£37.59</p>, <p class="price_color">Â£51.33</p>, <p class="price_color">Â£45.17</p>]

# %% [markdown]
# #### <span style="color:yellow">Para poder obtener el text precio vamos a utilizar un Estructura de Control (for).</span>
#
# #### <span style="color:yellow">Por cada elemento del arreglo vamos a definir un variable precio y se va asignar su propiedad texto.</span>
#
# #### <span style="color:red">Si corremos el ciclo  desplegamos precio vamos a obtener un arreglo de precios.</span>

# %%
precios = []

precio_items = soup.find_all('p', class_= 'price_color')

for item in precio_items:
    precio = item.text
    precios.append(precio)

# %% [markdown]
# #### <span style="color:red">Podemos observar que la información no está limpia. El arreglo precios tiene un caracter raro.</span>
# #### <span style="color:red">Debemos de quitar ese caracter y convertirlo de tipo texto a tipo numerico.</span>

# %%
precios
# Out:
# ['Â£51.77',
#  'Â£53.74',
#  'Â£50.10',
#  'Â£47.82',
#  'Â£54.23',
#  'Â£22.65',
#  'Â£33.34',
#  'Â£17.93',
#  'Â£22.60',
#  'Â£52.15',
#  'Â£13.99',
#  'Â£20.66',
#  'Â£17.46',
#  'Â£52.29',
#  'Â£35.02',
#  'Â£57.25',
#  'Â£23.88',
#  'Â£37.59',
#  'Â£51.33',
#  'Â£45.17']

# %% [markdown]
# #### <span style="color:yellow">Ahora vamos a buscar el texto donde nos diga si el item existe en tienda.</span>
#
# #### <span style="color:yellow">Vamos a crear un arreglo vacio llamado (existencia ) Y definimos el código de busqueda en la pagina Web.</span>
#
# #### <span style="color:red">Si corremos el ciclo  desplegamos el texto de existencia y vamos a obtener un arreglo de precios.</span>

# %%
existencias = []

existencia_items = soup.find_all('p', class_= 'instock availability')

for item in existencia_items:
    existencia = item.text
    existencias.append(existencia)

# %%
existencias
# Out:
# ['\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n',
#  '\n\n    \n        In stock\n    \n']

# %% [markdown]
# #### <span style="color:red">Podemos observar que la información no está limpia. El arreglo existencia tiene un caracter de salto de linea.</span>
# #### <span style="color:red">Debemos de quitar esos caracteres.</span>

# %% [markdown]
# #### <span style="color:yellow">Ahora vamos extraer el rating de la pagina web o sea las estrellitas.</span>
#
# #### <span style="color:yellow">Vamos a crear un arreglo llamado (ratings) seguido de una función la cual llamaremos extraer ratings</span>
#
# #### <span style="color:red">Si corremos el ciclo  desplegamos el rating de cada item.</span>

# %%
ratings = []

def extraer_ratings(soup):
    page_items = soup.find_all('p', class_= 'star-rating')

    for item in page_items:
        ratings.append(item['class'][1])

# %% [markdown]
# #### <span style="color:yellow">Este proceso es parecido a todos los anteriores para buscar el rating de la pagina web o sea las estrellitas.</span>
#
# #### <span style="color:yellow">.</span>

# %%
ratings = []

rating_items = soup.find_all('p', class_= 'star-rating')

print(rating_items)
# Out:
# [<p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Four">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Four">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Four">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Two">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Four">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Two">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Two">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>]

# %% [markdown]
# #### <span style="color:yellow">Este proceso es parecido a todos los anteriores para buscar las estrellitas del rating de la pagina web.</span>

# %%
ratings = []

rating_items = soup.find_all('p', class_= 'star-rating')

for item in rating_items:
    rating = item['class']

print(rating_items)
# Out:
# [<p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Four">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Four">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Four">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Two">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Four">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Two">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>, <p class="star-rating Two">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>]

# %% [markdown]
# #### <span style="color:yellow">Vamos a desplegar el segundo valor del parrafo 1er ("star-rating) 2do valor ("Three) <p class="star-rating Three"> del rating de la pagina web.</span>

# %%
ratings = []

rating_items = soup.find_all('p', class_= 'star-rating')

for item in rating_items:
    rating = item['class'][1]
    ratings.append(rating)

# %%
ratings
# Out:
# ['Three',
#  'One',
#  'One',
#  'Four',
#  'Five',
#  'One',
#  'Four',
#  'Three',
#  'Four',
#  'One',
#  'Two',
#  'Four',
#  'Five',
#  'Five',
#  'Five',
#  'Three',
#  'One',
#  'One',
#  'Two',
#  'Two']

# %% [markdown]
# #### <span style="color:yellow">Por último vamos a unificar y desplegar al mismo tiempo lo que se obtuvbo de la página web.</span>

# %% [markdown]
# #### <span style="color:yellow">Vamos a crear un diccionario llamada DataFrame .</span>

# %%
import pandas as pd

Data_extraction = {
    'Titulo':titulos,
    'Precio':precios,
    'Raiting':rating,
    'Existencia':existencias      
    }

df = pd.DataFrame(Data_extraction)

# %% [markdown]
# #### <span style="color:yellow">Vamos a crear un nuevo Dataframe con nuestros diccionario creado llamado Data_extraction</span>

# %%
df
# Out:
#                                                Titulo   Precio Raiting  \
# 0                                A Light in the Attic  Â£51.77     Two
# 1                                  Tipping the Velvet  Â£53.74     Two
# 2                                          Soumission  Â£50.10     Two
# 3                                       Sharp Objects  Â£47.82     Two
# 4               Sapiens: A Brief History of Humankind  Â£54.23     Two
# 5                                     The Requiem Red  Â£22.65     Two
# 6   The Dirty Little Secrets of Getting Your Dream...  Â£33.34     Two
# 7   The Coming Woman: A Novel Based on the Life of...  Â£17.93     Two
# 8   The Boys in the Boat: Nine Americans and Their...  Â£22.60     Two
# 9                                     The Black Maria  Â£52.15     Two
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  Â£13.99     Two
# 11                              Shakespeare's Sonnets  Â£20.66     Two
# 12                                        Set Me Free  Â£17.46     Two
# 13  Scott Pilgrim's Precious Little Life (Scott Pi...  Â£52.29     Two
# 14                          Rip it Up and Start Again  Â£35.02     Two
# 15  Our Band Could Be Your Life: Scenes from the A...  Â£57.25     Two
# 16                                               Olio  Â£23.88     Two
# 17  Mesaerion: The Best Science Fiction Stories 18...  Â£37.59     Two
# 18                       Libertarianism for Beginners  Â£51.33     Two
# 19                            It's Only the Himalayas  Â£45.17     Two
#
#                             Existencia
# 0   \n\n    \n        In stock\n    \n
# 1   \n\n    \n        In stock\n    \n
# 2   \n\n    \n        In stock\n    \n
# 3   \n\n    \n        In stock\n    \n
# 4   \n\n    \n        In stock\n    \n
# 5   \n\n    \n        In stock\n    \n
# 6   \n\n    \n        In stock\n    \n
# 7   \n\n    \n        In stock\n    \n
# 8   \n\n    \n        In stock\n    \n
# 9   \n\n    \n        In stock\n    \n
# 10  \n\n    \n        In stock\n    \n
# 11  \n\n    \n        In stock\n    \n
# 12  \n\n    \n        In stock\n    \n
# 13  \n\n    \n        In stock\n    \n
# 14  \n\n    \n        In stock\n    \n
# 15  \n\n    \n        In stock\n    \n
# 16  \n\n    \n        In stock\n    \n
# 17  \n\n    \n        In stock\n    \n
# 18  \n\n    \n        In stock\n    \n
# 19  \n\n    \n        In stock\n    \n

# %% [markdown]
# #### <span style="color:yellow">Y desplegamos nuestro nuevo DataFrame llamado df_Extraction</span>

# %%
df
# Out:
#                                                Titulo   Precio Raiting  \
# 0                                A Light in the Attic  Â£51.77     Two
# 1                                  Tipping the Velvet  Â£53.74     Two
# 2                                          Soumission  Â£50.10     Two
# 3                                       Sharp Objects  Â£47.82     Two
# 4               Sapiens: A Brief History of Humankind  Â£54.23     Two
# 5                                     The Requiem Red  Â£22.65     Two
# 6   The Dirty Little Secrets of Getting Your Dream...  Â£33.34     Two
# 7   The Coming Woman: A Novel Based on the Life of...  Â£17.93     Two
# 8   The Boys in the Boat: Nine Americans and Their...  Â£22.60     Two
# 9                                     The Black Maria  Â£52.15     Two
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  Â£13.99     Two
# 11                              Shakespeare's Sonnets  Â£20.66     Two
# 12                                        Set Me Free  Â£17.46     Two
# 13  Scott Pilgrim's Precious Little Life (Scott Pi...  Â£52.29     Two
# 14                          Rip it Up and Start Again  Â£35.02     Two
# 15  Our Band Could Be Your Life: Scenes from the A...  Â£57.25     Two
# 16                                               Olio  Â£23.88     Two
# 17  Mesaerion: The Best Science Fiction Stories 18...  Â£37.59     Two
# 18                       Libertarianism for Beginners  Â£51.33     Two
# 19                            It's Only the Himalayas  Â£45.17     Two
#
#                             Existencia
# 0   \n\n    \n        In stock\n    \n
# 1   \n\n    \n        In stock\n    \n
# 2   \n\n    \n        In stock\n    \n
# 3   \n\n    \n        In stock\n    \n
# 4   \n\n    \n        In stock\n    \n
# 5   \n\n    \n        In stock\n    \n
# 6   \n\n    \n        In stock\n    \n
# 7   \n\n    \n        In stock\n    \n
# 8   \n\n    \n        In stock\n    \n
# 9   \n\n    \n        In stock\n    \n
# 10  \n\n    \n        In stock\n    \n
# 11  \n\n    \n        In stock\n    \n
# 12  \n\n    \n        In stock\n    \n
# 13  \n\n    \n        In stock\n    \n
# 14  \n\n    \n        In stock\n    \n
# 15  \n\n    \n        In stock\n    \n
# 16  \n\n    \n        In stock\n    \n
# 17  \n\n    \n        In stock\n    \n
# 18  \n\n    \n        In stock\n    \n
# 19  \n\n    \n        In stock\n    \n

# %%
page = requests.get('https://www.cyberpuerta.mx/Promociones/')

soup = BeautifulSoup(page.text, 'html.parser')

print(soup.prettify())


print(soup)
# Out:
# <!DOCTYPE HTML>
# <html lang="es">
#  <head>
#   <link href="https://www.cyberpuerta.mx/out/generated/cms-pages.css?1593624763" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/em.selectbox.css?1690214375" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headerlogin.css?1690214375" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headernotice.css?1690214375" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headercompare.css?1690214375" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headerhelp.css?1690214375" rel="stylesheet" type="text/css"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/src/css/oxwidget_headerminibasket.css?1690214375" rel="stylesheet" type="text/css"/>
#   <link data-cp-orig="cdn.Swiper.css" href="https://cdnjs.cloudflare.com/ajax/libs/Swiper/4.3.5/css/swiper.min.css" rel="stylesheet" type="text/css"/>
#   <link data-cp-orig="cp.app.legacy.css" href="https://www.cyberpuerta.mx/out/dist/cp.app.legacy.c6cd68cd7a9e818b946e.g.css" rel="stylesheet" type="text/css"/>
#   <link data-cp-orig="cp.app.foundation.css" href="https://www.cyberpuerta.mx/out/dist/cp.app.foundation.e29b346a69794f0187d9.g.css" rel="stylesheet" type="text/css"/>
#   <link data-cp-orig="cp.app.css" href="https://www.cyberpuerta.mx/out/dist/cp.app.2597a5763d93a7d4fff0.g.css" rel="stylesheet" type="text/css"/>
#   <link data-cp-orig="vendors~cp.app.css" href="https://www.cyberpuerta.mx/out/dist/vendors~cp.app.f79cffac28db61b5a671.g.css" rel="stylesheet" type="text/css"/>
#   <link data-cp-orig="cdn.material-icons.css" href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet" type="text/css"/>
#   <link data-cp-orig="cdn.open-sans.css" href="https://fonts.googleapis.com/css?family=Open+Sans:400,700&amp;display=swap" rel="stylesheet" type="text/css"/>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#         let loginCookieMatch = document.cookie.match(/\bcpcautologin=([^;]+)/);
#         let loginCookie = loginCookieMatch ? loginCookieMatch[1] : null;
#
#         // gtm Cookie to be sent to get prediction from Google Recommendations AI
#         let gtmCookie = null;
#         function getCookie(cName) {
#           const name = cName + "=";
#           const cDecoded = decodeURIComponent(document.cookie); //to be careful
#           const cArr = cDecoded.split('; ');
#           let res;
#           cArr.forEach(val => {
#             if (val.indexOf(name) === 0) res = val.substring(name.length);
#           })
#           return res
#         }
#
#         window.onload = function() {
#             gtmCookie = getCookie("_ga");
#         };
#
#         // If in the query string is utm_campaign, set it in a cookie
#
#         // section to define variable to send information to another project "CP Cyberpuerta production"
#         var _gre = _gre || [];
#         // Credentials for project.
#         _gre.push(['apiKey', 'AIzaSyAOwVGpimHdB81KmBDgnKta0wxX9RqszKE']);
#         _gre.push(['projectId', 'cyberpuerta-144818']);
#         _gre.push(['locationId', 'global']);
#         _gre.push(['catalogId', 'default_catalog']);
#
#         let justOne = true;
#
#         window.onload = function() {
#             if ( justOne ) {
#                 var gre = document.createElement('script'); gre.type = 'text/javascript'; gre.async = true;
#                 gre.src = 'https://www.gstatic.com/retail/v2_event.js';
#                 var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(gre, s);
#                 justOne = false;
#             }
#         };
#
#                     dataLayer.push(
#                 {"shop_cl":"alist"}
#             );
#                     dataLayer.push(
#                 {"ab1047_pixel":0}
#             );
#                     dataLayer.push(
#                 {"sess_tk":"18BC8298"}
#             );
#                     dataLayer.push(
#                 {"internal_user":0}
#             );
#                     dataLayer.push(
#                 {"rai_active":true}
#             );
#                     dataLayer.push(
#                 {"new_customer":false}
#             );
#                     dataLayer.push(
#                 {"fresh":{"tags":["promociones"]}}
#             );
#
#         dataLayer.push({
#             api_version: 'v0.1'
#         })
#
#
#                                                     dataLayer.push({'Referer':'(direct)'});
#                 dataLayer.push({'firstaccess':'y'});
#
#                             // If is a search page or is a category/manufacturer page but comes from a search
#                             dataLayer.push({'pageview': '/alist - Promociones'});
#
#
#
#
#
#                             dataLayer.push({
#                 'ecomm_prodid': '',
#                 'ecomm_totalvalue': 0,
#                 'nl': 'n'
#             });
#
#             //IT-3502
#             //todo: implement for CP mobile, currently we dont send articles
#             //from cpfacebookpixel_category.tpl
#
#
#
#
#
#
#
#
#
#
#
#
#             window.dataLayer.push({
#                     'category': {
#                         'products': ['RX6650XT CLD 8GO','CA-1X2-00M1WN-00','PRO B660M-A WIFI DDR4','C31CH51001','BX8071512100','20MK400H-B','OGMM01','OGEM02','OGMM03','OGEM01'],                         'path': 'Inicio>Promociones',
#                         'name': 'Promociones'
#                     }
#             });
#             //In CP mobile we send the event after get articles(ajax)
#                                             //IT-4010 ask for an eventId
#                                 window.dataLayer.push({
#                     'event': 'categoryPageView',
#                     'fbCategoryId': 'catman64beba6e7ec788.66555417'
#                 });
#
#                 /** GA4Event */
#                 dataLayer.push({
#                     'event': 'view_item_list',
#                     'ecommerce': {
#                         'items': [
#                                                             {
#                                     'item_name': 'Tarjeta de Video ASRock AMD Radeon RX 6650 XT Challenger D OC, 8GB 128-Bit GDDR6, PCI Express 4.0 ― ¡Compra y llévate de regalo Starfield!',
#                                     'item_id': 'RX6650XT CLD 8GO',
#                                     'price': 4379,
#                                                                         'item_brand': 'ASROCK',
#                                                                                                                                                                                                                                             'item_category': 'Cómputo (Hardware)',
#                                                                                                                                 'item_category2': 'Componentes',
#                                                                                                                                 'item_category3': 'Tarjetas de Video',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 1
#                                 },
#                                                             {
#                                     'item_name': 'Gabinete Thermaltake S200 TG ARGB con Ventana, Midi-Tower, ATX/Micro ATX/Mini-ITX, USB 3.0, sin Fuente, 3 Ventiladores Instalados ARGB, Negro',
#                                     'item_id': 'CA-1X2-00M1WN-00',
#                                     'price': 1139,
#                                                                         'item_brand': 'THERMALTAKE',
#                                                                                                                                                                                                                                             'item_category': 'Cómputo (Hardware)',
#                                                                                                                                 'item_category2': 'Componentes',
#                                                                                                                                 'item_category3': 'Gabinetes',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 2
#                                 },
#                                                             {
#                                     'item_name': 'Tarjeta Madre MSI Micro-ATX PRO B660M-A WIFI DDR4, S-1700, Intel B660, HDMI, 128GB DDR4 para Intel ― Requiere Actualización de BIOS para Procesadores Intel 13va. Generación',
#                                     'item_id': 'PRO B660M-A WIFI DDR4',
#                                     'price': 1969,
#                                                                         'item_brand': 'MSI',
#                                                                                                                                                                                                                                             'item_category': 'Cómputo (Hardware)',
#                                                                                                                                 'item_category2': 'Componentes',
#                                                                                                                                 'item_category3': 'Tarjetas Madre',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 3
#                                 },
#                                                             {
#                                     'item_name': 'Epson TM-T20III Impresora de Tickets, Térmico, 203 x 203DPI, Serial/USB, Negro',
#                                     'item_id': 'C31CH51001',
#                                     'price': 3769,
#                                                                         'item_brand': 'EPSON',
#                                                                                                                                                                                                                                             'item_category': 'Punto de Venta (POS)',
#                                                                                                                                 'item_category2': 'Impresoras de Tickets',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 4
#                                 },
#                                                             {
#                                     'item_name': 'Procesador Intel Core i3-12100, S-1700, 3.30GHz, Quad-Core, 12MB Smart Cache (12va.  Generación - Alder Lake)',
#                                     'item_id': 'BX8071512100',
#                                     'price': 2139,
#                                                                         'item_brand': 'INTEL',
#                                                                                                                                                                                                                                             'item_category': 'Cómputo (Hardware)',
#                                                                                                                                 'item_category2': 'Componentes',
#                                                                                                                                 'item_category3': 'Procesadores',
#                                                                                                                                 'item_category4': 'Procesadores para PC',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 5
#                                 },
#                                                             {
#                                     'item_name': 'Monitor LG 20MK400H-B LED 19.5\", WXGA, 60Hz, HDMI, Negro',
#                                     'item_id': '20MK400H-B',
#                                     'price': 1239,
#                                                                         'item_brand': 'LG',
#                                                                                                                                                                                                                                             'item_category': 'Cómputo (Hardware)',
#                                                                                                                                 'item_category2': 'Monitores',
#                                                                                                                                 'item_category3': 'Monitores',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 6
#                                 },
#                                                             {
#                                     'item_name': 'Mouse Gamer Ocelot Gaming Óptico OGMM01, Alámbrico, USB A, 6400DPI, Negro',
#                                     'item_id': 'OGMM01',
#                                     'price': 88,
#                                                                         'item_brand': 'OCELOT GAMING',
#                                                                                                                                                                                                                                             'item_category': 'Cómputo (Hardware)',
#                                                                                                                                 'item_category2': 'Dispositivos de Entrada',
#                                                                                                                                 'item_category3': 'Mouse',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 7
#                                 },
#                                                             {
#                                     'item_name': 'Mouse Gamer Ocelot Gaming Óptico OGEM02, Alámbrico, USB A, 2400DPI, Negro',
#                                     'item_id': 'OGEM02',
#                                     'price': 87,
#                                                                         'item_brand': 'OCELOT GAMING',
#                                                                                                                                                                                                                                             'item_category': 'Cómputo (Hardware)',
#                                                                                                                                 'item_category2': 'Dispositivos de Entrada',
#                                                                                                                                 'item_category3': 'Mouse',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 8
#                                 },
#                                                             {
#                                     'item_name': 'Mouse Gamer Ocelot Gaming Óptico OGMM03, Alámbrico, USB A, 3200DPI, Negro/Rosa',
#                                     'item_id': 'OGMM03',
#                                     'price': 94,
#                                                                         'item_brand': 'OCELOT GAMING',
#                                                                                                                                                                                                                                             'item_category': 'Cómputo (Hardware)',
#                                                                                                                                 'item_category2': 'Dispositivos de Entrada',
#                                                                                                                                 'item_category3': 'Mouse',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 9
#                                 },
#                                                             {
#                                     'item_name': 'Mouse Gamer Ocelot Gaming Óptico OGEM01, Alámbrico, USB A, 2400DPI, Negro',
#                                     'item_id': 'OGEM01',
#                                     'price': 103,
#                                                                         'item_brand': 'OCELOT GAMING',
#                                                                                                                                                                                                                                             'item_category': 'Cómputo (Hardware)',
#                                                                                                                                 'item_category2': 'Dispositivos de Entrada',
#                                                                                                                                 'item_category3': 'Mouse',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 10
#                                 },
#                                                             {
#                                     'item_name': 'SSD Kingston A400, 120GB, SATA III, M.2',
#                                     'item_id': 'SA400M8/120G',
#                                     'price': 306,
#                                                                         'item_brand': 'KINGSTON',
#                                                                                                                                                                                                                                             'item_category': 'Cómputo (Hardware)',
#                                                                                                                                 'item_category2': 'Discos Duros - SSD - NAS',
#                                                                                                                                 'item_category3': 'SSD',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 11
#                                 },
#                                                             {
#                                     'item_name': 'X-Case Caja ACCREDKE10, 1x RJ-45, 10 Piezas',
#                                     'item_id': 'ACCREDKE10',
#                                     'price': 42,
#                                                                         'item_brand': 'X-CASE',
#                                                                                                                                                                                                                                             'item_category': 'Cómputo (Hardware)',
#                                                                                                                                 'item_category2': 'Cables',
#                                                                                                                                 'item_category3': 'Accesorios para Cables',
#                                                                                                                                 'item_category4': 'Tapas y Cajas',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 12
#                                 },
#                                                             {
#                                     'item_name': 'POSline Papel Bond RP1C7670, 76mm x 70mm, 50 Piezas',
#                                     'item_id': '2003002',
#                                     'price': 19,
#                                                                         'item_brand': 'POSLINE',
#                                                                                                                                                                                                                                             'item_category': 'Impresión y Copiado',
#                                                                                                                                 'item_category2': 'Papeles para Impresoras',
#                                                                                                                                 'item_category3': 'Papel POS',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 13
#                                 },
#                                                             {
#                                     'item_name': 'Memoria RAM Adata AD5U48008G-S DDR5, 4800MHz, 8GB, ECC, CL40',
#                                     'item_id': 'AD5U48008G-S',
#                                     'price': 442,
#                                                                         'item_brand': 'ADATA',
#                                                                                                                                                                                                                                             'item_category': 'Cómputo (Hardware)',
#                                                                                                                                 'item_category2': 'Memorias RAM y Flash',
#                                                                                                                                 'item_category3': 'Memorias RAM para PC',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 14
#                                 },
#                                                             {
#                                     'item_name': 'SSD Western Digital WD_Black SN770 NVMe, 1TB, PCI Express 4.0, M.2',
#                                     'item_id': 'WDS100T3X0E',
#                                     'price': 1039,
#                                                                         'item_brand': 'WESTERN DIGITAL',
#                                                                                                                                                                                                                                             'item_category': 'Cómputo (Hardware)',
#                                                                                                                                 'item_category2': 'Discos Duros - SSD - NAS',
#                                                                                                                                 'item_category3': 'SSD',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 15
#                                 },
#                                                             {
#                                     'item_name': 'Mouse Gamer Logitech Óptico G203 LightSync, Alámbrico, USB, 8000DPI, Lila',
#                                     'item_id': '910-005852',
#                                     'price': 302,
#                                                                         'item_brand': 'LOGITECH',
#                                                                                                                                                                                                                                             'item_category': 'Cómputo (Hardware)',
#                                                                                                                                 'item_category2': 'Dispositivos de Entrada',
#                                                                                                                                 'item_category3': 'Mouse',
#                                                                                                                                                             'item_list_name': 'category',
#                                     'item_variant': 'NA',
#                                     'index': 16
#                                 },
#                                                     ]
#                     }
#                 });
#
#
#                 if (window.cpGa && window.cpGa.ecProdImp && window.cpGa.ecProdImp.length > 0) {
#             dataLayer.push({
#                 'ecommerce': {
#                     'impressions': window.cpGa.ecProdImp
#                 }
#             });
#         }
#   </script>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){
#             w[l]=w[l]||[];w[l].push({
#                 'gtm.start': new Date().getTime(),'event':'gtm.js'
#             });
#             var f=d.getElementsByTagName(s)[0],
#                 j=d.createElement(s),
#                 dl=l!='dataLayer'?'&l='+l:'';
#             j.async=true;
#             j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window, document, 'script', 'dataLayer', 'GTM-TZF4FD');
#
#
#
#
#                                 let addToCart=null;
#
#
#             // If request isn't from a search, registry eventType as category-page-view
#                             //Google Recommendations AI category-page-view
#                 const categoryPageView = {
#                     'cloud_retail': {
#                         'eventType': 'category-page-view',
#                         //Removes starting and ending '/' and replaces inner '/' with ' > '
#                         'pageCategories': [window.location.pathname.replace(/^\/|\/$/g, '').replace(/\//g, ' > ')],
#                     }
#                 };
#
#                 categoryPageView.cloud_retail.visitorId = gtmCookie ? gtmCookie : loginCookie;
#                 dataLayer.push(categoryPageView);
#
#                 categoryPageView.cloud_retail.visitorId = getCookie("_ga");
#
#                 if ( !categoryPageView.cloud_retail.visitorId ) {
#                     categoryPageView.cloud_retail.visitorId = "GA1.2.1758256664.1659050322";
#                 }
#
#                 _gre.push(['logEvent', categoryPageView.cloud_retail]);
#
#             dataLayer.push({
#                 'event': 'track_content_group',
#                 'content_group': 'Listing'
#             });
#
#
#
#
#         //criteo pixel $oxcmp_utils->emcriteo_active()
#                     dataLayer.push({
#                 'criteo_data': [{"event":"setAccount","account":6218},{"event":"setSiteType","type":"d"},{"event":"setHashedEmail","email":""},{"event":"viewList","item":["RX6650XT CLD 8GO","CA-1X2-00M1WN-00","PRO B660M-A WIFI DDR4","C31CH51001"]}]
#             })
#   </script>
#   <!-- End Google Tag Manager -->
#   <script id="cp-category-view-data" type="application/json">
#    {"id":"4fadfd9ad0936","type":"cat","articleList":null,"linkToCompare":{"id":null,"title":"Comparaci\u00f3n de producto","url":"https://www.cyberpuerta.mx/index.php?cl=compare","image":null},"categoryAncestors":["4fadfd9ad0936"],"listMode":null,"pageSize":null,"page":0,"cpsp":{}}
#   </script>
#   <script id="cp-user-info-view-data" type="application/json">
#    {"isLoggedIn":false,"isBaseLogin":false,"picture":"https:\/\/www.cyberpuerta.mx\/out\/cyberpuertaV5\/img\/userblank.png","name":null,"nameAccount":null,"accountUrls":[],"defaultPicture":null,"email":null,"id":null,"saldo":{"active":false,"amount":0,"minimumOrderValue":0},"clientReference":null,"anonId":null,"zip":null,"emailActivation":true,"salesman":null,"isProcurement":null,"extraData":null,"identityVerificationStatus":null}
#   </script>
#   <meta content="width=device-width,initial-scale=1.0" name="viewport"/>
#   <title>
#    Promociones | Cyberpuerta.mx
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"4879248977",applicationID:"66344412"};;/*! For license information please see nr-loader-rum-1.236.0.min.js.LICENSE.txt */
# (()=>{"use strict";var e,t,n={5763:(e,t,n)=>{n.d(t,{P_:()=>f,Mt:()=>p,C5:()=>s,DL:()=>m,OP:()=>_,lF:()=>E,Yu:()=>y,Dg:()=>g,CX:()=>c,GE:()=>b,sU:()=>j});var r=n(8632),i=n(9567);const o={beacon:r.ce.beacon,errorBeacon:r.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},a={};function s(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!a[e])throw new Error("Info for ".concat(e," was never set"));return a[e]}function c(e,t){if(!e)throw new Error("All info objects require an agent identifier!");a[e]=(0,i.D)(t,o),(0,r.Qy)(e,a[e],"info")}var d=n(7056);const u=()=>{const e={blockSelector:"[data-nr-block]",maskInputOptions:{password:!0}};return{allow_bfcache:!0,privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,enabled:!0,harvestTimeSeconds:10},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},session:{domain:void 0,expiresMs:d.oD,inactiveMs:d.Hb},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10},metrics:{enabled:!0},page_action:{enabled:!0,harvestTimeSeconds:30},page_view_event:{enabled:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30,long_task:!1},session_trace:{enabled:!0,harvestTimeSeconds:10},harvest:{tooManyRequestsDelay:60},session_replay:{enabled:!1,harvestTimeSeconds:60,sampleRate:.1,errorSampleRate:.1,maskTextSelector:"*",maskAllInputs:!0,get blockClass(){return"nr-block"},get ignoreClass(){return"nr-ignore"},get maskTextClass(){return"nr-mask"},get blockSelector(){return e.blockSelector},set blockSelector(t){e.blockSelector+=",".concat(t)},get maskInputOptions(){return e.maskInputOptions},set maskInputOptions(t){e.maskInputOptions={...t,password:!0}}},spa:{enabled:!0,harvestTimeSeconds:10}}},l={};function f(e){if(!e)throw new Error("All configuration objects require an agent identifier!");if(!l[e])throw new Error("Configuration for ".concat(e," was never set"));return l[e]}function g(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");l[e]=(0,i.D)(t,u()),(0,r.Qy)(e,l[e],"config")}function p(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");var n=f(e);if(n){for(var r=t.split("."),i=0;i<r.length-1;i++)if("object"!=typeof(n=n[r[i]]))return;n=n[r[r.length-1]]}return n}const h={accountID:void 0,trustKey:void 0,agentID:void 0,licenseKey:void 0,applicationID:void 0,xpid:void 0},v={};function m(e){if(!e)throw new Error("All loader-config objects require an agent identifier!");if(!v[e])throw new Error("LoaderConfig for ".concat(e," was never set"));return v[e]}function b(e,t){if(!e)throw new Error("All loader-config objects require an agent identifier!");v[e]=(0,i.D)(t,h),(0,r.Qy)(e,v[e],"loader_config")}const y=(0,r.mF)().o;var w=n(385),A=n(6818);const x={buildEnv:A.Re,bytesSent:{},queryBytesSent:{},customTransaction:void 0,disabled:!1,distMethod:A.gF,isolatedBacklog:!1,loaderType:void 0,maxBytes:3e4,offset:Math.floor(w._A?.performance?.timeOrigin||w._A?.performance?.timing?.navigationStart||Date.now()),onerror:void 0,origin:""+w._A.location,ptid:void 0,releaseIds:{},session:void 0,xhrWrappable:"function"==typeof w._A.XMLHttpRequest?.prototype?.addEventListener,version:A.q4},D={};function _(e){if(!e)throw new Error("All runtime objects require an agent identifier!");if(!D[e])throw new Error("Runtime for ".concat(e," was never set"));return D[e]}function j(e,t){if(!e)throw new Error("All runtime objects require an agent identifier!");D[e]=(0,i.D)(t,x),(0,r.Qy)(e,D[e],"runtime")}function E(e){return function(e){try{const t=s(e);return!!t.licenseKey&&!!t.errorBeacon&&!!t.applicationID}catch(e){return!1}}(e)}},9567:(e,t,n)=>{n.d(t,{D:()=>i});var r=n(50);function i(e,t){try{if(!e||"object"!=typeo ...
#   </script>
#   <meta content="Venta del mejor catalogo de Promociones con las marcas AMD, INTEL y mas. Al mejor precio del mercado, 100% seguro." name="description"/>
#   <meta content="Promociones." name="keywords"/>
#   <link href="https://www.cyberpuerta.mx/Promociones/" rel="canonical"/>
#   <link href="https://www.cyberpuerta.mx/out/cyberpuertaV5/img/favicon.ico" rel="shortcut icon"/>
#   <script id="cp-env-data" type="application/json">
#    {"cl":"alist","isMobile":false,"isCpx":false,"enableCpNotify":false,"shopUrl":"https:\/\/www.cyberpuerta.mx","enableBanners":1690178400,"bannersFindUrl":"https:\/\/us-central1-cyberpuerta-144818.cloudfunctions.net\/cp-banner-find","bannersExpires":1690218751,"bannerPlaces":["list-main","left-top","side-left","side-right","page-top","list-main","list-left-top","side-left","side-right","page-top"],"bannerContext":[{"name":"path","value":["4fadfd9ad0936"]},{"name":"id","value":"4fadfd9ad0936"},{"name":"man","value":[]},{"name":"cklist","value":[]},{"name":"search","value":""}],"baseApiData":"*,*,4f1f198301cd6","shopPrefix":"cp","env":"prod","restrictionGroup":"1","restrictionGroupName":"Cyberpuerta","sessionToken":"","sessionId":null,"apiVersion":"v0.1","etaCalculatorUri":"https:\/\/cp-eta-calculator-e346qjngfq-uc.a.run.app","etaCalculatorExpires":1689681102,"additional":null,"noSpa":false,"showVat":true,"rai":false,"fid":{"enabled":true,"gsi_clientId":"1044917490556-kg2simrb5fm8ml0s0uubmgeri9rrfhf1.apps.googleusercontent.com","gsi_clientId_android":"1044917490556-9kvrnb85iao90rr8ejf6l4ksd5idut33.apps.googleusercontent.com","gsi_clientId_ios":"1044917490556-nqt66sdvhcel94loopng83jvjle8g4va.apps.googleusercontent.com","apple_clientId":"mx.cyberpuerta","autoLink":false,"autoRegister":true,"canAddPasswordAgain":true,"requirePasswordToLink":false},"cpAdditionalTaxInfo":true,"catalogExpires":"1689881041"}
#   </script>
#   <script id="cp-layout-view-data" type="application/json">
#    {"initialCategories":[{"id":"99748977a0a9f40e2.09126772","title":"C\u00f3mputo (Hardware)","link":"https://www.cyberpuerta.mx/Computo-Hardware/","image":"cp-menu-icon1","parentId":"","subCategories":[],"path":[],"hasSubCategories":true},{"id":"07a49b1b2f27967a1.24876408","title":"Impresi\u00f3n y Copiado","link":"https://www.cyberpuerta.mx/Impresion-y-Copiado/","image":"cp-menu-icon2","parentId":"","subCategories":[],"path":[],"hasSubCategories":true},{"id":"4fe38c01729fc","title":"Computadoras","link":"https://www.cyberpuerta.mx/Computadoras/","image":"cp-menu-icon6","parentId":"","subCategories":[],"path":[],"hasSubCategories":true},{"id":"4fe353e55a8d4","title":"Audio y Video","link":"https://www.cyberpuerta.mx/Audio-y-Video/","image":"cp-menu-icon4","parentId":"","subCategories":[],"path":[],"hasSubCategories":true},{"id":"5e8f92ef7a3a3","title":"Home Office","link":"https://www.cyberpuerta.mx/Home-Office/","image":"cp-menu-icon9","parentId":"","subCategories":[],"path":[],"hasSubCategories":true}],"moreCategoriesUrl":"https://www.cyberpuerta.mx/out/generated/main-menu/6-oxrootid-1689996556.json","menuUrl":"https://www.cyberpuerta.mx/out/generated/main-menu/main-1689996524.json","basket":{"empty":true,"articles":[],"linkNextStep":null,"numberOfItems":null,"savedItems":[],"numberOfSavedArticles":null,"linkToOffers":null,"saldoData":null,"messagesValidation":null,"errors":null,"forceOpen":null,"msiData":null,"summary":null,"paymentMethods":[],"CheckedPaymentId":""},"beforeCategories":[{"title":"Inicio","icon":"cp-menu-home-image","href":"https://www.cyberpuerta.mx/","template":""},{"title":"Mi cuenta","icon":"cp-menu-icon5","href":"","template":"cp-ko-user-menu"}],"afterCategories":[{"title":"Otras\u003Cbr\u003Ecategor\u00edas","icon":"cp-menu-icon7","href":"","template":"cp-ko-category-menu2"},{"title":"M\u00e1s\u003Cbr\u003Einformaci\u00f3n","icon":"cp-menu-icon3","href":"","template":"cp-ko-moreinfo-menu"}],"simpleHeader":false,"noHeader":false,"accountUrls":[{"url":"https://www.cyberpuerta.mx/mi-cuenta/","lang":"Mi cuenta"},{"url":"https://www.cyberpuerta.mx/historial-de-pedidos/","lang":"Historial de pedidos"},{"url":"https://www.cyberpuerta.mx/mis-direcciones/","lang":"Datos de env\u00edo, pago y facturaci\u00f3n"},{"url":"https://www.cyberpuerta.mx/mis-favoritos/","lang":"Mis favoritos"},{"url":"https://www.cyberpuerta.mx/mis-opiniones/","lang":"Mis opiniones"},{"url":"https://www.cyberpuerta.mx/mis-preguntas/","lang":"Mis preguntas"},{"url":"https://www.cyberpuerta.mx/mis-respuestas/","lang":"Mis respuestas"},{"url":"https://www.cyberpuerta.mx/mi-contrasena/","lang":"Configuraci\u00f3n de cuenta"},{"url":"https://www.cyberpuerta.mx/preferencias-de-correo/","lang":"Suscripciones"},{"url":"js-dynamic","lang":""},{"url":"#user-form=logout","lang":"Salir de cuenta","class":"button primary hollow expanded"}],"loginOptions":{"activeClass":"alist","navParams":"\u003Cinput type=\"hidden\" name=\"cnid\" value=\"4fadfd9ad0936\" /\u003E\n\u003Cinput type=\"hidden\" name=\"actcontrol\" value=\"alist\" /\u003E\n","action":"https://www.cyberpuerta.mx/index.php?","errors":[],"sizeOptions":[],"loginLink":"https://www.cyberpuerta.mx/web/account/login","logoutLink":"https://www.cyberpuerta.mx/web/account/logout","createAccountLink":"https://www.cyberpuerta.mx/crear-cuenta/","forgotPasswordLink":"https://www.cyberpuerta.mx/olvide-mi-contrasena/"},"cmsUrls":[],"basketUrl":"https://www.cyberpuerta.mx/carrito-de-compras/","homeLink":"https://www.cyberpuerta.mx/","actionLink":"https://www.cyberpuerta.mx/","searchParam":"","fidLink":null}
#   </script>
#   <script id="cp-view-data" type="application/json">
#    {"id":"4fadfd9ad0936","type":"cat","articleList":null,"linkToCompare":{"id":null,"title":"Comparaci\u00f3n de producto","url":"https://www.cyberpuerta.mx/index.php?cl=compare","image":null},"categoryAncestors":["4fadfd9ad0936"],"listMode":null,"pageSize":null,"page":0,"cpsp":{}}
#   </script>
#   <script data-cp-lang="" type="application/json">
#    {"cpx-compare":"Comparar","cpx-offer":"Oferta","cpx-new":"Nuevo","cpx-just-today":"\u00a1S\u00f3lo hoy!","cpx-from":"Desde","cpx-pcs":"Pza.|Pzs.","cpx-pcs-stock1":"Pieza en|Piezas en","cpx-pcs-stock2":"bodega|bodegas","cpx-shipping":"Env\u00edo","cpx-free-signs":"\u00a1Gratis!","cpx-out-of-stock":"Agotado","cpx-create-alert":"Crear alerta","cpx-see-more":"Ver m\u00e1s","cpx-add-to-cart":"Agregar a carrito","cpx-high-eta":"+%d d\u00edas","cpx-sku":"SKU","cpx-in-existence":"En existencia","cpx-show-all-filters":"Ver todos los filtros","cpx-show-more-options":"Ver m\u00e1s opciones...","cpx-show-less-options":"Ver menos opciones...","cpx-filters":"Filtros","cpx-applied-filters":"Filtros aplicados","cpx-in-cat-search":"Buscar en categor\u00eda","cpx-in-man-search":"Buscar en marca","cpx-sort-by":"Ordenar por","cpx-sort-by-cprelevance-desc":"Relevancia","cpx-sort-by-oxtitle-asc":"Nombre A-Z","cpx-sort-by-oxtitle-desc":"Nombre Z-A","cpx-sort-by-oxvarminprice-asc":"Menor Precio","cpx-sort-by-oxvarminprice-desc":"Mayor Precio","cpx-sort-by-oxstock-desc":"Disponibilidad","cpx-sort-by-oxinsert-desc":"M\u00e1s Nuevos","cpx-sort-by-oxrating-desc":"Mejor Calificaci\u00f3n","cpx-stock-alert-highlight":"Notificaci\u00f3n sobre nuevas existencias","cpx-stock-alert-text":"Este producto se encuentra temporalmente agotado, pero le enviaremos una notificaci\u00f3n a su correo electr\u00f3nico cuando est\u00e9 nuevamente disponible.","cpx-stock-alert-button":"Notificarme de Existencias","cpx-email":"E-mail","cpx-stock-alert-logged-msg":"Se ha activado la notificaci\u00f3n y recibir\u00e1s un correo cuando tengamos nuevas existencias de este art\u00edculo. ","cpx-stock-alert-logged-success-msg":"cpx-stock-alert-logged-success-msg","cpx-n-stars":"%d estrellas","cpx-from-n":"Desde %s","cpx-to-n":"Hasta %s","cpx-delete-all":"Borrar todos","cpx-price":"Precio","NO_ITEMS_FOUND":"No se encontraron resultados para","SEARCH_RECOMMENDATION_TITLE":"Consejos de b\u00fasqueda","SEARCH_RECOMMENDATION_ONE":"Intenta buscar por tipo de producto, marca o caracter\u00edstica del producto.","SEARCH_RECOMMENDATION_TWO":"Revisa la ortografia.","SEARCH_RECOMMENDATION_THREE":"Amplia tu b\u00fasqueda utilizando menos palabras o m\u00e1s generales.","SEARCH_RECOMMENDATION_FOUR":"Elimina los filtros aplicados que no consideres revelantes para tu b\u00fasqueda.","SEARCH_RECOMMENDATION_FIVE":"O da clic en el siguiente bot\u00f3n.","SEARCH_GO_TO_HOMEPAGE":"Ir a la p\u00e1gina principal","cpm_search_results_title":"%d resultados para \"%s\""}
#   </script>
#   <script>
#    window.cp = {}
#   </script>
#   <script data-cp-orig="cdn.jquery.js" src="https://cdnjs.cloudflare.com/ajax/libs/jquery/3.5.1/jquery.min.js">
#   </script>
#   <script data-cp-orig="cdn.foundation.js" src="https://cdnjs.cloudflare.com/ajax/libs/foundation/6.5.3/js/foundation.min.js">
#   </script>
#   <script data-cp-orig="cdn.knockout.js" src="https://cdnjs.cloudflare.com/ajax/libs/knockout/3.5.0/knockout-min.js">
#   </script>
#   <script data-cp-orig="cdn.moment.js" src="https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.27.0/moment.min.js">
#   </script>
#   <script data-cp-orig="cdn.moment-es.js" src="https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.27.0/locale/es.min.js">
#   </script>
#   <script data-cp-orig="cdn.moment-timezone.js" src="https://cdnjs.cloudflare.com/ajax/libs/moment-timezone/0.5.26/moment-timezone-with-data-10-year-range.min.js">
#   </script>
#   <script data-cp-orig="cdn.Swiper.js" src="https://cdnjs.cloudflare.com/ajax/libs/Swiper/4.3.5/js/swiper.min.js">
#   </script>
# ...
#                     exitintentdisplayed = true;
#                 }
#             }
#         }
#
#         if (!display) {
#             $(window).on("mouseleave", cpexitintent_leave);
#         }
#     });
# /**
#      * set the cookie to be sure the popup never display
#      */
#     function cpsaldo_set_newsletter_cookie()
#     {
#         let param=$('form#cpsaldo_newsletter_cookie').serialize();
#         $.ajax({
#             type: 'POST',
#             url: 'https://www.cyberpuerta.mx/index.php?',
#             data: param,
#             cache: false,
#             dataType: "html",
#         }).done(function(data) {
#             console.log(data);
#         });
#     }
#
#
#     var cpsaldo_newslettersticker_timer;
#     $('#cpsaldo_newslettersticker').mouseenter(function () {
#         clearTimeout(cpsaldo_newslettersticker_timer);
#         if ($('#cpsaldo_newslettersticker').attr('data-open') == "0") {
#             $('#cpsaldo_newslettersticker').attr('data-open', '2');
#             $('#cpsaldo_newslettersticker .bg1').animate({top: "-=120"}, 400, function () {
#             });
#             $('#cpsaldo_newslettersticker .bg2').delay(200).animate({top: "-=120"}, 400, function () {
#                 $('#cpsaldo_newslettersticker').attr('data-open', '1');
#             });
#             $('#cpsaldo_newslettersticker .bg3').animate({top: "-=120"}, 400, function () {
#             });
#         }
#         $('#cpsaldo_newslettersticker .close').stop(true).animate({opacity: 1}, 200, function () {
#         });
#     });
#     $('#cpsaldo_newslettersticker').mouseleave(function () {
#         if ($('#cpsaldo_newslettersticker').attr('data-open') != "0") {
#             cpsaldo_newslettersticker_timer = setTimeout(function () {
#                 $('#cpsaldo_newslettersticker .bg1').animate({top: "+=120"}, 1000, function () {
#                 });
#                 $('#cpsaldo_newslettersticker .bg2').animate({top: "+=120"}, 1000, function () {
#                     $('#cpsaldo_newslettersticker').attr('data-open', '0');
#                 });
#                 $('#cpsaldo_newslettersticker .bg3').animate({top: "+=120"}, 1000, function () {
#                 });
#             }, 1500);
#         }
#         $('#cpsaldo_newslettersticker .close').stop(true).animate({opacity: 0}, 200, function () {
#         });
#     });
#     $('#cpsaldo_newslettersticker .close').click(function () {
#         $('#cpsaldo_newslettersticker').animate({
#             opacity: 0
#         });
#
#         /* set cookie */
#         cpsaldo_set_newsletter_cookie();
#     });
#     $('#cpsaldo_newslettersticker div.bg10, #cpsaldo_newslettersticker div.bg1, #cpsaldo_newslettersticker div.bg2, #cpsaldo_newslettersticker div.bg3').click(function () {
#         $('#cpsaldo_newsletter_modal_popup_link').click();
#     });
# var oxwidget_headerlogin_timeoutopen = null;
#     var oxwidget_headerlogin_timeout     = null;
#     var oxwidget_headerlogin_canclose    = true;
#     var oxwidget_headerlogin_mousehover  = false;
#     $('#oxwidget_headerlogin input').focus(function () {
#         oxwidget_headerlogin_canclose = false;
#     }).blur(function () {
#         oxwidget_headerlogin_canclose = true;
#         if (!oxwidget_headerlogin_mousehover) {
#             clearTimeout(oxwidget_headerlogin_timeoutopen);
#             oxwidget_headerlogin_timeout = setTimeout(function () {
#                 $('#oxwidget_headerlogin').removeClass('hover');
#             }, 200);
#         }
#     });
#     $('#oxwidget_headerlogin').mouseenter(function () {
#         if (oxwidget_headerlogin_timeout) {
#             clearTimeout(oxwidget_headerlogin_timeout);
#         }
#         oxwidget_headerlogin_timeoutopen = setTimeout(function () {
#             $('#oxwidget_headerlogin').addClass('hover');
#         }, 200);
#
#         oxwidget_headerlogin_mousehover = true;
#     }).mouseleave(function () {
#         oxwidget_headerlogin_mousehover = false;
#         if (oxwidget_headerlogin_canclose) {
#             clearTimeout(oxwidget_headerlogin_timeoutopen);
#             oxwidget_headerlogin_timeout = setTimeout(function () {
#                 $('#oxwidget_headerlogin').removeClass('hover');
#             }, 200);
#         }
#     });
#
#     $('#logoutBtn').click(function () {
#         if (!window.dataLayer) return;
#
#         /** GA4Event */
#         window.dataLayer.push({
#             event: 'logout'
#         });
#     });
#     $('.oxwidget_headerlogin_loginform form').on('submit', function () {
#         try{
#             let localSearches = localStorage.getItem('recentSearches');
#             let localSearchesArr = [];
#             let searchesArr = [];
#             if(localSearches) {
#
#                 localSearchesArr = JSON.parse(localSearches);
#                 localSearchesArr.forEach((e) => {
#                     if(typeof e === 'string') {
#                         searchesArr.push({
#                             'date': Math.floor((new Date().getTime() - 60000) / 1000),
#                             'keyword': e
#                         });
#                     }else {
#                         searchesArr.push(e);
#                     }
#                 });
#             }
#             if(searchesArr.length > 8) {
#                 searchesArr = searchesArr.slice(searchesArr.length - 8, searchesArr.length);
#             }
#             // Add cookie to track that search is suggested
#             const d = new Date();
#             d.setTime(d.getTime() + 8000);
#             let expires = d.toUTCString();
#             document.cookie = 'recentSearchesCookie='+JSON.stringify(searchesArr)+'; expires='+expires+'; path=/;'
#         }catch (e){console.error(e);}
#     });
# $(function () {
#         var notice = $('#oxwidget_headernotice');
#         var popup = notice.find('.oxwidget_headernotice_popup');
#         popup.find('li').on("click mouseenter", function (e) {
#             popup.find('li').removeClass('selected');
#             $(e.currentTarget).addClass('selected');
#             popup.find('.oxwidget_headernotice_products > div').css('display', 'none');
#             popup.find('.oxwidget_headernotice_products #products' + $(e.currentTarget).attr('data-id')).css('display', 'block');
#         });
#
#         notice.hoverIntent(function () {
#             notice.addClass('hover');
#             var listbox = notice.find('.oxwidget_headernotice_listsbox');
#             if (listbox.length > 0 && !notice.attr('data-checked')) {
#                 notice.attr('data-checked', '1');
#                 var h = listbox.outerHeight(true);
#                 notice.find('.oxwidget_headernotice_products > div').each(function (i, el) {
#                     h = Math.max($(el).outerHeight(true), h);
#                 });
#                 popup.css('height', (h + 2) + 'px');
#                 popup.find('li').first().trigger("click");
#             }
#         }, function () {
#             notice.removeClass('hover');
#         });
#
#     });
#     function notice_global_remove(wid, aid) {
#         $('#oxwidget_headernotice_globalremove_wid').val(wid);
#         $('#oxwidget_headernotice_globalremove_aid').val(aid);
#         $('#oxwidget_headernotice_globalremove').trigger("submit");
#     }
# $(function () {
#         var help = $('#oxwidget_headerhelp');
#         help.hoverIntent(
#             function() { help.addClass('hover'); },
#             function() {help.removeClass('hover'); }
#         );
#     });
# var oxwidget_headerminibasket_timeout = null;
# $('#oxwidget_headerminibasket').mouseenter(function() {
#     $('#oxwidget_headerminibasket').addClass('hover');
#     $('#oxwidget_headerminibasket').parent('#emheaderminibasket').addClass('hover');
#     if (oxwidget_headerminibasket_timeout) {
#
#         clearTimeout(oxwidget_headerminibasket_timeout);
#     }
# }).mouseleave(function() {
#     oxwidget_headerminibasket_timeout = setTimeout(function () {
#         $('#oxwidget_headerminibasket').removeClass('hover');
#         $('#oxwidget_headerminibasket').parent('#emheaderminibasket').removeClass('hover');
#     }, 300)
# });
# $('.cp-header-overlay').click(function(){
#     $('#oxwidget_headerminibasket').removeClass('hover');
#     $('#oxwidget_headerminibasket').parent('#emheaderminibasket').removeClass('hover');
# });
# (function(){
#                 window.cpGa = window.cpGa || {};
#                 cpGa.ecPromoImp = cpGa.ecPromoImp || []; // first stored here, then pushed to datalayer
#                 window.ecPromoImpNivoShown = window.ecPromoImpNivoShown || []; // for nivoSlider
#
#                 $('a[data-ecPromoImp]').each(function(){
#                     var self = $(this);
#                     var promoFieldObject = JSON.parse(self.attr("data-ecPromoImp"));
#                     // promotion views, preparing
#                     if (promoFieldObject.creative.substr(promoFieldObject.creative.length - 2) == "-1") {
#                         // this if is because the nivoSlider will push too. If we disable the nivoSlider to do this then we remove this if
#                         window.ecPromoImpNivoShown.push(promoFieldObject.creative); // "burn" the banner so it is not counted again
#                         cpGa.ecPromoImp.push(promoFieldObject);
#                     }
#
#                     // promotion clicks
#                     self.click(function(){
#                         dataLayer.push({
#                             'event': 'promotionClick',
#                             'ecommerce': {
#                                 'promoClick': {
#                                     'promotions':[ promoFieldObject]
#                                 }
#                             }
#                         });
#                     });
#                 });
#             })();
# function cpnosto_request(place, rai = false, slot_name = "", show = false) {
#             $('#cpnosto_place').val(place);
#             let param = $('#cpnosto_form').serialize();
#             param += rai ? "&rai=true" : "";
#             param += slot_name ? `&slot_name=${ slot_name }` : "";
#             param += show ? "&show=true" : "";
#
#             // this sections
#             let specialSections = ["detail0", "home0"];
#
#             // here will be the local storage instead to use session
#             let placeId =  getCookie("_ga") + place + '';
#             let returnDataFromLocalStorage = sessionStorage.getItem(placeId);
#
#             if( !returnDataFromLocalStorage ) {
#                 $.ajax({
#                     type: 'GET',
#                     url: 'https://www.cyberpuerta.mx/index.php?',
#                     data: param,
#                     cache: false,
#                     dataType: "html",
#                 }).done(function (returndata) {
#
#                     if (returndata) {
#                         let element = `#cpnosto_${place}_result`;
#                         element += (rai) ? ".rai" : "";
#                         $(element).html(returndata);
#
#                         if ( specialSections.includes(place) ) {
#                             sessionStorage.setItem(placeId, returndata);
#                         }
#                     }
#                 });
#             } else {
#                 let element = `#cpnosto_${place}_result`;
#                 element += (rai) ? ".rai" : "";
#                 $(element).html(returnDataFromLocalStorage);
#             }
#         }
# </script>
# <script>
# var oxwidget_headercompare_timeout=null;
# var oxwidget_headercompare_timeoutdelay=null;
# var oxwidget_headercompare_timeoutopen=null;
# $('#oxwidget_headercompare').mouseenter(function() {
#     /*$('#oxwidget_headercompare').addClass('hover');*/
#     if(oxwidget_headercompare_timeoutdelay)
#     {
#         clearTimeout(oxwidget_headercompare_timeoutdelay);
#     }
#     if(oxwidget_headercompare_timeout)
#     {
#         clearTimeout(oxwidget_headercompare_timeout);
#     }
#     oxwidget_headercompare_timeoutopen=setTimeout(function() {
#         $('#oxwidget_headercompare').addClass('hover');
#     },200);
# }).mouseleave(function() {
#     if(oxwidget_headercompare_timeoutdelay)
#     {
#         clearTimeout(oxwidget_headercompare_timeoutdelay);
#     }
#     if(oxwidget_headercompare_timeoutopen)
#     {
#         clearTimeout(oxwidget_headercompare_timeoutopen);
#     }
#     oxwidget_headercompare_timeout=setTimeout(function() {
#         $('#oxwidget_headercompare').removeClass('hover');
#     },200);
# });
#
#
# function compare_global_remove(id)
# {
#     $('#oxwidget_headercompare_globalremove_aid').val(id);
#     $('#oxwidget_headercompare_globalremove').submit();
# }
#
# function compare_emstr_replace(search, replace, subject)
# {
#     return subject.split(search).join(replace);
# }
# function compare_add(id)
# {
#     $('#oxwidget_headercompare .oxwidget_headercompare_header_wait').css('display','block');
#
#     $('#compare_add'+id).css('display','none');
#     $('#compare_remove'+id).css('display','block');
#
#     var href=$('#emcomparelinkbox' + id + ' .emcomparelinkbox_link_add').attr('href');
#     href=compare_emstr_replace('&amp;','&',href);
#     href=href+'&emcomparemodule=1';
#
#     $.get(href, function(data) {
#                         var tmp='https://www.cyberpuerta.mx/index.php?cl=oxwidget_headercompare_getwidget&amp;searchparam=&amp;cnid=4fadfd9ad0936';
#         tmp=compare_emstr_replace('&amp;','&',tmp);
#         $.get(tmp,function(data) {
#             $('#oxwidget_headercompare').html(data);
#             $("#oxwidget_headercompare img").unveil();
#
#             if(oxwidget_headercompare_timeout)
#             {
#                 clearTimeout(oxwidget_headercompare_timeout);
#             }
#             $('#oxwidget_headercompare').addClass('hover');
#             oxwidget_headercompare_timeoutdelay=setTimeout(function() {
#                 $('#oxwidget_headercompare').removeClass('hover');
#             },5000);
#         });
#     });
# }
# function compare_remove(id)
# {
#     $('#oxwidget_headercompare .oxwidget_headercompare_header_wait').css('display','block');
#
#     $('#compare_add'+id).css('display','block');
#     $('#compare_remove'+id).css('display','none');
#
#     var href=$('#emcomparelinkbox' + id + ' .emcomparelinkbox_link_remove').attr('href');
#     href = href + "&emcomparemodule=1";
#     href=compare_emstr_replace('&amp;','&',href);
#     href=href+'&emcomparemodule=1';
#
#     $.get(href, function(data) {
#                         var tmp='https://www.cyberpuerta.mx/index.php?cl=oxwidget_headercompare_getwidget&amp;searchparam=&amp;cnid=4fadfd9ad0936';
#         tmp=compare_emstr_replace('&amp;','&',tmp);
#         $.get(tmp,function(data) {
#             $('#oxwidget_headercompare').html(data);
#         });
#     });
# }
#
# $('.emcomparelinkbox_link_add').on("click", function(e) {
#     var id = $(e.currentTarget).attr('data-id');
#     compare_add(id);
#     return false;
# });
# $('.emcomparelinkbox_link_remove').on("click", function(e) {
#     var id = $(e.currentTarget).attr('data-id');
#     compare_remove(id);
#     return false;
# });
# </script>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"4879248977","applicationID":"66344412","transactionName":"MQEAbUNRXkVQAEBbVghLN0tYH19OQgZbHEkOFA==","queueTime":0,"applicationTime":416,"atts":"HUYDGwtLTUs=","errorBeacon":"bam.nr-data.net","agent":""}</script><script>(function(){var js = "window['__CF$cv$params']={r:'7ebe04cfed509a47'};_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/scripts/invisible.js',document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();</script></body>
# </html>

# %% [markdown]
# <h2 style="color:blue">Ejercicio</h2>

# %%
urls = []

for i in range(1,10):
    response = requests.get(f'http://books.toscrape.com/catalogue/category/books/young-adult_21/page-{i}.html')

    if response.status_code == 200:
        urls.append(response.url)
