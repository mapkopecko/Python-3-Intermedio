# %%
from bs4 import BeautifulSoup
import requests

# %%
html_text = requests.get("https://extremetechcr.com/tienda/30-teclados").text

soup = BeautifulSoup(html_text,'html.parser')

print(soup)
# Out:
# <!DOCTYPE HTML>
#
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="es-es"><![endif]-->
# <!--[if IE 7]><html class="no-js lt-ie9 lt-ie8 ie7" lang="es-es"><![endif]-->
# <!--[if IE 8]><html class="no-js lt-ie9 ie8" lang="es-es"><![endif]-->
# <!--[if gt IE 8]> <html class="no-js ie9" lang="es-es"><![endif]-->
# <html class="default" lang="es-es">
# <head>
# <meta charset="utf-8"/>
# <title>TECLADOS - ExtremeTechCR</title>
# <meta content="PrestaShop" name="generator"/>
# <meta content="noindex,nofollow" name="robots"/>
# <meta content="width=device-width, minimum-scale=0.25, maximum-scale=1.6, initial-scale=1.0" name="viewport"/> <meta content="yes" name="apple-mobile-web-app-capable"/>
# <link href="/tienda/img/favicon.ico?1665417594" rel="icon" type="image/vnd.microsoft.icon"/>
# <link href="/tienda/img/favicon.ico?1665417594" rel="shortcut icon" type="image/x-icon"/>
# ...

# %%
product_list = soup.find_all('div', class_= 'product-container product-block')

# %%
print(product_list)
# Out:
# [<div class="product-container product-block" itemscope="" itemtype="http://schema.org/Product"><div class="left-block">
# <!-- @file modules\appagebuilder\views\templates\front\products\image_container -->
# <div class="product-image-container image">
# <div class="leo-more-info hidden-xs" data-idproduct="9676"></div>
# <a class="product_img_link" href="https://extremetechcr.com/tienda/perifericos/9676-teclado-unno-tekno-klass-usb-ingles-kb6706bk.html" itemprop="url" title="Teclado  UNNO TEKNO Klass USB Ingles - KB6706BK">
# <img alt="Teclado  UNNO TEKNO Klass USB Ingles - KB6706BK" class="replace-2x img-responsive" height="490" itemprop="image" src="https://extremetechcr.com/tienda/26741-home_default/teclado-unno-tekno-klass-usb-ingles-kb6706bk.jpg" title="Teclado  UNNO TEKNO Klass USB Ingles - KB6706BK" width="502"/>
# <span class="product-additional" data-idproduct="9676"></span>
# </a>
# ...

# %%
#product_name = soup.find('a', class_= 'product-name').text.strip()

#product_price = soup.find('span', class_= 'price product-price').text.replace(' ','').strip()

#print(product_name)
#print(product_price)

for product_lists in product_list:
    product_name = soup.find('a', class_= 'product-name').text.strip()
    product_price = soup.find('span', class_= 'price product-price').text.replace(' ','').strip()
    # print(product_name)
    # print(product_price)


    print(f'''
    Product name {product_name}
    Product price {product_price}
    ''')
# Out:
#     Product name Teclado  UNNO TEKNO Klass USB Ingles -...
#     Product price ₡4,000
#
#
#     Product name Teclado  UNNO TEKNO Klass USB Ingles -...
#     Product price ₡4,000
#
#
#     Product name Teclado  UNNO TEKNO Klass USB Ingles -...
#     Product price ₡4,000
#
#
#     Product name Teclado  UNNO TEKNO Klass USB Ingles -...
#     Product price ₡4,000
#
#
#     Product name Teclado  UNNO TEKNO Klass USB Ingles -...
#     Product price ₡4,000
#
#
#     Product name Teclado  UNNO TEKNO Klass USB Ingles -...
#     Product price ₡4,000
#
#
#     Product name Teclado  UNNO TEKNO Klass USB Ingles -...
#     Product price ₡4,000
#
#
#     Product name Teclado  UNNO TEKNO Klass USB Ingles -...
#     Product price ₡4,000
#
#
#     Product name Teclado  UNNO TEKNO Klass USB Ingles -...
#     Product price ₡4,000
#
#
#     Product name Teclado  UNNO TEKNO Klass USB Ingles -...
#     Product price ₡4,000
#
#
#     Product name Teclado  UNNO TEKNO Klass USB Ingles -...
# ...
